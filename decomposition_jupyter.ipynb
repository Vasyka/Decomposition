# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#from decompose import *
'''
# На старых данных:
dec = Decomposition()
path_and_sheetnames = {"./data/задание 1 для студентов.xlsx": [0, 1]}
dec.load_WIOD2013_merged_data(**path_and_sheetnames)
dec.prepare_data(column_order='eng')

# Запускаем методы декомпозиции
dec.decomposition_Baranov_2016()
dec.decomposition_Baranov_2018()
dec.decomposition_Magacho_2018()
'''

# На новых данных:
# Создаем новый экземпляр класса, загружаем данные и готовим их к декомпозиции
dec1 = Decomposition()
path_and_sheetnames1 = {"./data/симметричные таблицы WIOD 2003 и 2010 в ценах 2008 25 декабря.xlsx": [0, 1]}
dec1.load_WIOD2013_merged_data(**path_and_sheetnames1)
dec1.prepare_data(column_order='eng')

# Запускаем методы декомпозиции
dec1.decomposition_Baranov_2016()
dec1.decomposition_Baranov_2018()
dec1.decomposition_Magacho_2018()
dec1.decomposition_Chenery_extended()
# Out:
# Годы таблицы: 2003-2010
#
# Результат работы метода декомпозиции Baranov_2016 сохранен в папку results!
# Результат работы метода декомпозиции Baranov_2018 сохранен в папку results!
#
# Результат работы метода декомпозиции Magacho_2018 сохранен в папку results!
#
# Результат работы метода декомпозиции Chenery_extended сохранен в папку results!

# %%
# Создаем новый экземпляр класса, загружаем данные и готовим их к декомпозиции
dec = Decomposition()
path_and_sheetnames = {"./data/all2011.xlsx": ['SD calculated def', 'SM calculated def'],
                       "./data/all2014 (проверочная).xlsx": ['SD calculated def', 'SM calculated def']}
dec.load_Rosstat_separated_data(**path_and_sheetnames)
dec.prepare_data(column_order='rus')
# Запускаем методы декомпозиции
dec.decomposition_Baranov_2016()
dec.decomposition_Baranov_2018()
dec.decomposition_Magacho_2018()
dec.decomposition_Chenery_extended()
# Out:
# Годы таблицы: 2011-2014
#
# Результат работы метода декомпозиции Baranov_2016 сохранен в папку results!
# Результат работы метода декомпозиции Baranov_2018 сохранен в папку results!
#
# Результат работы метода декомпозиции Magacho_2018 сохранен в папку results!
#
# Результат работы метода декомпозиции Chenery_extended сохранен в папку results!

# %%
# Создаем новый экземпляр класса, загружаем данные и готовим их к декомпозиции
dec = Decomposition()
path_and_sheetnames = {"./data/all2014 (проверочная).xlsx": ['SD calculated def', 'SM calculated def'],
                       "./data/all2015 (проверочная).xlsx": ['SD calculated def', 'SM calculated def']}
dec.load_Rosstat_separated_data(**path_and_sheetnames)
dec.prepare_data(column_order='rus')

# Запускаем методы декомпозиции
dec.decomposition_Baranov_2016()
dec.decomposition_Baranov_2018()
dec.decomposition_Magacho_2018()
dec.decomposition_Chenery_extended()
# Out:
# Годы таблицы: 2014-2015
#
# Результат работы метода декомпозиции Baranov_2016 сохранен в папку results!
# Результат работы метода декомпозиции Baranov_2018 сохранен в папку results!
#
# Результат работы метода декомпозиции Magacho_2018 сохранен в папку results!
#
# Результат работы метода декомпозиции Chenery_extended сохранен в папку results!

# %%
import os
import re
import warnings
from operator import add
import timeit

import numpy as np
import pandas as pd

# Отключаем warnings
warnings.simplefilter("ignore")
# Расположение 1ого квадранта таблицы и столбцов\строк с названиями в ней
vertical_table_position = slice(5, 75)  # положение и размеры таблицы по вертикали
horizontal_table_position = slice(4, 46)  # положение и размеры таблицы по горизонтали
industries_part_position = slice(4, 39)  # положение и размеры части таблицы с промежуточным потреблением по
# горизонтали
codes_position = 1  # номер строки в таблице с кодами отраслей
columns_names_position = 2  # номер строки в таблице с названиями колонок
rows_names_position = 1  # номер столбца в таблице с названиями строк
countries_names_col = 2 # номер столбца в таблице с названиями стран
countries_names_row = 3  # номер строки в таблице с названиями стран

start_year = 95
end_year = 96
path1 = "./data/raw_wiod13/"
path2 = "./drive/My Drive/"
file_path = path2 + "wiot" + str(end_year) + "_row_pyp_dec14.xlsx" #"_row_apr12.xlsx"



country = "BRA" #Brazil

start = timeit.default_timer()
file = pd.ExcelFile(file_path)
world_df1 = pd.read_excel(file, sheet_name=0)
print(timeit.default_timer() - start,'s')
world_df1.head()
# Out:
# 26.76192963099993 s
#             Intercountry Input-Output Table for 1996 Unnamed: 1 Unnamed: 2  \
# 0  Intercountry Input-Output Table for 1996 in pr...        NaN        NaN
# 1                             (industry-by-industry)        NaN        NaN
# 2                                  (millions of US$)        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4                                                NaN        NaN        NaN
#
#   Unnamed: 3                                  Unnamed: 4  \
# 0        NaN                                         NaN
# 1        NaN                                         AtB
# 2        NaN  Agriculture, Hunting, Forestry and Fishing
# 3        NaN                                         AUS
# 4        NaN                                          c1
#
#              Unnamed: 5                   Unnamed: 6  \
# 0                   NaN                          NaN
# 1                     C                        15t16
# 2  Mining and Quarrying  Food, Beverages and Tobacco
# 3                   AUS                          AUS
# 4                    c2                           c3
#
#                       Unnamed: 7                     Unnamed: 8  \
# 0                            NaN                            NaN
# 1                          17t18                             19
# 2  Textiles and Textile Products  Leather, Leather and Footwear
# 3                            AUS                            AUS
# 4                             c4                             c5
#
#                            Unnamed: 9      ...       \
# 0                                 NaN      ...
# 1                                  20      ...
# 2  Wood and Products of Wood and Cork      ...
# 3                                 AUS      ...
# 4                                  c6      ...
#
#                                        Unnamed: 1635  \
# 0                                                NaN
# 1                                            CONS_np
# 2  Final consumption expenditure by non-profit or...
# 3                                                USA
# 4                                                c38
#
#                                  Unnamed: 1636                  Unnamed: 1637  \
# 0                                          NaN                            NaN
# 1                                       CONS_g                           GFCF
# 2  Final consumption expenditure by government  Gross fixed capital formation
# 3                                          USA                            USA
# 4                                          c39                            c41
#
#                           Unnamed: 1638  \
# 0                                   NaN
# 1                                 INVEN
# 2  Changes in inventories and valuables
# 3                                   USA
# 4                                   c42
#
#                                  Unnamed: 1639  \
# 0                                          NaN
# 1                                       CONS_h
# 2  Final consumption expenditure by households
# 3                                          RoW
# 4                                          c37
#
#                                        Unnamed: 1640  \
# 0                                                NaN
# 1                                            CONS_np
# 2  Final consumption expenditure by non-profit or...
# 3                                                RoW
# 4                                                c38
#
#                                  Unnamed: 1641                  Unnamed: 1642  \
# 0                                          NaN                            NaN
# 1                                       CONS_g                           GFCF
# 2  Final consumption expenditure by government  Gross fixed capital formation
# 3                                          RoW                            RoW
# 4                                          c39                            c41
#
#                           Unnamed: 1643 Unnamed: 1644
# 0                                   NaN           NaN
# 1                                 INVEN           NaN
# 2  Changes in inventories and valuables  Total output
# 3                                   RoW           NaN
# 4                                   c42           NaN
#
# [5 rows x 1645 columns]

# %%
# Получаем столбец/строку с названиями стран
countries_col = world_df1.iloc[:,countries_names_col]
countries_row = world_df1.iloc[countries_names_row,:]
# Получаем расположение данных для выбранной страны
vertical_country_position = np.where(countries_col == country)[0]
horizontal_country_position = np.where(countries_row == country)[0]
vertical_country_position
#horizontal_country_position
# Out:
# array([145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157,
#        158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170,
#        171, 172, 173, 174, 175, 176, 177, 178, 179])

# %%
# set columns & index 
columns = world_df1.iloc[columns_names_position,horizontal_country_position].values
index = world_df1.iloc[vertical_country_position, rows_names_position].values
industries_col = world_df1.iloc[:,rows_names_position]

import_df = pd.DataFrame(columns=columns, index = index)
import_df.columns.name = world_df1.columns[0] + ": " + country + " import"


# merge sum import by industries for all countries except chosen
for industry in index:
    industry_indexes = np.where(industries_col == industry)[0]
    
    # get import by industry for all counties except chosen
    import_by_industry = world_df1.iloc[industry_indexes, horizontal_country_position]
    import_by_industry = import_by_industry[countries_col[industry_indexes] != country]
    import_by_industry = import_by_industry.sum(axis=0).values
    
    import_df.loc[industry,:] = import_by_industry

import_df
# Out:
# Intercountry Input-Output Table for 1996: BRA import Agriculture, Hunting, Forestry and Fishing  \
# Agriculture, Hunting, Forestry and Fishing                                              253.934
# Mining and Quarrying                                                                    66.4898
# Food, Beverages and Tobacco                                                              106.93
# Textiles and Textile Products                                                           13.6758
# Leather, Leather and Footwear                                                          0.252136
# Wood and Products of Wood and Cork                                                      2.24454
# Pulp, Paper, Paper , Printing and Publishing                                            2.41363
# Coke, Refined Petroleum and Nuclear Fuel                                                88.6026
# Chemicals and Chemical Products                                                         1030.95
# Rubber and Plastics                                                                     17.5183
# Other Non-Metallic Mineral                                                              3.66195
# Basic Metals and Fabricated Metal                                                       15.1864
# Machinery, Nec                                                                          2.49347
# Electrical and Optical Equipment                                                        4.41138
# Transport Equipment                                                                        3.22
# Manufacturing, Nec; Recycling                                                           1.89973
# Electricity, Gas and Water Supply                                                       9.81857
# Construction                                                                           0.241523
# Sale, Maintenance and Repair of Motor Vehicles ...                                      1.55437
# Wholesale Trade and Commission Trade, Except of...                                      11.9283
# Retail Trade, Except of Motor Vehicles and Moto...                                      3.90902
# Hotels and Restaurants                                                                 0.751268
# Inland Transport                                                                        16.6513
# Water Transport                                                                         1.53177
# Air Transport                                                                           1.96259
# Other Supporting and Auxiliary Transport Activi...                                      7.74381
# Post and Telecommunications                                                             5.91528
# Financial Intermediation                                                                6.49207
# Real Estate Activities                                                                  1.97621
# Renting of M&Eq and Other Business Activities                                           0.85667
# Public Admin and Defence; Compulsory Social Sec...                                     0.793027
# Education                                                                             0.0100786
# Health and Social Work                                                                0.0537064
# Other Community, Social and Personal Services                                          0.576471
# Private Households with Employed Persons                                              0.0138134
#
# Intercountry Input-Output Table for 1996: BRA import Mining and Quarrying  \
# Agriculture, Hunting, Forestry and Fishing                       0.241656
# Mining and Quarrying                                                190.9
# Food, Beverages and Tobacco                                      0.861983
# Textiles and Textile Products                                     7.79476
# Leather, Leather and Footwear                                    0.145751
# Wood and Products of Wood and Cork                               0.350001
# Pulp, Paper, Paper , Printing and Publishing                      5.51219
# Coke, Refined Petroleum and Nuclear Fuel                          32.5923
# Chemicals and Chemical Products                                   57.6994
# Rubber and Plastics                                               13.3651
# Other Non-Metallic Mineral                                        3.96653
# Basic Metals and Fabricated Metal                                 55.1718
# Machinery, Nec                                                    110.297
# Electrical and Optical Equipment                                  37.8962
# Transport Equipment                                               7.21298
# Manufacturing, Nec; Recycling                                     1.09147
# Electricity, Gas and Water Supply                                 14.4045
# Construction                                                     0.878475
# Sale, Maintenance and Repair of Motor Vehicles ...               0.527801
# Wholesale Trade and Commission Trade, Except of...                5.39384
# Retail Trade, Except of Motor Vehicles and Moto...                 1.8325
# Hotels and Restaurants                                            77.7133
# Inland Transport                                                  25.6322
# Water Transport                                                   2.18721
# Air Transport                                                     2.73069
# Other Supporting and Auxiliary Transport Activi...                10.8546
# Post and Telecommunications                                       17.0811
# Financial Intermediation                                          7.26513
# Real Estate Activities                                            46.3037
# Renting of M&Eq and Other Business Activities                     40.5777
# Public Admin and Defence; Compulsory Social Sec...                1.10784
# Education                                                         3.34067
# Health and Social Work                                           0.399104
# Other Community, Social and Personal Services                     1.27175
# Private Households with Employed Persons                      0.000180453
#
# Intercountry Input-Output Table for 1996: BRA import Food, Beverages and Tobacco  \
# Agriculture, Hunting, Forestry and Fishing                               1467.15
# Mining and Quarrying                                                     7.46264
# Food, Beverages and Tobacco                                              396.883
# Textiles and Textile Products                                             12.928
# Leather, Leather and Footwear                                           0.298826
# Wood and Products of Wood and Cork                                        1.3955
# Pulp, Paper, Paper , Printing and Publishing                             77.3915
# Coke, Refined Petroleum and Nuclear Fuel                                 41.8693
# Chemicals and Chemical Products                                          180.359
# Rubber and Plastics                                                       95.582
# Other Non-Metallic Mineral                                               10.3682
# Basic Metals and Fabricated Metal                                        81.0037
# Machinery, Nec                                                           92.3581
# Electrical and Optical Equipment                                         28.2906
# Transport Equipment                                                      15.1201
# Manufacturing, Nec; Recycling                                            2.84209
# Electricity, Gas and Water Supply                                         24.964
# Construction                                                            0.731017
# Sale, Maintenance and Repair of Motor Vehicles ...                       3.85912
# Wholesale Trade and Commission Trade, Except of...                       22.3416
# Retail Trade, Except of Motor Vehicles and Moto...                       9.81225
# Hotels and Restaurants                                                   38.8466
# Inland Transport                                                         42.3406
# Water Transport                                                          3.91034
# Air Transport                                                            5.00631
# Other Supporting and Auxiliary Transport Activi...                       19.6562
# Post and Telecommunications                                              14.0892
# Financial Intermediation                                                  22.858
# Real Estate Activities                                                   12.9722
# Renting of M&Eq and Other Business Activities                            77.1391
# Public Admin and Defence; Compulsory Social Sec...                       1.87379
# Education                                                                5.70844
# Health and Social Work                                                  0.326127
# Other Community, Social and Personal Services                            1.75693
# Private Households with Employed Persons                               0.0868117
#
# Intercountry Input-Output Table for 1996: BRA import Textiles and Textile Products  \
# Agriculture, Hunting, Forestry and Fishing                                 28.3349
# Mining and Quarrying                                                       1.31884
# Food, Beverages and Tobacco                                                1.83383
# Textiles and Textile Products                                              767.503
# Leather, Leather and Footwear                                              3.58086
# Wood and Products of Wood and Cork                                        0.336804
# Pulp, Paper, Paper , Printing and Publishing                               7.69961
# Coke, Refined Petroleum and Nuclear Fuel                                   21.3988
# Chemicals and Chemical Products                                            222.392
# Rubber and Plastics                                                         11.501
# Other Non-Metallic Mineral                                                0.869844
# Basic Metals and Fabricated Metal                                           2.5773
# Machinery, Nec                                                             41.2931
# Electrical and Optical Equipment                                           5.02523
# Transport Equipment                                                        3.54894
# Manufacturing, Nec; Recycling                                              5.62565
# Electricity, Gas and Water Supply                                          13.8234
# Construction                                                              0.120584
# Sale, Maintenance and Repair of Motor Vehicles ...                         1.03094
# Wholesale Trade and Commission Trade, Except of...                         6.76248
# Retail Trade, Except of Motor Vehicles and Moto...                         3.69477
# Hotels and Restaurants                                                   0.0281514
# Inland Transport                                                           7.82978
# Water Transport                                                           0.716375
# Air Transport                                                             0.914873
# Other Supporting and Auxiliary Transport Activi...                         3.62851
# Post and Telecommunications                                                1.64101
# Financial Intermediation                                                   6.73795
# Real Estate Activities                                                      6.8053
# Renting of M&Eq and Other Business Activities                               12.798
# Public Admin and Defence; Compulsory Social Sec...                        0.458672
# Education                                                                 0.946739
# Health and Social Work                                                    0.140638
# Other Community, Social and Personal Services                             0.461355
# Private Households with Employed Persons                                0.00188525
#
# Intercountry Input-Output Table for 1996: BRA import Leather, Leather and Footwear  \
# Agriculture, Hunting, Forestry and Fishing                                0.726446
# Mining and Quarrying                                                       2.44829
# Food, Beverages and Tobacco                                                31.0862
# Textiles and Textile Products                                              38.5652
# Leather, Leather and Footwear                                              107.827
# Wood and Products of Wood and Cork                                        0.402557
# Pulp, Paper, Paper , Printing and Publishing                               24.8707
# Coke, Refined Petroleum and Nuclear Fuel                                   5.66821
# Chemicals and Chemical Products                                                149
# Rubber and Plastics                                                        17.1323
# Other Non-Metallic Mineral                                                 1.36167
# Basic Metals and Fabricated Metal                                          7.42655
# Machinery, Nec                                                             9.29963
# Electrical and Optical Equipment                                           4.80976
# Transport Equipment                                                        1.17407
# Manufacturing, Nec; Recycling                                              1.22352
# Electricity, Gas and Water Supply                                          3.18692
# Construction                                                             0.0821268
# Sale, Maintenance and Repair of Motor Vehicles ...                        0.537574
# Wholesale Trade and Commission Trade, Except of...                         4.10064
# Retail Trade, Except of Motor Vehicles and Moto...                         2.02181
# Hotels and Restaurants                                                    0.225402
# Inland Transport                                                           4.32584
# Water Transport                                                           0.395647
# Air Transport                                                             0.509356
# Other Supporting and Auxiliary Transport Activi...                         2.00605
# Post and Telecommunications                                                2.19938
# Financial Intermediation                                                   2.38949
# Real Estate Activities                                                     1.51409
# Renting of M&Eq and Other Business Activities                              7.19647
# Public Admin and Defence; Compulsory Social Sec...                        0.157332
# Education                                                                 0.528498
# Health and Social Work                                                   0.0251853
# Other Community, Social and Personal Services                             0.332271
# Private Households with Employed Persons                               0.000117702
#
# Intercountry Input-Output Table for 1996: BRA import Wood and Products of Wood and Cork  \
# Agriculture, Hunting, Forestry and Fishing                                      30.3103
# Mining and Quarrying                                                           0.389735
# Food, Beverages and Tobacco                                                    0.312537
# Textiles and Textile Products                                                  0.187989
# Leather, Leather and Footwear                                                 0.0197307
# Wood and Products of Wood and Cork                                              22.7831
# Pulp, Paper, Paper , Printing and Publishing                                    7.21185
# Coke, Refined Petroleum and Nuclear Fuel                                         7.6744
# Chemicals and Chemical Products                                                  27.743
# Rubber and Plastics                                                             4.72093
# Other Non-Metallic Mineral                                                     0.216035
# Basic Metals and Fabricated Metal                                                 7.269
# Machinery, Nec                                                                  12.7722
# Electrical and Optical Equipment                                                1.72235
# Transport Equipment                                                              1.1435
# Manufacturing, Nec; Recycling                                                  0.377189
# Electricity, Gas and Water Supply                                                3.5081
# Construction                                                                    0.18495
# Sale, Maintenance and Repair of Motor Vehicles ...                             0.133661
# Wholesale Trade and Commission Trade, Except of...                             0.879453
# Retail Trade, Except of Motor Vehicles and Moto...                             0.364289
# Hotels and Restaurants                                                           7.0507
# Inland Transport                                                                2.63078
# Water Transport                                                                0.247249
# Air Transport                                                                  0.308639
# Other Supporting and Auxiliary Transport Activi...                              1.21951
# Post and Telecommunications                                                    0.666392
# Financial Intermediation                                                         1.5596
# Real Estate Activities                                                         0.876628
# Renting of M&Eq and Other Business Activities                                   2.56731
# Public Admin and Defence; Compulsory Social Sec...                             0.496662
# Education                                                                      0.220371
# Health and Social Work                                                        0.0344353
# Other Community, Social and Personal Services                                    0.1198
# Private Households with Employed Persons                                    3.12872e-05
#
# Intercountry Input-Output Table for 1996: BRA import Pulp, Paper, Paper , Printing and Publishing  \
# Agriculture, Hunting, Forestry and Fishing                                                37.7255
# Mining and Quarrying                                                                      21.2552
# Food, Beverages and Tobacco                                                               3.26563
# Textiles and Textile Products                                                             9.50762
# Leather, Leather and Footwear                                                            0.591568
# Wood and Products of Wood and Cork                                                        3.01425
# Pulp, Paper, Paper , Printing and Publishing                                              471.986
# Coke, Refined Petroleum and Nuclear Fuel                                                  17.1429
# Chemicals and Chemical Products                                                           273.273
# Rubber and Plastics                                                                       42.9913
# Other Non-Metallic Mineral                                                                1.81382
# Basic Metals and Fabricated Metal                                                         23.2872
# Machinery, Nec                                                                            35.0125
# Electrical and Optical Equipment                                                          34.6213
# Transport Equipment                                                                       5.16415
# Manufacturing, Nec; Recycling                                                             1.57223
# Electricity, Gas and Water Supply                                                         14.5832
# Construction                                                                             0.254579
# Sale, Maintenance and Repair of Motor Vehicles ...                                       0.915791
# Wholesale Trade and Commission Trade, Except of...                                        6.36413
# Retail Trade, Except of Motor Vehicles and Moto...                                        2.47541
# Hotels and Restaurants                                                                    14.9438
# Inland Transport                                                                           9.9499
# Water Transport                                                                          0.924229
# Air Transport                                                                             1.17062
# Other Supporting and Auxiliary Transport Activi...                                        4.62461
# Post and Telecommunications                                                               8.46799
# Financial Intermediation                                                                  9.15032
# Real Estate Activities                                                                    8.63073
# Renting of M&Eq and Other Business Activities                                             48.6082
# Public Admin and Defence; Compulsory Social Sec...                                        1.50919
# Education                                                                                 3.58354
# Health and Social Work                                                                   0.175593
# Other Community, Social and Personal Services                                            0.735468
# Private Households with Employed Persons                                              0.000236374
#
# Intercountry Input-Output Table for 1996: BRA import Coke, Refined Petroleum and Nuclear Fuel  \
# Agriculture, Hunting, Forestry and Fishing                                            84.9524
# Mining and Quarrying                                                                  3487.09
# Food, Beverages and Tobacco                                                           5.03144
# Textiles and Textile Products                                                          1.2965
# Leather, Leather and Footwear                                                       0.0319444
# Wood and Products of Wood and Cork                                                  0.0715749
# Pulp, Paper, Paper , Printing and Publishing                                          1.60237
# Coke, Refined Petroleum and Nuclear Fuel                                              378.589
# Chemicals and Chemical Products                                                       32.9837
# Rubber and Plastics                                                                   5.55383
# Other Non-Metallic Mineral                                                            1.81799
# Basic Metals and Fabricated Metal                                                     13.5279
# Machinery, Nec                                                                         26.604
# Electrical and Optical Equipment                                                      13.1533
# Transport Equipment                                                                   3.02309
# Manufacturing, Nec; Recycling                                                         0.60711
# Electricity, Gas and Water Supply                                                     25.6925
# Construction                                                                          0.46139
# Sale, Maintenance and Repair of Motor Vehicles ...                                    1.37585
# Wholesale Trade and Commission Trade, Except of...                                    163.634
# Retail Trade, Except of Motor Vehicles and Moto...                                     2.2194
# Hotels and Restaurants                                                                13.9683
# Inland Transport                                                                      226.497
# Water Transport                                                                      0.955121
# Air Transport                                                                         1.16124
# Other Supporting and Auxiliary Transport Activi...                                    4.63202
# Post and Telecommunications                                                           5.33149
# Financial Intermediation                                                              3.24008
# Real Estate Activities                                                                  20.27
# Renting of M&Eq and Other Business Activities                                         19.1331
# Public Admin and Defence; Compulsory Social Sec...                                   0.466521
# Education                                                                             1.56376
# Health and Social Work                                                               0.112148
# Other Community, Social and Personal Services                                         3.72573
# Private Households with Employed Persons                                           0.00527122
#
# Intercountry Input-Output Table for 1996: BRA import Chemicals and Chemical Products  \
# Agriculture, Hunting, Forestry and Fishing                                   4.07332
# Mining and Quarrying                                                         181.223
# Food, Beverages and Tobacco                                                  24.4735
# Textiles and Textile Products                                                16.8928
# Leather, Leather and Footwear                                               0.474113
# Wood and Products of Wood and Cork                                           2.99483
# Pulp, Paper, Paper , Printing and Publishing                                 41.8672
# Coke, Refined Petroleum and Nuclear Fuel                                     229.224
# Chemicals and Chemical Products                                              1770.52
# Rubber and Plastics                                                          36.8621
# Other Non-Metallic Mineral                                                   13.5247
# Basic Metals and Fabricated Metal                                            45.5321
# Machinery, Nec                                                                69.171
# Electrical and Optical Equipment                                             25.5653
# Transport Equipment                                                          8.17499
# Manufacturing, Nec; Recycling                                                2.92996
# Electricity, Gas and Water Supply                                            23.7673
# Construction                                                                  0.7918
# Sale, Maintenance and Repair of Motor Vehicles ...                           2.30971
# Wholesale Trade and Commission Trade, Except of...                           18.9648
# Retail Trade, Except of Motor Vehicles and Moto...                           5.09139
# Hotels and Restaurants                                                        14.551
# Inland Transport                                                             20.7827
# Water Transport                                                              1.78802
# Air Transport                                                                  2.261
# Other Supporting and Auxiliary Transport Activi...                            8.9601
# Post and Telecommunications                                                  18.1509
# Financial Intermediation                                                     17.1734
# Real Estate Activities                                                       8.21266
# Renting of M&Eq and Other Business Activities                                62.7562
# Public Admin and Defence; Compulsory Social Sec...                           1.12694
# Education                                                                    5.11537
# Health and Social Work                                                      0.259413
# Other Community, Social and Personal Services                                1.38768
# Private Households with Employed Persons                                 0.000610639
#
# Intercountry Input-Output Table for 1996: BRA import Rubber and Plastics  \
# Agriculture, Hunting, Forestry and Fishing                       6.77568
# Mining and Quarrying                                             4.10096
# Food, Beverages and Tobacco                                      5.03807
# Textiles and Textile Products                                    19.7911
# Leather, Leather and Footwear                                   0.332775
# Wood and Products of Wood and Cork                              0.641717
# Pulp, Paper, Paper , Printing and Publishing                     36.7457
# Coke, Refined Petroleum and Nuclear Fuel                          37.293
# Chemicals and Chemical Products                                  935.781
# Rubber and Plastics                                              66.3497
# Other Non-Metallic Mineral                                       2.15738
# Basic Metals and Fabricated Metal                                24.6977
# Machinery, Nec                                                   35.8304
# Electrical and Optical Equipment                                 19.3995
# Transport Equipment                                              8.92251
# Manufacturing, Nec; Recycling                                    2.29862
# Electricity, Gas and Water Supply                                10.2661
# Construction                                                    0.235544
# Sale, Maintenance and Repair of Motor Vehicles ...              0.998345
# Wholesale Trade and Commission Trade, Except of...               8.01033
# Retail Trade, Except of Motor Vehicles and Moto...               2.28895
# Hotels and Restaurants                                           11.3981
# Inland Transport                                                 7.65982
# Water Transport                                                 0.710764
# Air Transport                                                   0.898121
# Other Supporting and Auxiliary Transport Activi...               3.55092
# Post and Telecommunications                                      7.82973
# Financial Intermediation                                         5.23949
# Real Estate Activities                                           4.80042
# Renting of M&Eq and Other Business Activities                    10.8846
# Public Admin and Defence; Compulsory Social Sec...              0.501141
# Education                                                       0.825816
# Health and Social Work                                          0.113421
# Other Community, Social and Personal Services                   0.872103
# Private Households with Employed Persons                     0.000578529
#
# Intercountry Input-Output Table for 1996: BRA import                 ...                   \
# Agriculture, Hunting, Forestry and Fishing                           ...
# Mining and Quarrying                                                 ...
# Food, Beverages and Tobacco                                          ...
# Textiles and Textile Products                                        ...
# Leather, Leather and Footwear                                        ...
# Wood and Products of Wood and Cork                                   ...
# Pulp, Paper, Paper , Printing and Publishing                         ...
# Coke, Refined Petroleum and Nuclear Fuel                             ...
# Chemicals and Chemical Products                                      ...
# Rubber and Plastics                                                  ...
# Other Non-Metallic Mineral                                           ...
# Basic Metals and Fabricated Metal                                    ...
# Machinery, Nec                                                       ...
# Electrical and Optical Equipment                                     ...
# Transport Equipment                                                  ...
# Manufacturing, Nec; Recycling                                        ...
# Electricity, Gas and Water Supply                                    ...
# Construction                                                         ...
# Sale, Maintenance and Repair of Motor Vehicles ...                   ...
# Wholesale Trade and Commission Trade, Except of...                   ...
# Retail Trade, Except of Motor Vehicles and Moto...                   ...
# Hotels and Restaurants                                               ...
# Inland Transport                                                     ...
# Water Transport                                                      ...
# Air Transport                                                        ...
# Other Supporting and Auxiliary Transport Activi...                   ...
# Post and Telecommunications                                          ...
# Financial Intermediation                                             ...
# Real Estate Activities                                               ...
# Renting of M&Eq and Other Business Activities                        ...
# Public Admin and Defence; Compulsory Social Sec...                   ...
# Education                                                            ...
# Health and Social Work                                               ...
# Other Community, Social and Personal Services                        ...
# Private Households with Employed Persons                             ...
#
# Intercountry Input-Output Table for 1996: BRA import Public Admin and Defence; Compulsory Social Security  \
# Agriculture, Hunting, Forestry and Fishing                                                      4.81713
# Mining and Quarrying                                                                            5.83409
# Food, Beverages and Tobacco                                                                     29.6568
# Textiles and Textile Products                                                                   1.93488
# Leather, Leather and Footwear                                                                   0.10087
# Wood and Products of Wood and Cork                                                             0.485841
# Pulp, Paper, Paper , Printing and Publishing                                                    31.2524
# Coke, Refined Petroleum and Nuclear Fuel                                                        80.6719
# Chemicals and Chemical Products                                                                 125.335
# Rubber and Plastics                                                                             2.97631
# Other Non-Metallic Mineral                                                                      1.95509
# Basic Metals and Fabricated Metal                                                               24.1205
# Machinery, Nec                                                                                  25.5825
# Electrical and Optical Equipment                                                                91.9929
# Transport Equipment                                                                             27.6304
# Manufacturing, Nec; Recycling                                                                   2.22262
# Electricity, Gas and Water Supply                                                               41.6544
# Construction                                                                                    2.41078
# Sale, Maintenance and Repair of Motor Vehicles ...                                              0.88037
# Wholesale Trade and Commission Trade, Except of...                                              5.26967
# Retail Trade, Except of Motor Vehicles and Moto...                                               6.2371
# Hotels and Restaurants                                                                           452.84
# Inland Transport                                                                                8.01557
# Water Transport                                                                                 1.13976
# Air Transport                                                                                   1.22395
# Other Supporting and Auxiliary Transport Activi...                                              3.75267
# Post and Telecommunications                                                                     172.517
# Financial Intermediation                                                                        101.831
# Real Estate Activities                                                                          61.1392
# Renting of M&Eq and Other Business Activities                                                   196.807
# Public Admin and Defence; Compulsory Social Sec...                                              2.91541
# Education                                                                                        25.384
# Health and Social Work                                                                          4.39709
# Other Community, Social and Personal Services                                                   7.16577
# Private Households with Employed Persons                                                     0.00045341
#
# Intercountry Input-Output Table for 1996: BRA import    Education  \
# Agriculture, Hunting, Forestry and Fishing                2.63967
# Mining and Quarrying                                      1.57671
# Food, Beverages and Tobacco                               13.7519
# Textiles and Textile Products                             0.50693
# Leather, Leather and Footwear                            0.096808
# Wood and Products of Wood and Cork                       0.330429
# Pulp, Paper, Paper , Printing and Publishing              13.0516
# Coke, Refined Petroleum and Nuclear Fuel                  13.5585
# Chemicals and Chemical Products                           50.0159
# Rubber and Plastics                                      0.892234
# Other Non-Metallic Mineral                                1.17314
# Basic Metals and Fabricated Metal                         2.50731
# Machinery, Nec                                            32.1535
# Electrical and Optical Equipment                          12.1632
# Transport Equipment                                       5.80581
# Manufacturing, Nec; Recycling                             15.3001
# Electricity, Gas and Water Supply                         18.2685
# Construction                                              1.57709
# Sale, Maintenance and Repair of Motor Vehicles ...       0.418184
# Wholesale Trade and Commission Trade, Except of...         2.4806
# Retail Trade, Except of Motor Vehicles and Moto...         2.2426
# Hotels and Restaurants                                    129.862
# Inland Transport                                          4.98723
# Water Transport                                          0.571715
# Air Transport                                            0.622274
# Other Supporting and Auxiliary Transport Activi...        2.32859
# Post and Telecommunications                               50.9248
# Financial Intermediation                                  3.41081
# Real Estate Activities                                    38.9227
# Renting of M&Eq and Other Business Activities             83.6442
# Public Admin and Defence; Compulsory Social Sec...        1.23642
# Education                                                 11.4332
# Health and Social Work                                   0.654666
# Other Community, Social and Personal Services             2.06141
# Private Households with Employed Persons              0.000275819
#
# Intercountry Input-Output Table for 1996: BRA import Health and Social Work  \
# Agriculture, Hunting, Forestry and Fishing                          2.99024
# Mining and Quarrying                                                4.80605
# Food, Beverages and Tobacco                                         15.1659
# Textiles and Textile Products                                       22.6738
# Leather, Leather and Footwear                                       0.33149
# Wood and Products of Wood and Cork                                  0.47202
# Pulp, Paper, Paper , Printing and Publishing                        33.9486
# Coke, Refined Petroleum and Nuclear Fuel                            31.2811
# Chemicals and Chemical Products                                     697.028
# Rubber and Plastics                                                 41.7869
# Other Non-Metallic Mineral                                          16.1244
# Basic Metals and Fabricated Metal                                   17.1214
# Machinery, Nec                                                      17.1365
# Electrical and Optical Equipment                                    76.7778
# Transport Equipment                                                 9.95529
# Manufacturing, Nec; Recycling                                       3.73819
# Electricity, Gas and Water Supply                                   19.3205
# Construction                                                        1.71465
# Sale, Maintenance and Repair of Motor Vehicles ...                  1.21104
# Wholesale Trade and Commission Trade, Except of...                  8.39031
# Retail Trade, Except of Motor Vehicles and Moto...                  7.83886
# Hotels and Restaurants                                               506.18
# Inland Transport                                                     11.069
# Water Transport                                                     1.47218
# Air Transport                                                       1.39859
# Other Supporting and Auxiliary Transport Activi...                  5.17708
# Post and Telecommunications                                          32.991
# Financial Intermediation                                            4.22601
# Real Estate Activities                                              52.5333
# Renting of M&Eq and Other Business Activities                       132.627
# Public Admin and Defence; Compulsory Social Sec...                  2.55883
# Education                                                           18.9728
# Health and Social Work                                               2.9153
# Other Community, Social and Personal Services                       17.8154
# Private Households with Employed Persons                        0.000426721
#
# Intercountry Input-Output Table for 1996: BRA import Other Community, Social and Personal Services  \
# Agriculture, Hunting, Forestry and Fishing                                                 2.64998
# Mining and Quarrying                                                                       3.71017
# Food, Beverages and Tobacco                                                                9.66796
# Textiles and Textile Products                                                              12.8298
# Leather, Leather and Footwear                                                             0.571692
# Wood and Products of Wood and Cork                                                        0.356698
# Pulp, Paper, Paper , Printing and Publishing                                               47.8281
# Coke, Refined Petroleum and Nuclear Fuel                                                   93.3286
# Chemicals and Chemical Products                                                             43.929
# Rubber and Plastics                                                                        26.0456
# Other Non-Metallic Mineral                                                                  1.7203
# Basic Metals and Fabricated Metal                                                          6.22062
# Machinery, Nec                                                                             21.8027
# Electrical and Optical Equipment                                                           157.742
# Transport Equipment                                                                        126.867
# Manufacturing, Nec; Recycling                                                              5.54305
# Electricity, Gas and Water Supply                                                          15.2148
# Construction                                                                                0.8313
# Sale, Maintenance and Repair of Motor Vehicles ...                                         1.67845
# Wholesale Trade and Commission Trade, Except of...                                         6.16244
# Retail Trade, Except of Motor Vehicles and Moto...                                         3.53008
# Hotels and Restaurants                                                                     128.451
# Inland Transport                                                                           21.1915
# Water Transport                                                                            2.05261
# Air Transport                                                                              2.75291
# Other Supporting and Auxiliary Transport Activi...                                         9.86256
# Post and Telecommunications                                                                100.873
# Financial Intermediation                                                                   10.5777
# Real Estate Activities                                                                     57.3903
# Renting of M&Eq and Other Business Activities                                              108.423
# Public Admin and Defence; Compulsory Social Sec...                                         1.68036
# Education                                                                                  8.40234
# Health and Social Work                                                                    0.758951
# ...
# Financial Intermediation                                                                 92.1067
# Real Estate Activities                                                                   376.843
# Renting of M&Eq and Other Business Activities                                            133.438
# Public Admin and Defence; Compulsory Social Sec...                                       9.72022
# Education                                                                                 19.073
# Health and Social Work                                                                   6.31584
# Other Community, Social and Personal Services                                            48.4747
# Private Households with Employed Persons                                               0.0121044
#
# Intercountry Input-Output Table for 1996: BRA import Final consumption expenditure by non-profit organisations serving households (NPISH)  \
# Agriculture, Hunting, Forestry and Fishing                                                   0.00575195
# Mining and Quarrying                                                                          0.0014841
# Food, Beverages and Tobacco                                                                 5.52626e-07
# Textiles and Textile Products                                                                 0.0044909
# Leather, Leather and Footwear                                                               0.000772635
# Wood and Products of Wood and Cork                                                           0.00589126
# Pulp, Paper, Paper , Printing and Publishing                                                 0.00578184
# Coke, Refined Petroleum and Nuclear Fuel                                                    2.52963e-05
# Chemicals and Chemical Products                                                              0.00363107
# Rubber and Plastics                                                                          0.00065923
# Other Non-Metallic Mineral                                                                   0.00865496
# Basic Metals and Fabricated Metal                                                              0.282633
# Machinery, Nec                                                                                 0.553661
# Electrical and Optical Equipment                                                               0.384963
# Transport Equipment                                                                           0.0580134
# Manufacturing, Nec; Recycling                                                               9.22466e-06
# Electricity, Gas and Water Supply                                                            0.00018315
# Construction                                                                                5.17008e-05
# Sale, Maintenance and Repair of Motor Vehicles ...                                           0.00012929
# Wholesale Trade and Commission Trade, Except of...                                           0.00285918
# Retail Trade, Except of Motor Vehicles and Moto...                                           0.00447965
# Hotels and Restaurants                                                                        0.0143928
# Inland Transport                                                                               0.188504
# Water Transport                                                                             7.53004e-07
# Air Transport                                                                               2.22833e-06
# Other Supporting and Auxiliary Transport Activi...                                          0.000118569
# Post and Telecommunications                                                                   0.0160611
# Financial Intermediation                                                                    1.24612e-06
# Real Estate Activities                                                                      1.66105e-05
# Renting of M&Eq and Other Business Activities                                                0.00156234
# Public Admin and Defence; Compulsory Social Sec...                                            0.0162839
# Education                                                                                    0.00616957
# Health and Social Work                                                                        0.0492344
# Other Community, Social and Personal Services                                                   5.38056
# Private Households with Employed Persons                                                              0
#
# Intercountry Input-Output Table for 1996: BRA import Final consumption expenditure by government  \
# Agriculture, Hunting, Forestry and Fishing                                           7.46962e-05
# Mining and Quarrying                                                                 1.18536e-06
# Food, Beverages and Tobacco                                                          1.29852e-05
# Textiles and Textile Products                                                         3.3204e-06
# Leather, Leather and Footwear                                                        3.01861e-06
# Wood and Products of Wood and Cork                                                   2.18673e-08
# Pulp, Paper, Paper , Printing and Publishing                                          0.00438463
# Coke, Refined Petroleum and Nuclear Fuel                                                       0
# Chemicals and Chemical Products                                                       4.2484e-05
# Rubber and Plastics                                                                  3.32072e-06
# Other Non-Metallic Mineral                                                            6.5529e-07
# Basic Metals and Fabricated Metal                                                    8.00338e-06
# Machinery, Nec                                                                       2.24674e-05
# Electrical and Optical Equipment                                                     0.000137219
# Transport Equipment                                                                  2.82262e-05
# Manufacturing, Nec; Recycling                                                        4.64395e-07
# Electricity, Gas and Water Supply                                                    3.40959e-05
# Construction                                                                         7.32198e-06
# Sale, Maintenance and Repair of Motor Vehicles ...                                   3.94215e-05
# Wholesale Trade and Commission Trade, Except of...                                   0.000443832
# Retail Trade, Except of Motor Vehicles and Moto...                                   0.000330811
# Hotels and Restaurants                                                               0.000704569
# Inland Transport                                                                     3.80234e-05
# Water Transport                                                                      5.78129e-09
# Air Transport                                                                         1.7715e-06
# Other Supporting and Auxiliary Transport Activi...                                   7.52467e-06
# Post and Telecommunications                                                           0.00219281
# Financial Intermediation                                                                 1.38267
# Real Estate Activities                                                                0.00012099
# Renting of M&Eq and Other Business Activities                                           0.079505
# Public Admin and Defence; Compulsory Social Sec...                                       0.25617
# Education                                                                                 20.012
# Health and Social Work                                                                   2.54113
# Other Community, Social and Personal Services                                         0.00234592
# Private Households with Employed Persons                                                       0
#
# Intercountry Input-Output Table for 1996: BRA import Gross fixed capital formation  \
# Agriculture, Hunting, Forestry and Fishing                                  7.0395
# Mining and Quarrying                                                       3.34475
# Food, Beverages and Tobacco                                                3.01988
# Textiles and Textile Products                                              3.01131
# Leather, Leather and Footwear                                              0.82376
# Wood and Products of Wood and Cork                                         3.92051
# Pulp, Paper, Paper , Printing and Publishing                               44.2649
# Coke, Refined Petroleum and Nuclear Fuel                                   1.38163
# Chemicals and Chemical Products                                            34.1729
# Rubber and Plastics                                                        30.7967
# Other Non-Metallic Mineral                                                 8.90631
# Basic Metals and Fabricated Metal                                           377.72
# Machinery, Nec                                                             4232.88
# Electrical and Optical Equipment                                           5247.89
# Transport Equipment                                                        1719.85
# Manufacturing, Nec; Recycling                                              163.153
# Electricity, Gas and Water Supply                                          13.7806
# Construction                                                               70.0139
# Sale, Maintenance and Repair of Motor Vehicles ...                         2.83176
# Wholesale Trade and Commission Trade, Except of...                         44.5142
# Retail Trade, Except of Motor Vehicles and Moto...                         18.2491
# Hotels and Restaurants                                                   0.0653212
# Inland Transport                                                           3.62508
# Water Transport                                                         0.00486251
# Air Transport                                                              1.00597
# Other Supporting and Auxiliary Transport Activi...                        0.873354
# Post and Telecommunications                                                3.76781
# Financial Intermediation                                                 0.0553058
# Real Estate Activities                                                    0.451402
# Renting of M&Eq and Other Business Activities                              15.6336
# Public Admin and Defence; Compulsory Social Sec...                         1.85022
# Education                                                                  3.87701
# Health and Social Work                                                     3.96452
# Other Community, Social and Personal Services                             0.813216
# Private Households with Employed Persons                               0.000992652
#
# Intercountry Input-Output Table for 1996: BRA import Changes in inventories and valuables
# Agriculture, Hunting, Forestry and Fishing                                              0
# Mining and Quarrying                                                                    0
# Food, Beverages and Tobacco                                                             0
# Textiles and Textile Products                                                           0
# Leather, Leather and Footwear                                                           0
# Wood and Products of Wood and Cork                                                      0
# Pulp, Paper, Paper , Printing and Publishing                                            0
# Coke, Refined Petroleum and Nuclear Fuel                                                0
# Chemicals and Chemical Products                                                         0
# Rubber and Plastics                                                                     0
# Other Non-Metallic Mineral                                                              0
# Basic Metals and Fabricated Metal                                                       0
# Machinery, Nec                                                                          0
# Electrical and Optical Equipment                                                        0
# Transport Equipment                                                                     0
# Manufacturing, Nec; Recycling                                                           0
# Electricity, Gas and Water Supply                                                       0
# Construction                                                                            0
# Sale, Maintenance and Repair of Motor Vehicles ...                                      0
# Wholesale Trade and Commission Trade, Except of...                                      0
# Retail Trade, Except of Motor Vehicles and Moto...                                      0
# Hotels and Restaurants                                                                  0
# Inland Transport                                                                        0
# Water Transport                                                                         0
# Air Transport                                                                           0
# Other Supporting and Auxiliary Transport Activi...                                      0
# Post and Telecommunications                                                             0
# Financial Intermediation                                                                0
# Real Estate Activities                                                                  0
# Renting of M&Eq and Other Business Activities                                           0
# Public Admin and Defence; Compulsory Social Sec...                                      0
# Education                                                                               0
# Health and Social Work                                                                  0
# Other Community, Social and Personal Services                                           0
# Private Households with Employed Persons                                                0
#
# [35 rows x 40 columns]

# %%
# Сохраняем обрезанную версию таблицы отечественного выпуска для выбранной страны, добавляем строки и столбцы с названиями
df = world_df1.iloc[vertical_country_position,horizontal_country_position]
df.columns = world_df1.iloc[columns_names_position,horizontal_country_position]
df.columns.name = world_df1.columns[0] + ": " + country
 
df.index = world_df1.iloc[vertical_country_position, rows_names_position]
df.index.name = ""
df.name = df.columns.name
df
# Out:
# Intercountry Input-Output Table for 1996: BRA      Agriculture, Hunting, Forestry and Fishing  \
#
# Agriculture, Hunting, Forestry and Fishing                                            4876.39
# Mining and Quarrying                                                                  226.866
# Food, Beverages and Tobacco                                                           2918.65
# Textiles and Textile Products                                                         109.613
# Leather, Leather and Footwear                                                         2.12569
# Wood and Products of Wood and Cork                                                     106.63
# Pulp, Paper, Paper , Printing and Publishing                                          14.5803
# Coke, Refined Petroleum and Nuclear Fuel                                              742.613
# Chemicals and Chemical Products                                                       3466.68
# Rubber and Plastics                                                                    221.19
# Other Non-Metallic Mineral                                                              53.82
# Basic Metals and Fabricated Metal                                                     199.819
# Machinery, Nec                                                                        9.96461
# Electrical and Optical Equipment                                                       29.128
# Transport Equipment                                                                   19.2344
# Manufacturing, Nec; Recycling                                                         21.6592
# Electricity, Gas and Water Supply                                                     311.576
# Construction                                                                         0.527529
# Sale, Maintenance and Repair of Motor Vehicles ...                                    438.947
# Wholesale Trade and Commission Trade, Except of...                                      810.1
# Retail Trade, Except of Motor Vehicles and Moto...                                    1433.82
# Hotels and Restaurants                                                                2.91716
# Inland Transport                                                                      280.182
# Water Transport                                                                       24.1316
# Air Transport                                                                         36.2794
# Other Supporting and Auxiliary Transport Activi...                                    125.964
# Post and Telecommunications                                                           97.5399
# Financial Intermediation                                                              648.346
# Real Estate Activities                                                                19.9957
# Renting of M&Eq and Other Business Activities                                         638.901
# Public Admin and Defence; Compulsory Social Sec...                                    34.0185
# Education                                                                            0.698274
# Health and Social Work                                                                10.4978
# Other Community, Social and Personal Services                                         404.014
# Private Households with Employed Persons                                                    0
#
# Intercountry Input-Output Table for 1996: BRA      Mining and Quarrying  \
#
# Agriculture, Hunting, Forestry and Fishing                       6.4032
# Mining and Quarrying                                            482.121
# Food, Beverages and Tobacco                                     19.6743
# Textiles and Textile Products                                   95.4765
# Leather, Leather and Footwear                                   1.46523
# Wood and Products of Wood and Cork                              2.20472
# Pulp, Paper, Paper , Printing and Publishing                    77.0835
# Coke, Refined Petroleum and Nuclear Fuel                        333.852
# Chemicals and Chemical Products                                 210.123
# Rubber and Plastics                                             184.223
# Other Non-Metallic Mineral                                      79.3724
# Basic Metals and Fabricated Metal                               731.344
# Machinery, Nec                                                  523.971
# Electrical and Optical Equipment                                221.418
# Transport Equipment                                             51.4302
# Manufacturing, Nec; Recycling                                   7.39107
# Electricity, Gas and Water Supply                               437.677
# Construction                                                    182.969
# Sale, Maintenance and Repair of Motor Vehicles ...              124.535
# Wholesale Trade and Commission Trade, Except of...              229.836
# Retail Trade, Except of Motor Vehicles and Moto...              406.794
# Hotels and Restaurants                                          105.191
# Inland Transport                                                509.771
# Water Transport                                                 43.9056
# Air Transport                                                   66.0077
# Other Supporting and Auxiliary Transport Activi...              229.182
# Post and Telecommunications                                     177.466
# Financial Intermediation                                        705.783
# Real Estate Activities                                          489.766
# Renting of M&Eq and Other Business Activities                   1162.43
# Public Admin and Defence; Compulsory Social Sec...               53.379
# Education                                                       8.70529
# Health and Social Work                                          9.52298
# Other Community, Social and Personal Services                   735.073
# Private Households with Employed Persons                              0
#
# Intercountry Input-Output Table for 1996: BRA      Food, Beverages and Tobacco  \
#
# Agriculture, Hunting, Forestry and Fishing                             27813.4
# Mining and Quarrying                                                   23.0278
# Food, Beverages and Tobacco                                            11306.6
# Textiles and Textile Products                                          165.284
# Leather, Leather and Footwear                                          6.89892
# Wood and Products of Wood and Cork                                     42.3017
# Pulp, Paper, Paper , Printing and Publishing                           676.547
# Coke, Refined Petroleum and Nuclear Fuel                               511.939
# Chemicals and Chemical Products                                        664.075
# Rubber and Plastics                                                    1351.88
# Other Non-Metallic Mineral                                             227.666
# Basic Metals and Fabricated Metal                                      1129.67
# Machinery, Nec                                                         451.012
# Electrical and Optical Equipment                                       195.311
# Transport Equipment                                                    91.6205
# Manufacturing, Nec; Recycling                                          45.1339
# Electricity, Gas and Water Supply                                       779.18
# Construction                                                           57.7004
# Sale, Maintenance and Repair of Motor Vehicles ...                     1060.26
# Wholesale Trade and Commission Trade, Except of...                     1956.76
# Retail Trade, Except of Motor Vehicles and Moto...                     3463.32
# Hotels and Restaurants                                                 55.0795
# Inland Transport                                                       968.988
# Water Transport                                                        83.4572
# Air Transport                                                           125.47
# Other Supporting and Auxiliary Transport Activi...                     435.637
# Post and Telecommunications                                            337.334
# Financial Intermediation                                               2294.37
# Real Estate Activities                                                 139.363
# Renting of M&Eq and Other Business Activities                          2209.59
# Public Admin and Defence; Compulsory Social Sec...                     124.383
# Education                                                              5.67642
# Health and Social Work                                                 24.0907
# Other Community, Social and Personal Services                          1397.25
# Private Households with Employed Persons                                     0
#
# Intercountry Input-Output Table for 1996: BRA      Textiles and Textile Products  \
#
# Agriculture, Hunting, Forestry and Fishing                               527.716
# Mining and Quarrying                                                     3.58297
# Food, Beverages and Tobacco                                                37.35
# Textiles and Textile Products                                            9616.27
# Leather, Leather and Footwear                                            21.9427
# Wood and Products of Wood and Cork                                       1.17628
# Pulp, Paper, Paper , Printing and Publishing                             209.069
# Coke, Refined Petroleum and Nuclear Fuel                                 178.621
# Chemicals and Chemical Products                                          771.885
# Rubber and Plastics                                                      190.501
# Other Non-Metallic Mineral                                                 1.091
# Basic Metals and Fabricated Metal                                        10.8559
# Machinery, Nec                                                           194.514
# Electrical and Optical Equipment                                         21.8863
# Transport Equipment                                                      30.1442
# Manufacturing, Nec; Recycling                                            107.848
# Electricity, Gas and Water Supply                                        443.568
# Construction                                                              16.844
# Sale, Maintenance and Repair of Motor Vehicles ...                       312.595
# Wholesale Trade and Commission Trade, Except of...                        576.91
# Retail Trade, Except of Motor Vehicles and Moto...                       1021.09
# Hotels and Restaurants                                                   1.90659
# Inland Transport                                                         186.207
# Water Transport                                                          16.0377
# Air Transport                                                            24.1111
# Other Supporting and Auxiliary Transport Activi...                        83.715
# Post and Telecommunications                                              64.8244
# Financial Intermediation                                                 678.536
# Real Estate Activities                                                   72.3282
# Renting of M&Eq and Other Business Activities                            424.609
# Public Admin and Defence; Compulsory Social Sec...                       26.2373
# Education                                                                1.59578
# Health and Social Work                                                    7.2744
# Other Community, Social and Personal Services                            268.505
# Private Households with Employed Persons                                       0
#
# Intercountry Input-Output Table for 1996: BRA      Leather, Leather and Footwear  \
#
# Agriculture, Hunting, Forestry and Fishing                               55.9265
# Mining and Quarrying                                                     7.96229
# Food, Beverages and Tobacco                                               878.37
# Textiles and Textile Products                                            273.999
# Leather, Leather and Footwear                                            2201.23
# Wood and Products of Wood and Cork                                       8.13612
# Pulp, Paper, Paper , Printing and Publishing                             201.108
# Coke, Refined Petroleum and Nuclear Fuel                                 33.5494
# Chemicals and Chemical Products                                          506.622
# Rubber and Plastics                                                      245.259
# Other Non-Metallic Mineral                                               22.2033
# Basic Metals and Fabricated Metal                                        103.773
# Machinery, Nec                                                           49.2977
# Electrical and Optical Equipment                                         34.0941
# Transport Equipment                                                      7.59253
# Manufacturing, Nec; Recycling                                            30.5668
# Electricity, Gas and Water Supply                                        100.134
# Construction                                                             4.90897
# Sale, Maintenance and Repair of Motor Vehicles ...                       150.996
# Wholesale Trade and Commission Trade, Except of...                       278.671
# Retail Trade, Except of Motor Vehicles and Moto...                       493.227
# Hotels and Restaurants                                                   1.00138
# Inland Transport                                                         109.923
# Water Transport                                                          9.46744
# Air Transport                                                            14.2333
# Other Supporting and Auxiliary Transport Activi...                        49.419
# Post and Telecommunications                                              38.2674
# Financial Intermediation                                                  239.75
# Real Estate Activities                                                    16.173
# Renting of M&Eq and Other Business Activities                            250.657
# Public Admin and Defence; Compulsory Social Sec...                        12.007
# Education                                                               0.544307
# Health and Social Work                                                   3.50843
# Other Community, Social and Personal Services                            158.505
# Private Households with Employed Persons                                       0
#
# Intercountry Input-Output Table for 1996: BRA      Wood and Products of Wood and Cork  \
#
# Agriculture, Hunting, Forestry and Fishing                                    564.257
# Mining and Quarrying                                                          1.09236
# Food, Beverages and Tobacco                                                   6.96868
# Textiles and Textile Products                                                0.903602
# Leather, Leather and Footwear                                               0.0308116
# Wood and Products of Wood and Cork                                            1324.94
# Pulp, Paper, Paper , Printing and Publishing                                  68.3789
# Coke, Refined Petroleum and Nuclear Fuel                                      75.5127
# Chemicals and Chemical Products                                               91.9735
# Rubber and Plastics                                                           67.8715
# Other Non-Metallic Mineral                                                    3.31302
# Basic Metals and Fabricated Metal                                             97.8419
# Machinery, Nec                                                                61.4083
# Electrical and Optical Equipment                                              12.7163
# Transport Equipment                                                           7.87933
# Manufacturing, Nec; Recycling                                                 19.3815
# Electricity, Gas and Water Supply                                             111.666
# Construction                                                                  5.98904
# Sale, Maintenance and Repair of Motor Vehicles ...                            34.2781
# Wholesale Trade and Commission Trade, Except of...                            63.2619
# Retail Trade, Except of Motor Vehicles and Moto...                            111.969
# Hotels and Restaurants                                                        9.61629
# Inland Transport                                                              46.0152
# Water Transport                                                                3.9632
# Air Transport                                                                 5.95828
# Other Supporting and Auxiliary Transport Activi...                            20.6875
# Post and Telecommunications                                                   16.0193
# Financial Intermediation                                                      157.283
# Real Estate Activities                                                        9.25475
# Renting of M&Eq and Other Business Activities                                 104.929
# Public Admin and Defence; Compulsory Social Sec...                            6.25251
# Education                                                                    0.236723
# Health and Social Work                                                       0.865714
# Other Community, Social and Personal Services                                 66.3524
# Private Households with Employed Persons                                            0
#
# Intercountry Input-Output Table for 1996: BRA      Pulp, Paper, Paper , Printing and Publishing  \
#
# Agriculture, Hunting, Forestry and Fishing                                              703.934
# Mining and Quarrying                                                                    27.2798
# Food, Beverages and Tobacco                                                             63.4635
# Textiles and Textile Products                                                           104.664
# Leather, Leather and Footwear                                                           8.70112
# Wood and Products of Wood and Cork                                                      104.998
# Pulp, Paper, Paper , Printing and Publishing                                            4213.95
# Coke, Refined Petroleum and Nuclear Fuel                                                 102.38
# Chemicals and Chemical Products                                                         917.366
# Rubber and Plastics                                                                     525.056
# Other Non-Metallic Mineral                                                               20.235
# Basic Metals and Fabricated Metal                                                       301.066
# Machinery, Nec                                                                          154.918
# Electrical and Optical Equipment                                                        67.6237
# Transport Equipment                                                                     19.2038
# Manufacturing, Nec; Recycling                                                           42.6696
# Electricity, Gas and Water Supply                                                       460.562
# Construction                                                                            22.6915
# Sale, Maintenance and Repair of Motor Vehicles ...                                       247.54
# Wholesale Trade and Commission Trade, Except of...                                      456.848
# Retail Trade, Except of Motor Vehicles and Moto...                                      808.589
# Hotels and Restaurants                                                                  21.4954
# Inland Transport                                                                        356.543
# Water Transport                                                                         30.7084
# Air Transport                                                                            46.167
# Other Supporting and Auxiliary Transport Activi...                                      160.294
# Post and Telecommunications                                                             124.123
# Financial Intermediation                                                                914.392
# Real Estate Activities                                                                  92.4179
# Renting of M&Eq and Other Business Activities                                           813.027
# Public Admin and Defence; Compulsory Social Sec...                                      72.4726
# Education                                                                               3.30225
# Health and Social Work                                                                   6.6927
# Other Community, Social and Personal Services                                           514.124
# Private Households with Employed Persons                                                      0
#
# Intercountry Input-Output Table for 1996: BRA      Coke, Refined Petroleum and Nuclear Fuel  \
#
# Agriculture, Hunting, Forestry and Fishing                                           1584.9
# Mining and Quarrying                                                                8590.76
# Food, Beverages and Tobacco                                                         197.476
# Textiles and Textile Products                                                       19.0516
# Leather, Leather and Footwear                                                      0.175678
# Wood and Products of Wood and Cork                                                 0.656038
# Pulp, Paper, Paper , Printing and Publishing                                        16.3945
# Coke, Refined Petroleum and Nuclear Fuel                                            4026.25
# Chemicals and Chemical Products                                                     138.653
# Rubber and Plastics                                                                 69.5091
# Other Non-Metallic Mineral                                                          15.8039
# Basic Metals and Fabricated Metal                                                   124.547
# Machinery, Nec                                                                      122.208
# Electrical and Optical Equipment                                                    70.6035
# Transport Equipment                                                                 15.3361
# Manufacturing, Nec; Recycling                                                       2.29796
# Electricity, Gas and Water Supply                                                   190.703
# Construction                                                                        21.7511
# Sale, Maintenance and Repair of Motor Vehicles ...                                  364.925
# Wholesale Trade and Commission Trade, Except of...                                  673.488
# Retail Trade, Except of Motor Vehicles and Moto...                                  1192.03
# Hotels and Restaurants                                                              21.0661
# Inland Transport                                                                    263.825
# Water Transport                                                                     22.7228
# Air Transport                                                                       34.1615
# Other Supporting and Auxiliary Transport Activi...                                  118.611
# Post and Telecommunications                                                         91.8456
# Financial Intermediation                                                            314.744
# Real Estate Activities                                                              213.349
# Renting of M&Eq and Other Business Activities                                       601.602
# Public Admin and Defence; Compulsory Social Sec...                                  27.7401
# Education                                                                            4.5204
# Health and Social Work                                                              10.5019
# Other Community, Social and Personal Services                                       380.428
# Private Households with Employed Persons                                                  0
#
# Intercountry Input-Output Table for 1996: BRA      Chemicals and Chemical Products  \
#
# Agriculture, Hunting, Forestry and Fishing                                 143.588
# Mining and Quarrying                                                       571.423
# Food, Beverages and Tobacco                                                504.365
# Textiles and Textile Products                                              104.053
# Leather, Leather and Footwear                                              2.38981
# Wood and Products of Wood and Cork                                          131.12
# Pulp, Paper, Paper , Printing and Publishing                               456.105
# Coke, Refined Petroleum and Nuclear Fuel                                   2057.53
# Chemicals and Chemical Products                                            5937.29
# Rubber and Plastics                                                        465.255
# Other Non-Metallic Mineral                                                 265.244
# Basic Metals and Fabricated Metal                                          591.278
# Machinery, Nec                                                             308.278
# Electrical and Optical Equipment                                           129.247
# Transport Equipment                                                        38.9046
# Manufacturing, Nec; Recycling                                              16.2202
# Electricity, Gas and Water Supply                                          746.015
# Construction                                                               54.7499
# Sale, Maintenance and Repair of Motor Vehicles ...                         636.223
# Wholesale Trade and Commission Trade, Except of...                         1174.18
# Retail Trade, Except of Motor Vehicles and Moto...                         2078.22
# Hotels and Restaurants                                                      23.412
# Inland Transport                                                           626.048
# Water Transport                                                            53.9204
# Air Transport                                                               81.064
# Other Supporting and Auxiliary Transport Activi...                         281.459
# Post and Telecommunications                                                217.946
# Financial Intermediation                                                   1718.63
# Real Estate Activities                                                     86.8814
# Renting of M&Eq and Other Business Activities                              1427.58
# Public Admin and Defence; Compulsory Social Sec...                         88.4047
# Education                                                                  7.05541
# Health and Social Work                                                     16.2558
# Other Community, Social and Personal Services                              902.741
# Private Households with Employed Persons                                         0
#
# Intercountry Input-Output Table for 1996: BRA      Rubber and Plastics  \
#
# Agriculture, Hunting, Forestry and Fishing                     141.743
# Mining and Quarrying                                           12.2075
# Food, Beverages and Tobacco                                    26.6007
# Textiles and Textile Products                                  189.796
# Leather, Leather and Footwear                                 0.919975
# Wood and Products of Wood and Cork                             9.62356
# Pulp, Paper, Paper , Printing and Publishing                   360.957
# Coke, Refined Petroleum and Nuclear Fuel                       181.587
# Chemicals and Chemical Products                                3074.49
# Rubber and Plastics                                            922.234
# Other Non-Metallic Mineral                                     8.73407
# Basic Metals and Fabricated Metal                              321.121
# Machinery, Nec                                                 165.199
# Electrical and Optical Equipment                               123.561
# Transport Equipment                                            47.2122
# Manufacturing, Nec; Recycling                                  33.8435
# Electricity, Gas and Water Supply                              323.415
# Construction                                                   16.4654
# Sale, Maintenance and Repair of Motor Vehicles ...             256.538
# Wholesale Trade and Commission Trade, Except of...             473.453
# Retail Trade, Except of Motor Vehicles and Moto...             837.978
# Hotels and Restaurants                                         16.8472
# Inland Transport                                               203.431
# Water Transport                                                17.5212
# Air Transport                                                  26.3413
# Other Supporting and Auxiliary Transport Activi...             91.4586
# Post and Telecommunications                                    70.8206
# Financial Intermediation                                       518.141
# Real Estate Activities                                         50.2218
# Renting of M&Eq and Other Business Activities                  463.885
# Public Admin and Defence; Compulsory Social Sec...             30.9168
# Education                                                      1.39262
# Health and Social Work                                         7.03639
# Other Community, Social and Personal Services                  293.341
# Private Households with Employed Persons                             0
#
# Intercountry Input-Output Table for 1996: BRA                      ...                   \
#                                                                    ...
# Agriculture, Hunting, Forestry and Fishing                         ...
# Mining and Quarrying                                               ...
# Food, Beverages and Tobacco                                        ...
# Textiles and Textile Products                                      ...
# Leather, Leather and Footwear                                      ...
# Wood and Products of Wood and Cork                                 ...
# Pulp, Paper, Paper , Printing and Publishing                       ...
# Coke, Refined Petroleum and Nuclear Fuel                           ...
# Chemicals and Chemical Products                                    ...
# Rubber and Plastics                                                ...
# Other Non-Metallic Mineral                                         ...
# Basic Metals and Fabricated Metal                                  ...
# Machinery, Nec                                                     ...
# Electrical and Optical Equipment                                   ...
# Transport Equipment                                                ...
# Manufacturing, Nec; Recycling                                      ...
# Electricity, Gas and Water Supply                                  ...
# Construction                                                       ...
# Sale, Maintenance and Repair of Motor Vehicles ...                 ...
# Wholesale Trade and Commission Trade, Except of...                 ...
# Retail Trade, Except of Motor Vehicles and Moto...                 ...
# Hotels and Restaurants                                             ...
# Inland Transport                                                   ...
# Water Transport                                                    ...
# Air Transport                                                      ...
# Other Supporting and Auxiliary Transport Activi...                 ...
# Post and Telecommunications                                        ...
# Financial Intermediation                                           ...
# Real Estate Activities                                             ...
# Renting of M&Eq and Other Business Activities                      ...
# Public Admin and Defence; Compulsory Social Sec...                 ...
# Education                                                          ...
# Health and Social Work                                             ...
# Other Community, Social and Personal Services                      ...
# Private Households with Employed Persons                           ...
#
# Intercountry Input-Output Table for 1996: BRA      Public Admin and Defence; Compulsory Social Security  \
#
# Agriculture, Hunting, Forestry and Fishing                                                    110.748
# Mining and Quarrying                                                                          11.7032
# Food, Beverages and Tobacco                                                                   799.193
# Textiles and Textile Products                                                                 52.2738
# Leather, Leather and Footwear                                                                  1.1571
# Wood and Products of Wood and Cork                                                            16.5162
# Pulp, Paper, Paper , Printing and Publishing                                                  434.459
# Coke, Refined Petroleum and Nuclear Fuel                                                      841.729
# Chemicals and Chemical Products                                                               383.052
# Rubber and Plastics                                                                           20.7464
# Other Non-Metallic Mineral                                                                    34.6851
# Basic Metals and Fabricated Metal                                                             319.707
# Machinery, Nec                                                                                65.5762
# Electrical and Optical Equipment                                                              211.973
# Transport Equipment                                                                           112.126
# Manufacturing, Nec; Recycling                                                                  29.628
# Electricity, Gas and Water Supply                                                             1290.27
# Construction                                                                                  1458.35
# Sale, Maintenance and Repair of Motor Vehicles ...                                            193.522
# Wholesale Trade and Commission Trade, Except of...                                            357.155
# Retail Trade, Except of Motor Vehicles and Moto...                                            632.138
# Hotels and Restaurants                                                                        604.798
# Inland Transport                                                                              1704.15
# Water Transport                                                                               146.775
# Air Transport                                                                                 220.662
# Other Supporting and Auxiliary Transport Activi...                                            766.152
# Post and Telecommunications                                                                   593.266
# Financial Intermediation                                                                      10287.4
# Real Estate Activities                                                                        648.983
# Renting of M&Eq and Other Business Activities                                                 3885.98
# Public Admin and Defence; Compulsory Social Sec...                                            151.195
# Education                                                                                     74.3488
# Health and Social Work                                                                         14.549
# Other Community, Social and Personal Services                                                 2457.33
# Private Households with Employed Persons                                                            0
#
# Intercountry Input-Output Table for 1996: BRA      Education  \
#
# Agriculture, Hunting, Forestry and Fishing           61.1859
# Mining and Quarrying                                 2.26915
# Food, Beverages and Tobacco                          368.159
# Textiles and Textile Products                        6.14243
# Leather, Leather and Footwear                       0.638475
# Wood and Products of Wood and Cork                   2.50944
# Pulp, Paper, Paper , Printing and Publishing         279.008
# Coke, Refined Petroleum and Nuclear Fuel             135.583
# Chemicals and Chemical Products                      152.362
# Rubber and Plastics                                  4.04225
# Other Non-Metallic Mineral                           21.9977
# Basic Metals and Fabricated Metal                    16.0172
# Machinery, Nec                                       125.498
# Electrical and Optical Equipment                     14.5083
# Transport Equipment                                  6.32861
# Manufacturing, Nec; Recycling                        464.071
# Electricity, Gas and Water Supply                    571.923
# Construction                                         1368.02
# Sale, Maintenance and Repair of Motor Vehicles ...   105.601
# Wholesale Trade and Commission Trade, Except of...   194.892
# Retail Trade, Except of Motor Vehicles and Moto...   344.945
# Hotels and Restaurants                               173.698
# Inland Transport                                     634.282
# Water Transport                                      54.6296
# Air Transport                                        82.1301
# Other Supporting and Auxiliary Transport Activi...    285.16
# Post and Telecommunications                          220.813
# Financial Intermediation                             303.679
# Real Estate Activities                                 412.8
# Renting of M&Eq and Other Business Activities        1446.36
# Public Admin and Defence; Compulsory Social Sec...   71.8793
# Education                                            38.8324
# Health and Social Work                               8.00772
# Other Community, Social and Personal Services        914.615
# Private Households with Employed Persons                   0
#
# Intercountry Input-Output Table for 1996: BRA      Health and Social Work  \
#
# Agriculture, Hunting, Forestry and Fishing                        63.2739
# Mining and Quarrying                                              11.4388
# Food, Beverages and Tobacco                                       315.379
# Textiles and Textile Products                                     425.247
# Leather, Leather and Footwear                                       1.905
# Wood and Products of Wood and Cork                                3.45764
# Pulp, Paper, Paper , Printing and Publishing                      462.525
# Coke, Refined Petroleum and Nuclear Fuel                          174.593
# Chemicals and Chemical Products                                   2267.14
# Rubber and Plastics                                               569.138
# Other Non-Metallic Mineral                                        354.568
# Basic Metals and Fabricated Metal                                  219.05
# Machinery, Nec                                                    39.3812
# Electrical and Optical Equipment                                  226.152
# Transport Equipment                                               16.1988
# Manufacturing, Nec; Recycling                                     13.6379
# Electricity, Gas and Water Supply                                 589.008
# Construction                                                      652.027
# Sale, Maintenance and Repair of Motor Vehicles ...                298.902
# Wholesale Trade and Commission Trade, Except of...                551.639
# Retail Trade, Except of Motor Vehicles and Moto...                976.362
# Hotels and Restaurants                                             677.41
# Inland Transport                                                  858.625
# Water Transport                                                   73.9518
# Air Transport                                                     111.179
# Other Supporting and Auxiliary Transport Activi...                 386.02
# Post and Telecommunications                                       298.913
# Financial Intermediation                                          357.715
# Real Estate Activities                                            555.628
# Renting of M&Eq and Other Business Activities                     1957.93
# Public Admin and Defence; Compulsory Social Sec...                112.941
# Education                                                         58.3368
# Health and Social Work                                              15.13
# Other Community, Social and Personal Services                     1238.11
# Private Households with Employed Persons                                0
#
# Intercountry Input-Output Table for 1996: BRA      Other Community, Social and Personal Services  \
#
# Agriculture, Hunting, Forestry and Fishing                                               54.0116
# Mining and Quarrying                                                                     8.62087
# Food, Beverages and Tobacco                                                              262.408
# Textiles and Textile Products                                                             305.81
# Leather, Leather and Footwear                                                            9.06045
# Wood and Products of Wood and Cork                                                       5.52959
# Pulp, Paper, Paper , Printing and Publishing                                             1169.88
# Coke, Refined Petroleum and Nuclear Fuel                                                 992.279
# Chemicals and Chemical Products                                                          132.911
# Rubber and Plastics                                                                      357.804
# Other Non-Metallic Mineral                                                                31.226
# Basic Metals and Fabricated Metal                                                        49.9237
# Machinery, Nec                                                                            56.992
# Electrical and Optical Equipment                                                         438.958
# Transport Equipment                                                                      593.156
# Manufacturing, Nec; Recycling                                                            143.078
# Electricity, Gas and Water Supply                                                        454.482
# Construction                                                                             156.378
# Sale, Maintenance and Repair of Motor Vehicles ...                                       320.638
# Wholesale Trade and Commission Trade, Except of...                                       591.754
# Retail Trade, Except of Motor Vehicles and Moto...                                       1047.36
# Hotels and Restaurants                                                                   173.471
# Inland Transport                                                                          1211.8
# Water Transport                                                                           104.37
# Air Transport                                                                             156.91
# Other Supporting and Auxiliary Transport Activi...                                       544.799
# Post and Telecommunications                                                              421.863
# Financial Intermediation                                                                 1018.61
# Real Estate Activities                                                                   608.538
# Renting of M&Eq and Other Business Activities                                            2763.27
# Public Admin and Defence; Compulsory Social Sec...                                       135.422
# Education                                                                                 13.141
# ...
# Real Estate Activities                                                                 53657.4
# Renting of M&Eq and Other Business Activities                                          28068.6
# Public Admin and Defence; Compulsory Social Sec...                                     1220.23
# Education                                                                              11611.1
# Health and Social Work                                                                 16201.1
# Other Community, Social and Personal Services                                          17749.4
# Private Households with Employed Persons                                                     0
#
# Intercountry Input-Output Table for 1996: BRA      Final consumption expenditure by non-profit organisations serving households (NPISH)  \
#
# Agriculture, Hunting, Forestry and Fishing                                                          0
# Mining and Quarrying                                                                                0
# Food, Beverages and Tobacco                                                                         0
# Textiles and Textile Products                                                                       0
# Leather, Leather and Footwear                                                                       0
# Wood and Products of Wood and Cork                                                                  0
# Pulp, Paper, Paper , Printing and Publishing                                                        0
# Coke, Refined Petroleum and Nuclear Fuel                                                            0
# Chemicals and Chemical Products                                                                     0
# Rubber and Plastics                                                                                 0
# Other Non-Metallic Mineral                                                                          0
# Basic Metals and Fabricated Metal                                                                   0
# Machinery, Nec                                                                                      0
# Electrical and Optical Equipment                                                                    0
# Transport Equipment                                                                                 0
# Manufacturing, Nec; Recycling                                                                       0
# Electricity, Gas and Water Supply                                                                   0
# Construction                                                                                        0
# Sale, Maintenance and Repair of Motor Vehicles ...                                                  0
# Wholesale Trade and Commission Trade, Except of...                                                  0
# Retail Trade, Except of Motor Vehicles and Moto...                                                  0
# Hotels and Restaurants                                                                              0
# Inland Transport                                                                              1790.36
# Water Transport                                                                               154.201
# Air Transport                                                                                 231.825
# Other Supporting and Auxiliary Transport Activi...                                             804.91
# Post and Telecommunications                                                                   623.279
# Financial Intermediation                                                                            0
# Real Estate Activities                                                                              0
# Renting of M&Eq and Other Business Activities                                                 4082.57
# Public Admin and Defence; Compulsory Social Sec...                                            4.75675
# Education                                                                                    0.482379
# Health and Social Work                                                                        639.865
# Other Community, Social and Personal Services                                                 2581.64
# Private Households with Employed Persons                                                            0
#
# Intercountry Input-Output Table for 1996: BRA      Final consumption expenditure by government  \
#
# Agriculture, Hunting, Forestry and Fishing                                                   0
# Mining and Quarrying                                                                         0
# Food, Beverages and Tobacco                                                                  0
# Textiles and Textile Products                                                                0
# Leather, Leather and Footwear                                                                0
# Wood and Products of Wood and Cork                                                           0
# Pulp, Paper, Paper , Printing and Publishing                                                 0
# Coke, Refined Petroleum and Nuclear Fuel                                                     0
# Chemicals and Chemical Products                                                              0
# Rubber and Plastics                                                                          0
# Other Non-Metallic Mineral                                                                   0
# Basic Metals and Fabricated Metal                                                            0
# Machinery, Nec                                                                               0
# Electrical and Optical Equipment                                                             0
# Transport Equipment                                                                          0
# Manufacturing, Nec; Recycling                                                                0
# Electricity, Gas and Water Supply                                                            0
# Construction                                                                                 0
# Sale, Maintenance and Repair of Motor Vehicles ...                                           0
# Wholesale Trade and Commission Trade, Except of...                                           0
# Retail Trade, Except of Motor Vehicles and Moto...                                           0
# Hotels and Restaurants                                                                       0
# Inland Transport                                                                      0.892789
# Water Transport                                                                      0.0768861
# Air Transport                                                                         0.115607
# Other Supporting and Auxiliary Transport Activi...                                    0.401376
# Post and Telecommunications                                                           0.310808
# Financial Intermediation                                                               676.359
# Real Estate Activities                                                                       0
# Renting of M&Eq and Other Business Activities                                          2.03581
# Public Admin and Defence; Compulsory Social Sec...                                     94618.7
# Education                                                                              34464.1
# Health and Social Work                                                                 28032.2
# Other Community, Social and Personal Services                                          1.28736
# Private Households with Employed Persons                                                     0
#
# Intercountry Input-Output Table for 1996: BRA      Gross fixed capital formation  \
#
# Agriculture, Hunting, Forestry and Fishing                               3961.24
# Mining and Quarrying                                                     10.3885
# Food, Beverages and Tobacco                                              93.4397
# Textiles and Textile Products                                            51.9872
# Leather, Leather and Footwear                                            5.90912
# Wood and Products of Wood and Cork                                       76.7151
# Pulp, Paper, Paper , Printing and Publishing                             19.1242
# Coke, Refined Petroleum and Nuclear Fuel                                 1.39375
# Chemicals and Chemical Products                                          49.7238
# Rubber and Plastics                                                      89.5532
# Other Non-Metallic Mineral                                               26.1058
# Basic Metals and Fabricated Metal                                        3197.57
# Machinery, Nec                                                           8941.28
# Electrical and Optical Equipment                                         12222.5
# Transport Equipment                                                      8382.21
# Manufacturing, Nec; Recycling                                            3302.66
# Electricity, Gas and Water Supply                                        3.40804
# Construction                                                             65214.8
# Sale, Maintenance and Repair of Motor Vehicles ...                       1716.29
# Wholesale Trade and Commission Trade, Except of...                        3167.5
# Retail Trade, Except of Motor Vehicles and Moto...                       5606.25
# Hotels and Restaurants                                                   11.5339
# Inland Transport                                                         544.073
# Water Transport                                                            46.86
# Air Transport                                                            70.4494
# Other Supporting and Auxiliary Transport Activi...                       244.604
# Post and Telecommunications                                              189.408
# Financial Intermediation                                                  22.957
# Real Estate Activities                                                   1127.13
# Renting of M&Eq and Other Business Activities                            1240.65
# Public Admin and Defence; Compulsory Social Sec...                       51.1865
# Education                                                                 17.249
# Health and Social Work                                                   51.7703
# Other Community, Social and Personal Services                            784.536
# Private Households with Employed Persons                                       0
#
# Intercountry Input-Output Table for 1996: BRA      Changes in inventories and valuables
#
# Agriculture, Hunting, Forestry and Fishing                                      535.967
# Mining and Quarrying                                                            303.511
# Food, Beverages and Tobacco                                                     283.542
# Textiles and Textile Products                                                  -148.673
# Leather, Leather and Footwear                                                   373.552
# Wood and Products of Wood and Cork                                             -30.0125
# Pulp, Paper, Paper , Printing and Publishing                                    543.311
# Coke, Refined Petroleum and Nuclear Fuel                                       -159.185
# Chemicals and Chemical Products                                                -216.651
# Rubber and Plastics                                                             16.4772
# Other Non-Metallic Mineral                                                      333.584
# Basic Metals and Fabricated Metal                                              -158.244
# Machinery, Nec                                                                 -123.857
# Electrical and Optical Equipment                                               -224.148
# Transport Equipment                                                             -458.05
# Manufacturing, Nec; Recycling                                                  -59.7968
# Electricity, Gas and Water Supply                                                     0
# Construction                                                                          0
# Sale, Maintenance and Repair of Motor Vehicles ...                              26.4971
# Wholesale Trade and Commission Trade, Except of...                              48.9018
# Retail Trade, Except of Motor Vehicles and Moto...                              86.5527
# Hotels and Restaurants                                                         0.180807
# Inland Transport                                                                7.33237
# Water Transport                                                                0.631524
# Air Transport                                                                  0.949433
# Other Supporting and Auxiliary Transport Activi...                              3.29648
# Post and Telecommunications                                                     2.55262
# Financial Intermediation                                                              0
# Real Estate Activities                                                        0.0243214
# Renting of M&Eq and Other Business Activities                                     16.72
# Public Admin and Defence; Compulsory Social Sec...                               17.985
# Education                                                                     0.0849896
# Health and Social Work                                                         0.483839
# Other Community, Social and Personal Services                                    10.573
# Private Households with Employed Persons                                              0
#
# [35 rows x 40 columns]

# %%
# Суммарный экспорт в оставльные страны 
export_df = world_df1.iloc[vertical_country_position,-1].values
sum_domestic = df.sum(axis=1).values
export = export_df - sum_domestic
df['Exports'] = export
df['Total output'] = sum_domestic

# %%
df
# Out:
# Intercountry Input-Output Table for 1996: BRA      Agriculture, Hunting, Forestry and Fishing  \
#
# Agriculture, Hunting, Forestry and Fishing                                            4876.39
# Mining and Quarrying                                                                  226.866
# Food, Beverages and Tobacco                                                           2918.65
# Textiles and Textile Products                                                         109.613
# Leather, Leather and Footwear                                                         2.12569
# Wood and Products of Wood and Cork                                                     106.63
# Pulp, Paper, Paper , Printing and Publishing                                          14.5803
# Coke, Refined Petroleum and Nuclear Fuel                                              742.613
# Chemicals and Chemical Products                                                       3466.68
# Rubber and Plastics                                                                    221.19
# Other Non-Metallic Mineral                                                              53.82
# Basic Metals and Fabricated Metal                                                     199.819
# Machinery, Nec                                                                        9.96461
# Electrical and Optical Equipment                                                       29.128
# Transport Equipment                                                                   19.2344
# Manufacturing, Nec; Recycling                                                         21.6592
# Electricity, Gas and Water Supply                                                     311.576
# Construction                                                                         0.527529
# Sale, Maintenance and Repair of Motor Vehicles ...                                    438.947
# Wholesale Trade and Commission Trade, Except of...                                      810.1
# Retail Trade, Except of Motor Vehicles and Moto...                                    1433.82
# Hotels and Restaurants                                                                2.91716
# Inland Transport                                                                      280.182
# Water Transport                                                                       24.1316
# Air Transport                                                                         36.2794
# Other Supporting and Auxiliary Transport Activi...                                    125.964
# Post and Telecommunications                                                           97.5399
# Financial Intermediation                                                              648.346
# Real Estate Activities                                                                19.9957
# Renting of M&Eq and Other Business Activities                                         638.901
# Public Admin and Defence; Compulsory Social Sec...                                    34.0185
# Education                                                                            0.698274
# Health and Social Work                                                                10.4978
# Other Community, Social and Personal Services                                         404.014
# Private Households with Employed Persons                                                    0
#
# Intercountry Input-Output Table for 1996: BRA      Mining and Quarrying  \
#
# Agriculture, Hunting, Forestry and Fishing                       6.4032
# Mining and Quarrying                                            482.121
# Food, Beverages and Tobacco                                     19.6743
# Textiles and Textile Products                                   95.4765
# Leather, Leather and Footwear                                   1.46523
# Wood and Products of Wood and Cork                              2.20472
# Pulp, Paper, Paper , Printing and Publishing                    77.0835
# Coke, Refined Petroleum and Nuclear Fuel                        333.852
# Chemicals and Chemical Products                                 210.123
# Rubber and Plastics                                             184.223
# Other Non-Metallic Mineral                                      79.3724
# Basic Metals and Fabricated Metal                               731.344
# Machinery, Nec                                                  523.971
# Electrical and Optical Equipment                                221.418
# Transport Equipment                                             51.4302
# Manufacturing, Nec; Recycling                                   7.39107
# Electricity, Gas and Water Supply                               437.677
# Construction                                                    182.969
# Sale, Maintenance and Repair of Motor Vehicles ...              124.535
# Wholesale Trade and Commission Trade, Except of...              229.836
# Retail Trade, Except of Motor Vehicles and Moto...              406.794
# Hotels and Restaurants                                          105.191
# Inland Transport                                                509.771
# Water Transport                                                 43.9056
# Air Transport                                                   66.0077
# Other Supporting and Auxiliary Transport Activi...              229.182
# Post and Telecommunications                                     177.466
# Financial Intermediation                                        705.783
# Real Estate Activities                                          489.766
# Renting of M&Eq and Other Business Activities                   1162.43
# Public Admin and Defence; Compulsory Social Sec...               53.379
# Education                                                       8.70529
# Health and Social Work                                          9.52298
# Other Community, Social and Personal Services                   735.073
# Private Households with Employed Persons                              0
#
# Intercountry Input-Output Table for 1996: BRA      Food, Beverages and Tobacco  \
#
# Agriculture, Hunting, Forestry and Fishing                             27813.4
# Mining and Quarrying                                                   23.0278
# Food, Beverages and Tobacco                                            11306.6
# Textiles and Textile Products                                          165.284
# Leather, Leather and Footwear                                          6.89892
# Wood and Products of Wood and Cork                                     42.3017
# Pulp, Paper, Paper , Printing and Publishing                           676.547
# Coke, Refined Petroleum and Nuclear Fuel                               511.939
# Chemicals and Chemical Products                                        664.075
# Rubber and Plastics                                                    1351.88
# Other Non-Metallic Mineral                                             227.666
# Basic Metals and Fabricated Metal                                      1129.67
# Machinery, Nec                                                         451.012
# Electrical and Optical Equipment                                       195.311
# Transport Equipment                                                    91.6205
# Manufacturing, Nec; Recycling                                          45.1339
# Electricity, Gas and Water Supply                                       779.18
# Construction                                                           57.7004
# Sale, Maintenance and Repair of Motor Vehicles ...                     1060.26
# Wholesale Trade and Commission Trade, Except of...                     1956.76
# Retail Trade, Except of Motor Vehicles and Moto...                     3463.32
# Hotels and Restaurants                                                 55.0795
# Inland Transport                                                       968.988
# Water Transport                                                        83.4572
# Air Transport                                                           125.47
# Other Supporting and Auxiliary Transport Activi...                     435.637
# Post and Telecommunications                                            337.334
# Financial Intermediation                                               2294.37
# Real Estate Activities                                                 139.363
# Renting of M&Eq and Other Business Activities                          2209.59
# Public Admin and Defence; Compulsory Social Sec...                     124.383
# Education                                                              5.67642
# Health and Social Work                                                 24.0907
# Other Community, Social and Personal Services                          1397.25
# Private Households with Employed Persons                                     0
#
# Intercountry Input-Output Table for 1996: BRA      Textiles and Textile Products  \
#
# Agriculture, Hunting, Forestry and Fishing                               527.716
# Mining and Quarrying                                                     3.58297
# Food, Beverages and Tobacco                                                37.35
# Textiles and Textile Products                                            9616.27
# Leather, Leather and Footwear                                            21.9427
# Wood and Products of Wood and Cork                                       1.17628
# Pulp, Paper, Paper , Printing and Publishing                             209.069
# Coke, Refined Petroleum and Nuclear Fuel                                 178.621
# Chemicals and Chemical Products                                          771.885
# Rubber and Plastics                                                      190.501
# Other Non-Metallic Mineral                                                 1.091
# Basic Metals and Fabricated Metal                                        10.8559
# Machinery, Nec                                                           194.514
# Electrical and Optical Equipment                                         21.8863
# Transport Equipment                                                      30.1442
# Manufacturing, Nec; Recycling                                            107.848
# Electricity, Gas and Water Supply                                        443.568
# Construction                                                              16.844
# Sale, Maintenance and Repair of Motor Vehicles ...                       312.595
# Wholesale Trade and Commission Trade, Except of...                        576.91
# Retail Trade, Except of Motor Vehicles and Moto...                       1021.09
# Hotels and Restaurants                                                   1.90659
# Inland Transport                                                         186.207
# Water Transport                                                          16.0377
# Air Transport                                                            24.1111
# Other Supporting and Auxiliary Transport Activi...                        83.715
# Post and Telecommunications                                              64.8244
# Financial Intermediation                                                 678.536
# Real Estate Activities                                                   72.3282
# Renting of M&Eq and Other Business Activities                            424.609
# Public Admin and Defence; Compulsory Social Sec...                       26.2373
# Education                                                                1.59578
# Health and Social Work                                                    7.2744
# Other Community, Social and Personal Services                            268.505
# Private Households with Employed Persons                                       0
#
# Intercountry Input-Output Table for 1996: BRA      Leather, Leather and Footwear  \
#
# Agriculture, Hunting, Forestry and Fishing                               55.9265
# Mining and Quarrying                                                     7.96229
# Food, Beverages and Tobacco                                               878.37
# Textiles and Textile Products                                            273.999
# Leather, Leather and Footwear                                            2201.23
# Wood and Products of Wood and Cork                                       8.13612
# Pulp, Paper, Paper , Printing and Publishing                             201.108
# Coke, Refined Petroleum and Nuclear Fuel                                 33.5494
# Chemicals and Chemical Products                                          506.622
# Rubber and Plastics                                                      245.259
# Other Non-Metallic Mineral                                               22.2033
# Basic Metals and Fabricated Metal                                        103.773
# Machinery, Nec                                                           49.2977
# Electrical and Optical Equipment                                         34.0941
# Transport Equipment                                                      7.59253
# Manufacturing, Nec; Recycling                                            30.5668
# Electricity, Gas and Water Supply                                        100.134
# Construction                                                             4.90897
# Sale, Maintenance and Repair of Motor Vehicles ...                       150.996
# Wholesale Trade and Commission Trade, Except of...                       278.671
# Retail Trade, Except of Motor Vehicles and Moto...                       493.227
# Hotels and Restaurants                                                   1.00138
# Inland Transport                                                         109.923
# Water Transport                                                          9.46744
# Air Transport                                                            14.2333
# Other Supporting and Auxiliary Transport Activi...                        49.419
# Post and Telecommunications                                              38.2674
# Financial Intermediation                                                  239.75
# Real Estate Activities                                                    16.173
# Renting of M&Eq and Other Business Activities                            250.657
# Public Admin and Defence; Compulsory Social Sec...                        12.007
# Education                                                               0.544307
# Health and Social Work                                                   3.50843
# Other Community, Social and Personal Services                            158.505
# Private Households with Employed Persons                                       0
#
# Intercountry Input-Output Table for 1996: BRA      Wood and Products of Wood and Cork  \
#
# Agriculture, Hunting, Forestry and Fishing                                    564.257
# Mining and Quarrying                                                          1.09236
# Food, Beverages and Tobacco                                                   6.96868
# Textiles and Textile Products                                                0.903602
# Leather, Leather and Footwear                                               0.0308116
# Wood and Products of Wood and Cork                                            1324.94
# Pulp, Paper, Paper , Printing and Publishing                                  68.3789
# Coke, Refined Petroleum and Nuclear Fuel                                      75.5127
# Chemicals and Chemical Products                                               91.9735
# Rubber and Plastics                                                           67.8715
# Other Non-Metallic Mineral                                                    3.31302
# Basic Metals and Fabricated Metal                                             97.8419
# Machinery, Nec                                                                61.4083
# Electrical and Optical Equipment                                              12.7163
# Transport Equipment                                                           7.87933
# Manufacturing, Nec; Recycling                                                 19.3815
# Electricity, Gas and Water Supply                                             111.666
# Construction                                                                  5.98904
# Sale, Maintenance and Repair of Motor Vehicles ...                            34.2781
# Wholesale Trade and Commission Trade, Except of...                            63.2619
# Retail Trade, Except of Motor Vehicles and Moto...                            111.969
# Hotels and Restaurants                                                        9.61629
# Inland Transport                                                              46.0152
# Water Transport                                                                3.9632
# Air Transport                                                                 5.95828
# Other Supporting and Auxiliary Transport Activi...                            20.6875
# Post and Telecommunications                                                   16.0193
# Financial Intermediation                                                      157.283
# Real Estate Activities                                                        9.25475
# Renting of M&Eq and Other Business Activities                                 104.929
# Public Admin and Defence; Compulsory Social Sec...                            6.25251
# Education                                                                    0.236723
# Health and Social Work                                                       0.865714
# Other Community, Social and Personal Services                                 66.3524
# Private Households with Employed Persons                                            0
#
# Intercountry Input-Output Table for 1996: BRA      Pulp, Paper, Paper , Printing and Publishing  \
#
# Agriculture, Hunting, Forestry and Fishing                                              703.934
# Mining and Quarrying                                                                    27.2798
# Food, Beverages and Tobacco                                                             63.4635
# Textiles and Textile Products                                                           104.664
# Leather, Leather and Footwear                                                           8.70112
# Wood and Products of Wood and Cork                                                      104.998
# Pulp, Paper, Paper , Printing and Publishing                                            4213.95
# Coke, Refined Petroleum and Nuclear Fuel                                                 102.38
# Chemicals and Chemical Products                                                         917.366
# Rubber and Plastics                                                                     525.056
# Other Non-Metallic Mineral                                                               20.235
# Basic Metals and Fabricated Metal                                                       301.066
# Machinery, Nec                                                                          154.918
# Electrical and Optical Equipment                                                        67.6237
# Transport Equipment                                                                     19.2038
# Manufacturing, Nec; Recycling                                                           42.6696
# Electricity, Gas and Water Supply                                                       460.562
# Construction                                                                            22.6915
# Sale, Maintenance and Repair of Motor Vehicles ...                                       247.54
# Wholesale Trade and Commission Trade, Except of...                                      456.848
# Retail Trade, Except of Motor Vehicles and Moto...                                      808.589
# Hotels and Restaurants                                                                  21.4954
# Inland Transport                                                                        356.543
# Water Transport                                                                         30.7084
# Air Transport                                                                            46.167
# Other Supporting and Auxiliary Transport Activi...                                      160.294
# Post and Telecommunications                                                             124.123
# Financial Intermediation                                                                914.392
# Real Estate Activities                                                                  92.4179
# Renting of M&Eq and Other Business Activities                                           813.027
# Public Admin and Defence; Compulsory Social Sec...                                      72.4726
# Education                                                                               3.30225
# Health and Social Work                                                                   6.6927
# Other Community, Social and Personal Services                                           514.124
# Private Households with Employed Persons                                                      0
#
# Intercountry Input-Output Table for 1996: BRA      Coke, Refined Petroleum and Nuclear Fuel  \
#
# Agriculture, Hunting, Forestry and Fishing                                           1584.9
# Mining and Quarrying                                                                8590.76
# Food, Beverages and Tobacco                                                         197.476
# Textiles and Textile Products                                                       19.0516
# Leather, Leather and Footwear                                                      0.175678
# Wood and Products of Wood and Cork                                                 0.656038
# Pulp, Paper, Paper , Printing and Publishing                                        16.3945
# Coke, Refined Petroleum and Nuclear Fuel                                            4026.25
# Chemicals and Chemical Products                                                     138.653
# Rubber and Plastics                                                                 69.5091
# Other Non-Metallic Mineral                                                          15.8039
# Basic Metals and Fabricated Metal                                                   124.547
# Machinery, Nec                                                                      122.208
# Electrical and Optical Equipment                                                    70.6035
# Transport Equipment                                                                 15.3361
# Manufacturing, Nec; Recycling                                                       2.29796
# Electricity, Gas and Water Supply                                                   190.703
# Construction                                                                        21.7511
# Sale, Maintenance and Repair of Motor Vehicles ...                                  364.925
# Wholesale Trade and Commission Trade, Except of...                                  673.488
# Retail Trade, Except of Motor Vehicles and Moto...                                  1192.03
# Hotels and Restaurants                                                              21.0661
# Inland Transport                                                                    263.825
# Water Transport                                                                     22.7228
# Air Transport                                                                       34.1615
# Other Supporting and Auxiliary Transport Activi...                                  118.611
# Post and Telecommunications                                                         91.8456
# Financial Intermediation                                                            314.744
# Real Estate Activities                                                              213.349
# Renting of M&Eq and Other Business Activities                                       601.602
# Public Admin and Defence; Compulsory Social Sec...                                  27.7401
# Education                                                                            4.5204
# Health and Social Work                                                              10.5019
# Other Community, Social and Personal Services                                       380.428
# Private Households with Employed Persons                                                  0
#
# Intercountry Input-Output Table for 1996: BRA      Chemicals and Chemical Products  \
#
# Agriculture, Hunting, Forestry and Fishing                                 143.588
# Mining and Quarrying                                                       571.423
# Food, Beverages and Tobacco                                                504.365
# Textiles and Textile Products                                              104.053
# Leather, Leather and Footwear                                              2.38981
# Wood and Products of Wood and Cork                                          131.12
# Pulp, Paper, Paper , Printing and Publishing                               456.105
# Coke, Refined Petroleum and Nuclear Fuel                                   2057.53
# Chemicals and Chemical Products                                            5937.29
# Rubber and Plastics                                                        465.255
# Other Non-Metallic Mineral                                                 265.244
# Basic Metals and Fabricated Metal                                          591.278
# Machinery, Nec                                                             308.278
# Electrical and Optical Equipment                                           129.247
# Transport Equipment                                                        38.9046
# Manufacturing, Nec; Recycling                                              16.2202
# Electricity, Gas and Water Supply                                          746.015
# Construction                                                               54.7499
# Sale, Maintenance and Repair of Motor Vehicles ...                         636.223
# Wholesale Trade and Commission Trade, Except of...                         1174.18
# Retail Trade, Except of Motor Vehicles and Moto...                         2078.22
# Hotels and Restaurants                                                      23.412
# Inland Transport                                                           626.048
# Water Transport                                                            53.9204
# Air Transport                                                               81.064
# Other Supporting and Auxiliary Transport Activi...                         281.459
# Post and Telecommunications                                                217.946
# Financial Intermediation                                                   1718.63
# Real Estate Activities                                                     86.8814
# Renting of M&Eq and Other Business Activities                              1427.58
# Public Admin and Defence; Compulsory Social Sec...                         88.4047
# Education                                                                  7.05541
# Health and Social Work                                                     16.2558
# Other Community, Social and Personal Services                              902.741
# Private Households with Employed Persons                                         0
#
# Intercountry Input-Output Table for 1996: BRA      Rubber and Plastics  \
#
# Agriculture, Hunting, Forestry and Fishing                     141.743
# Mining and Quarrying                                           12.2075
# Food, Beverages and Tobacco                                    26.6007
# Textiles and Textile Products                                  189.796
# Leather, Leather and Footwear                                 0.919975
# Wood and Products of Wood and Cork                             9.62356
# Pulp, Paper, Paper , Printing and Publishing                   360.957
# Coke, Refined Petroleum and Nuclear Fuel                       181.587
# Chemicals and Chemical Products                                3074.49
# Rubber and Plastics                                            922.234
# Other Non-Metallic Mineral                                     8.73407
# Basic Metals and Fabricated Metal                              321.121
# Machinery, Nec                                                 165.199
# Electrical and Optical Equipment                               123.561
# Transport Equipment                                            47.2122
# Manufacturing, Nec; Recycling                                  33.8435
# Electricity, Gas and Water Supply                              323.415
# Construction                                                   16.4654
# Sale, Maintenance and Repair of Motor Vehicles ...             256.538
# Wholesale Trade and Commission Trade, Except of...             473.453
# Retail Trade, Except of Motor Vehicles and Moto...             837.978
# Hotels and Restaurants                                         16.8472
# Inland Transport                                               203.431
# Water Transport                                                17.5212
# Air Transport                                                  26.3413
# Other Supporting and Auxiliary Transport Activi...             91.4586
# Post and Telecommunications                                    70.8206
# Financial Intermediation                                       518.141
# Real Estate Activities                                         50.2218
# Renting of M&Eq and Other Business Activities                  463.885
# Public Admin and Defence; Compulsory Social Sec...             30.9168
# Education                                                      1.39262
# Health and Social Work                                         7.03639
# Other Community, Social and Personal Services                  293.341
# Private Households with Employed Persons                             0
#
# Intercountry Input-Output Table for 1996: BRA           ...       \
#                                                         ...
# Agriculture, Hunting, Forestry and Fishing              ...
# Mining and Quarrying                                    ...
# Food, Beverages and Tobacco                             ...
# Textiles and Textile Products                           ...
# Leather, Leather and Footwear                           ...
# Wood and Products of Wood and Cork                      ...
# Pulp, Paper, Paper , Printing and Publishing            ...
# Coke, Refined Petroleum and Nuclear Fuel                ...
# Chemicals and Chemical Products                         ...
# Rubber and Plastics                                     ...
# Other Non-Metallic Mineral                              ...
# Basic Metals and Fabricated Metal                       ...
# Machinery, Nec                                          ...
# Electrical and Optical Equipment                        ...
# Transport Equipment                                     ...
# Manufacturing, Nec; Recycling                           ...
# Electricity, Gas and Water Supply                       ...
# Construction                                            ...
# Sale, Maintenance and Repair of Motor Vehicles ...      ...
# Wholesale Trade and Commission Trade, Except of...      ...
# Retail Trade, Except of Motor Vehicles and Moto...      ...
# Hotels and Restaurants                                  ...
# Inland Transport                                        ...
# Water Transport                                         ...
# Air Transport                                           ...
# Other Supporting and Auxiliary Transport Activi...      ...
# Post and Telecommunications                             ...
# Financial Intermediation                                ...
# Real Estate Activities                                  ...
# Renting of M&Eq and Other Business Activities           ...
# Public Admin and Defence; Compulsory Social Sec...      ...
# Education                                               ...
# Health and Social Work                                  ...
# Other Community, Social and Personal Services           ...
# Private Households with Employed Persons                ...
#
# Intercountry Input-Output Table for 1996: BRA      Health and Social Work  \
#
# Agriculture, Hunting, Forestry and Fishing                        63.2739
# Mining and Quarrying                                              11.4388
# Food, Beverages and Tobacco                                       315.379
# Textiles and Textile Products                                     425.247
# Leather, Leather and Footwear                                       1.905
# Wood and Products of Wood and Cork                                3.45764
# Pulp, Paper, Paper , Printing and Publishing                      462.525
# Coke, Refined Petroleum and Nuclear Fuel                          174.593
# Chemicals and Chemical Products                                   2267.14
# Rubber and Plastics                                               569.138
# Other Non-Metallic Mineral                                        354.568
# Basic Metals and Fabricated Metal                                  219.05
# Machinery, Nec                                                    39.3812
# Electrical and Optical Equipment                                  226.152
# Transport Equipment                                               16.1988
# Manufacturing, Nec; Recycling                                     13.6379
# Electricity, Gas and Water Supply                                 589.008
# Construction                                                      652.027
# Sale, Maintenance and Repair of Motor Vehicles ...                298.902
# Wholesale Trade and Commission Trade, Except of...                551.639
# Retail Trade, Except of Motor Vehicles and Moto...                976.362
# Hotels and Restaurants                                             677.41
# Inland Transport                                                  858.625
# Water Transport                                                   73.9518
# Air Transport                                                     111.179
# Other Supporting and Auxiliary Transport Activi...                 386.02
# Post and Telecommunications                                       298.913
# Financial Intermediation                                          357.715
# Real Estate Activities                                            555.628
# Renting of M&Eq and Other Business Activities                     1957.93
# Public Admin and Defence; Compulsory Social Sec...                112.941
# Education                                                         58.3368
# Health and Social Work                                              15.13
# Other Community, Social and Personal Services                     1238.11
# Private Households with Employed Persons                                0
#
# Intercountry Input-Output Table for 1996: BRA      Other Community, Social and Personal Services  \
#
# Agriculture, Hunting, Forestry and Fishing                                               54.0116
# Mining and Quarrying                                                                     8.62087
# Food, Beverages and Tobacco                                                              262.408
# Textiles and Textile Products                                                             305.81
# Leather, Leather and Footwear                                                            9.06045
# Wood and Products of Wood and Cork                                                       5.52959
# Pulp, Paper, Paper , Printing and Publishing                                             1169.88
# Coke, Refined Petroleum and Nuclear Fuel                                                 992.279
# Chemicals and Chemical Products                                                          132.911
# Rubber and Plastics                                                                      357.804
# Other Non-Metallic Mineral                                                                31.226
# Basic Metals and Fabricated Metal                                                        49.9237
# Machinery, Nec                                                                            56.992
# Electrical and Optical Equipment                                                         438.958
# Transport Equipment                                                                      593.156
# Manufacturing, Nec; Recycling                                                            143.078
# Electricity, Gas and Water Supply                                                        454.482
# Construction                                                                             156.378
# Sale, Maintenance and Repair of Motor Vehicles ...                                       320.638
# Wholesale Trade and Commission Trade, Except of...                                       591.754
# Retail Trade, Except of Motor Vehicles and Moto...                                       1047.36
# Hotels and Restaurants                                                                   173.471
# Inland Transport                                                                          1211.8
# Water Transport                                                                           104.37
# Air Transport                                                                             156.91
# Other Supporting and Auxiliary Transport Activi...                                       544.799
# Post and Telecommunications                                                              421.863
# Financial Intermediation                                                                 1018.61
# Real Estate Activities                                                                   608.538
# Renting of M&Eq and Other Business Activities                                            2763.27
# Public Admin and Defence; Compulsory Social Sec...                                       135.422
# Education                                                                                 13.141
# Health and Social Work                                                                   15.1445
# Other Community, Social and Personal Services                                            1747.37
# Private Households with Employed Persons                                                       0
#
# Intercountry Input-Output Table for 1996: BRA      Private Households with Employed Persons  \
#
# Agriculture, Hunting, Forestry and Fishing                                                0
# Mining and Quarrying                                                                      0
# Food, Beverages and Tobacco                                                               0
# Textiles and Textile Products                                                             0
# Leather, Leather and Footwear                                                             0
# Wood and Products of Wood and Cork                                                        0
# Pulp, Paper, Paper , Printing and Publishing                                              0
# Coke, Refined Petroleum and Nuclear Fuel                                                  0
# Chemicals and Chemical Products                                                           0
# Rubber and Plastics                                                                       0
# Other Non-Metallic Mineral                                                                0
# Basic Metals and Fabricated Metal                                                         0
# Machinery, Nec                                                                            0
# Electrical and Optical Equipment                                                          0
# Transport Equipment                                                                       0
# Manufacturing, Nec; Recycling                                                             0
# Electricity, Gas and Water Supply                                                         0
# Construction                                                                              0
# Sale, Maintenance and Repair of Motor Vehicles ...                                        0
# Wholesale Trade and Commission Trade, Except of...                                        0
# Retail Trade, Except of Motor Vehicles and Moto...                                        0
# Hotels and Restaurants                                                                    0
# Inland Transport                                                                          0
# Water Transport                                                                           0
# Air Transport                                                                             0
# Other Supporting and Auxiliary Transport Activi...                                        0
# Post and Telecommunications                                                               0
# Financial Intermediation                                                                  0
# Real Estate Activities                                                                    0
# Renting of M&Eq and Other Business Activities                                             0
# Public Admin and Defence; Compulsory Social Sec...                                        0
# Education                                                                                 0
# Health and Social Work                                                                    0
# Other Community, Social and Personal Services                                             0
# Private Households with Employed Persons                                                  0
#
# Intercountry Input-Output Table for 1996: BRA      Final consumption expenditure by households  \
#
# Agriculture, Hunting, Forestry and Fishing                                             15165.1
# Mining and Quarrying                                                                   240.337
# Food, Beverages and Tobacco                                                            50611.7
# Textiles and Textile Products                                                          17909.3
# Leather, Leather and Footwear                                                          4859.52
# Wood and Products of Wood and Cork                                                     253.111
# Pulp, Paper, Paper , Printing and Publishing                                           4607.72
# Coke, Refined Petroleum and Nuclear Fuel                                               12168.6
# Chemicals and Chemical Products                                                        14773.5
# Rubber and Plastics                                                                    1570.46
# Other Non-Metallic Mineral                                                             443.261
# Basic Metals and Fabricated Metal                                                      919.529
# Machinery, Nec                                                                         4596.59
# Electrical and Optical Equipment                                                       7745.43
# Transport Equipment                                                                    16246.6
# Manufacturing, Nec; Recycling                                                          7105.31
# Electricity, Gas and Water Supply                                                        12902
# Construction                                                                                 0
# Sale, Maintenance and Repair of Motor Vehicles ...                                     7125.87
# Wholesale Trade and Commission Trade, Except of...                                     13151.2
# Retail Trade, Except of Motor Vehicles and Moto...                                     23276.6
# Hotels and Restaurants                                                                 23193.8
# Inland Transport                                                                       12309.1
# Water Transport                                                                        1060.16
# Air Transport                                                                          1593.85
# Other Supporting and Auxiliary Transport Activi...                                     5533.94
# Post and Telecommunications                                                            4285.18
# Financial Intermediation                                                               44189.2
# Real Estate Activities                                                                 53657.4
# Renting of M&Eq and Other Business Activities                                          28068.6
# Public Admin and Defence; Compulsory Social Sec...                                     1220.23
# Education                                                                              11611.1
# ...
# Transport Equipment                                                                                 0
# Manufacturing, Nec; Recycling                                                                       0
# Electricity, Gas and Water Supply                                                                   0
# Construction                                                                                        0
# Sale, Maintenance and Repair of Motor Vehicles ...                                                  0
# Wholesale Trade and Commission Trade, Except of...                                                  0
# Retail Trade, Except of Motor Vehicles and Moto...                                                  0
# Hotels and Restaurants                                                                              0
# Inland Transport                                                                              1790.36
# Water Transport                                                                               154.201
# Air Transport                                                                                 231.825
# Other Supporting and Auxiliary Transport Activi...                                             804.91
# Post and Telecommunications                                                                   623.279
# Financial Intermediation                                                                            0
# Real Estate Activities                                                                              0
# Renting of M&Eq and Other Business Activities                                                 4082.57
# Public Admin and Defence; Compulsory Social Sec...                                            4.75675
# Education                                                                                    0.482379
# Health and Social Work                                                                        639.865
# Other Community, Social and Personal Services                                                 2581.64
# Private Households with Employed Persons                                                            0
#
# Intercountry Input-Output Table for 1996: BRA      Final consumption expenditure by government  \
#
# Agriculture, Hunting, Forestry and Fishing                                                   0
# Mining and Quarrying                                                                         0
# Food, Beverages and Tobacco                                                                  0
# Textiles and Textile Products                                                                0
# Leather, Leather and Footwear                                                                0
# Wood and Products of Wood and Cork                                                           0
# Pulp, Paper, Paper , Printing and Publishing                                                 0
# Coke, Refined Petroleum and Nuclear Fuel                                                     0
# Chemicals and Chemical Products                                                              0
# Rubber and Plastics                                                                          0
# Other Non-Metallic Mineral                                                                   0
# Basic Metals and Fabricated Metal                                                            0
# Machinery, Nec                                                                               0
# Electrical and Optical Equipment                                                             0
# Transport Equipment                                                                          0
# Manufacturing, Nec; Recycling                                                                0
# Electricity, Gas and Water Supply                                                            0
# Construction                                                                                 0
# Sale, Maintenance and Repair of Motor Vehicles ...                                           0
# Wholesale Trade and Commission Trade, Except of...                                           0
# Retail Trade, Except of Motor Vehicles and Moto...                                           0
# Hotels and Restaurants                                                                       0
# Inland Transport                                                                      0.892789
# Water Transport                                                                      0.0768861
# Air Transport                                                                         0.115607
# Other Supporting and Auxiliary Transport Activi...                                    0.401376
# Post and Telecommunications                                                           0.310808
# Financial Intermediation                                                               676.359
# Real Estate Activities                                                                       0
# Renting of M&Eq and Other Business Activities                                          2.03581
# Public Admin and Defence; Compulsory Social Sec...                                     94618.7
# Education                                                                              34464.1
# Health and Social Work                                                                 28032.2
# Other Community, Social and Personal Services                                          1.28736
# Private Households with Employed Persons                                                     0
#
# Intercountry Input-Output Table for 1996: BRA      Gross fixed capital formation  \
#
# Agriculture, Hunting, Forestry and Fishing                               3961.24
# Mining and Quarrying                                                     10.3885
# Food, Beverages and Tobacco                                              93.4397
# Textiles and Textile Products                                            51.9872
# Leather, Leather and Footwear                                            5.90912
# Wood and Products of Wood and Cork                                       76.7151
# Pulp, Paper, Paper , Printing and Publishing                             19.1242
# Coke, Refined Petroleum and Nuclear Fuel                                 1.39375
# Chemicals and Chemical Products                                          49.7238
# Rubber and Plastics                                                      89.5532
# Other Non-Metallic Mineral                                               26.1058
# Basic Metals and Fabricated Metal                                        3197.57
# Machinery, Nec                                                           8941.28
# Electrical and Optical Equipment                                         12222.5
# Transport Equipment                                                      8382.21
# Manufacturing, Nec; Recycling                                            3302.66
# Electricity, Gas and Water Supply                                        3.40804
# Construction                                                             65214.8
# Sale, Maintenance and Repair of Motor Vehicles ...                       1716.29
# Wholesale Trade and Commission Trade, Except of...                        3167.5
# Retail Trade, Except of Motor Vehicles and Moto...                       5606.25
# Hotels and Restaurants                                                   11.5339
# Inland Transport                                                         544.073
# Water Transport                                                            46.86
# Air Transport                                                            70.4494
# Other Supporting and Auxiliary Transport Activi...                       244.604
# Post and Telecommunications                                              189.408
# Financial Intermediation                                                  22.957
# Real Estate Activities                                                   1127.13
# Renting of M&Eq and Other Business Activities                            1240.65
# Public Admin and Defence; Compulsory Social Sec...                       51.1865
# Education                                                                 17.249
# Health and Social Work                                                   51.7703
# Other Community, Social and Personal Services                            784.536
# Private Households with Employed Persons                                       0
#
# Intercountry Input-Output Table for 1996: BRA      Changes in inventories and valuables  \
#
# Agriculture, Hunting, Forestry and Fishing                                      535.967
# Mining and Quarrying                                                            303.511
# Food, Beverages and Tobacco                                                     283.542
# Textiles and Textile Products                                                  -148.673
# Leather, Leather and Footwear                                                   373.552
# Wood and Products of Wood and Cork                                             -30.0125
# Pulp, Paper, Paper , Printing and Publishing                                    543.311
# Coke, Refined Petroleum and Nuclear Fuel                                       -159.185
# Chemicals and Chemical Products                                                -216.651
# Rubber and Plastics                                                             16.4772
# Other Non-Metallic Mineral                                                      333.584
# Basic Metals and Fabricated Metal                                              -158.244
# Machinery, Nec                                                                 -123.857
# Electrical and Optical Equipment                                               -224.148
# Transport Equipment                                                             -458.05
# Manufacturing, Nec; Recycling                                                  -59.7968
# Electricity, Gas and Water Supply                                                     0
# Construction                                                                          0
# Sale, Maintenance and Repair of Motor Vehicles ...                              26.4971
# Wholesale Trade and Commission Trade, Except of...                              48.9018
# Retail Trade, Except of Motor Vehicles and Moto...                              86.5527
# Hotels and Restaurants                                                         0.180807
# Inland Transport                                                                7.33237
# Water Transport                                                                0.631524
# Air Transport                                                                  0.949433
# Other Supporting and Auxiliary Transport Activi...                              3.29648
# Post and Telecommunications                                                     2.55262
# Financial Intermediation                                                              0
# Real Estate Activities                                                        0.0243214
# Renting of M&Eq and Other Business Activities                                     16.72
# Public Admin and Defence; Compulsory Social Sec...                               17.985
# Education                                                                     0.0849896
# Health and Social Work                                                         0.483839
# Other Community, Social and Personal Services                                    10.573
# Private Households with Employed Persons                                              0
#
# Intercountry Input-Output Table for 1996: BRA        Exports  Total output
#
# Agriculture, Hunting, Forestry and Fishing           4122.92  57878.069216
# Mining and Quarrying                                 2470.49  13396.464862
# Food, Beverages and Tobacco                          9390.64  78163.967059
# Textiles and Textile Products                        1173.38  31931.873449
# Leather, Leather and Footwear                        2237.76   7590.778916
# Wood and Products of Wood and Cork                   1010.74   5920.943709
# Pulp, Paper, Paper , Printing and Publishing         1960.34  21840.629863
# Coke, Refined Petroleum and Nuclear Fuel               963.8  29766.924840
# Chemicals and Chemical Products                      3252.52  38886.582297
# Rubber and Plastics                                  888.149  15769.795205
# Other Non-Metallic Mineral                           700.146  12566.326576
# Basic Metals and Fabricated Metal                    7406.04  34094.798155
# Machinery, Nec                                       2713.41  19817.999168
# Electrical and Optical Equipment                     2192.38  34675.488546
# Transport Equipment                                  4828.92  37781.353065
# Manufacturing, Nec; Recycling                        662.395  13748.797169
# Electricity, Gas and Water Supply                   0.978617  34062.572638
# Construction                                         424.594  75160.162339
# Sale, Maintenance and Repair of Motor Vehicles ...   78.8703  17661.113720
# Wholesale Trade and Commission Trade, Except of...    145.54  32594.492645
# Retail Trade, Except of Motor Vehicles and Moto...   257.873  57689.929660
# Hotels and Restaurants                               1734.07  26302.883593
# Inland Transport                                     662.955  33547.236449
# Water Transport                                      57.0991   2889.362672
# Air Transport                                        85.8432   4343.869167
# Other Supporting and Auxiliary Transport Activi...   298.052  15082.151837
# Post and Telecommunications                          230.813  11678.804899
# Financial Intermediation                             387.957  95218.903999
# Real Estate Activities                               310.529  64784.650771
# Renting of M&Eq and Other Business Activities        1511.79  76497.896623
# Public Admin and Defence; Compulsory Social Sec...   97.0658  98280.135816
# Education                                            12.7304  46586.686002
# Health and Social Work                               10.2972  45256.270099
# Other Community, Social and Personal Services        956.917  48374.029418
# Private Households with Employed Persons                   0      0.000000
#
# [35 rows x 42 columns]

# %%
import os
import re
import warnings
from operator import add

import numpy as np
import pandas as pd

# Отключаем warnings
warnings.simplefilter("ignore")


class Decomposition(object):
    """
    Класс с методами необходимыми для декомпозиции.

    Пользовательские методы:
    ------------------------
    - load_WIOD2013_merged_data(**path_and_sheetnames) - чтение данных из таблиц WIOD release 2013. Таблицы
    отечественного выпуска и импорта находятся на одной странице, данные за разные годы лежат в одном файле.
    - load_Rosstat_separated_data(**path_and_sheetnames) - чтение данных из таблиц Росстата. Таблицы отечественного
    выпуска и импорта находятся на разных страницах, данные за разные годы лежат в разных файлах.
    - prepare_data(column_order) - подготовка данных перед декомпозицией

    Методы декомпозиции:
    --------------------
    - decomposition_Baranov_2016() - декомпозиция из статьи в "Вопросах статистики" 2016 год по 2м факторам.
    - decomposition_Baranov_2018() - декомпозиция по статье "Методологические проблемы использования метода структурной
    декомпозиции в модели "затраты – выпуск" на современном этапе" (2018) - по 6 факторам - промежуточный спрос,
    внешний спрос, спрос домашних хозяйств, спрос государства, валовое накопление основного капитала,
    изменение материальных оборотных средств
    - decomposition_Magacho_2018() - декомпозиция из статьи Magacho, G.R., et al., "Impacts of trade liberalization
    on countries’ sectoral structure of production and trade: A structural decomposition analysis." Structural Change
    and Economics Dynamics (2018) - по 4 факторам - технологические изменения, импортозамещение, конечный спрос, экспорт(формула 15).
    Также раскладываем суммарный экспорт на directed и indirirected.
    - decomposition_Chenery() - декомпозиция Chenery

    Методы используемые для внутренних операций:
    --------------------------------------------
    - get_by_name(name) - возвращает столбец по номеру столбца с конца из матриц обоих годов для отечественной
    продукции и импорта
    - get_table(df) - возвращает матрицы затрат на покупку продуктов одних отраслей для производства продуктов других
    отраслей
    - check_sums_equality(Z, F, Total) - проверяет правильность полученной таблицы X или M с точностью до 10^-8
    - save_to_excel(file_name, rounding="%.3f", **tables) - сохраняет полученные таблицы в выбранный excel-файл
    - pack_name(str) - приклеивает к строке годы, к которым относится содержание строки, и если было указано, то год,
    для которого были пересчитаны цены в таблице
    - add_percent_to_column_name(str) - добавляет знак процента для названий колонок таблиц.
    - divide_or_put_zero(X,Y) - производит деление вектора X на Y, если Y != 0, остальное заполняет нулями.

    """

    def __init__(self):
        self.prices_in = ""  # в каких ценах пересчитаны таблицы
        self.years = []  # годы за которые приведены таблицы
        self.df_d = []  # таблицы отечественного выпуска
        self.df_m = []  # таблицы импорта
        self.eps0 = 1e-20 # хранит число на которое заменяются нули в таблице

    def load_WIOD2013_merged_data(self, **path_and_sheetnames):
        """
        Чтение данных из таблиц WIOD release 2013. Таблицы отечественного выпуска и импорта находятся на одной
        странице, данные за разные годы лежат в одном файле.

        Parameters
        ----------
        path_and_sheetnames: dictionary
            путь к excel-файлу и страницы в excel-файле

        """

        # Расположение 1ого квадранта таблицы и столбцов\строк с названиями в ней
        vertical_table_position = slice(5, 75)  # положение и размеры таблицы по вертикали
        horizontal_table_position = slice(4, 46)  # положение и размеры таблицы по горизонтали
        industries_part_position = slice(4, 39)  # положение и размеры части таблицы с промежуточным потреблением по
        # горизонтали
        codes_position = 1  # номер строки в таблице с кодами отраслей
        columns_names_position = 2  # номер строки в таблице с названиями колонок
        rows_names_position = 1  # номер столбца в таблице с названиями строк


        df_all = []
        for path, sheetnames in path_and_sheetnames.items():
            file = pd.ExcelFile(path)
            for sheetname in sheetnames:
                df1 = pd.read_excel(file, sheet_name=sheetname)

                # Получаем имена столбцов и строк
                rows = df1.iloc[vertical_table_position, rows_names_position]
                rows.name = ""
                columns = df1.iloc[columns_names_position, horizontal_table_position]
                columns.name = df1.columns[0]

                # Получаем из таблицы коды отраслей (одинаковые по вертикали и горизонтали)
                self.codes = df1.iloc[codes_position, industries_part_position]

                # Сохраняем обрезанную версию таблицы
                df = df1.iloc[vertical_table_position, horizontal_table_position]
                df.columns = columns
                df.index = rows
                df.name = columns.name

                df_all.append(df)
                self.years.append(re.search("\d+", columns.name).group(0))

            #print("Обрабатываем данные из таблицы \"" + columns.name + "\"")
            self.prices_in = "(в ценах " + re.search("\d+", df1.iloc[0, 0]).group(0) + "года)"

            # Делим таблицы на отечественный выпуск и импорт
            self.df_d = [df_all[0].iloc[:35], df_all[1].iloc[:35]]
            self.df_m = [df_all[0].iloc[35:], df_all[1].iloc[35:]]

    def load_Rosstat_separated_data(self, **path_and_sheetnames):
        """
        Чтение данных из таблиц Росстата. Таблицы отечественного выпуска и импорта находятся на разных страницах,
        данные за разные годы лежат в разных файлах.

        Parameters
        ----------
        path_and_sheetnames: dictionary
            путь к excel-файлу и страницы в excel-файле

        """

        # Расположение таблицы и столбцов\строк с названиями в ней
        vertical_table_position = slice(3, 62)  # положение и размеры таблицы по вертикали
        horizontal_table_position = slice(3, 69)  # положение и размеры таблицы по горизонтали
        industries_part_position = slice(3, 62)  # положение и размеры части таблицы с промежуточным потреблением по
        # горизонтали
        codes_position = 1  # номер строки в таблице с кодами отраслей
        columns_names_position = 0  # номер строки в таблице с названиями колонок
        rows_names_position = 2  # номер столбца в таблице с названиями строк


        for path, sheetnames in path_and_sheetnames.items():
            file = pd.ExcelFile(path)
            for i, sheetname in enumerate(sheetnames):
                df1 = pd.read_excel(file, sheet_name=sheetname)

                # Получаем имена столбцов и строк
                rows = df1.iloc[vertical_table_position, rows_names_position]
                rows.name = ""
                columns = df1.iloc[columns_names_position, horizontal_table_position]
                columns.name = df1.columns[0]

                # Получаем из таблицы коды отраслей (одинаковые по вертикали и горизонтали)
                self.codes = df1.iloc[codes_position, industries_part_position]

                # Сохраняем обрезанную версию таблицы
                df = df1.iloc[vertical_table_position, horizontal_table_position]
                df.columns = columns
                df.index = rows
                df.name = columns.name

                # Делим таблицы на отечественный выпуск и импорт
                if not i:
                    self.df_d.append(df)
                else:
                    self.df_m.append(df)

            #print("Обрабатываем данные из таблицы \"" + columns.name + "\"")
            self.years.append(re.search("\d+", columns.name).group(0))

    def get_by_pos(self, pos):
        """
        Возвращает столбец по номеру столбца с конца из матриц обоих годов для отечественной продукции и импорта
        """
        get_by_pos0 = lambda df: df.iloc[:, pos]
        res_m = np.array(list(map(get_by_pos0, self.df_m)))
        res_d = np.array(list(map(get_by_pos0, self.df_d)))
        return res_m, res_d

    def get_table(self, df):
        """
        Возвращает матрицы затрат на покупку продуктов одних отраслей для производства продуктов других отраслей
        """
        return df.iloc[:, :-7]

    def pack_name(self, str):
        """
        Приклеивает к строке годы, к которым относится содержание строки, и если было указано, то год, для которого были
        пересчитаны цены в таблице

        str: string
            строка-название таблицы\страницы файла
        """
        return str + " за " + self.my_years + "гг " + self.prices_in

    def check_sums_equality(self, Z, F, Total):
        """
        Проверяет правильность полученной таблицы X или M с точностью до 10^-8
        """
        for year in [0, 1]:
            z = Z[year]
            f = F[year]
            total = Total[year]
            for i in range(len(total)):
                if (abs(sum(z.iloc[i]) + f[i] - total[i]) >= 1e-8):
                    #print("Ошибка в таблице \"", z.columns.name, "\" в строке \"", z.columns[i],
                         # "\" должно быть:", sum(z.iloc[i]) + f[i], ", написано:", total[i])
                    Total[year][i] = sum(z.iloc[i]) + f[i]
        return Total

    def divide_or_put_zero(self,X,Y):
        """
        Производит деление вектора X на Y, если Y != 0, остальное заполняет нулями.
        """
        res = np.zeros_like(X)
        mask = Y != 0.
        res[mask] = X[mask] / Y[mask]
        return res

    def add_percent_to_column_name(self,s):
        """
        Добавляет знак процента для названий колонок таблиц.
        """
        return s + ", %"

    def prepare_data(self, column_order):
        """
        Подготовка данных перед декомпозицией

        column_order: string
            Порядок столбцов в таблице "eng" - households, NPISH, government or "rus" - households, government, NPISH
        """
        self.columns = self.df_d[0].columns.values
        self.my_years = self.years[0] + "-" + self.years[1]
        length = len(self.columns) - 7
        os.makedirs("./results/" + self.my_years, exist_ok=True)
        print("Годы таблицы:", self.my_years)

        if column_order == 'eng':
            self.C_mnpish, self.C_dnpish = self.get_by_pos(-6)
            self.C_mg, self.C_dg = self.get_by_pos(-5)
        else:
            self.C_mg, self.C_dg = self.get_by_pos(-6)
            self.C_mnpish, self.C_dnpish = self.get_by_pos(-5)

        self.C_mh, self.C_dh = self.get_by_pos(-7)
        self.I_mgfch, self.I_dgfch = self.get_by_pos(-4)
        self.I_ms, self.I_ds = self.get_by_pos(-3)
        self.E_r, self.E = self.get_by_pos(-2)
        self.M, self.X = self.get_by_pos(-1)

        Z_m = list(map(self.get_table, self.df_m))
        Z_d = list(map(self.get_table, self.df_d))

        # Заменяем нули на выбранный eps0
        self.X[self.X == 0] = self.eps0
        self.M[self.M == 0] = self.eps0

        # Вычисляем суммы столбцов таблицы
        self.I_m = self.I_mgfch + self.I_ms
        self.I_d = self.I_dgfch + self.I_ds
        self.C_mh = self.C_mh + self.C_mnpish
        self.C_dh = self.C_dh + self.C_dnpish
        self.C_m = self.C_mg + self.C_mh
        self.C_d = self.C_dg + self.C_dh
        self.F_m = self.I_m + self.C_m + self.E_r
        self.F_d = self.I_d + self.C_d + self.E

        # Получаем суммарные показатели для импорта и отечественной продукции
        self.I_s = self.I_ds + self.I_ms
        self.I_gfch = self.I_dgfch + self.I_mgfch
        self.In = self.I_d + self.I_m
        self.C_g = self.C_dg + self.C_mg
        self.C_h = self.C_dh + self.C_mh
        self.C = self.C_d + self.C_m

        # Проверяем правильность столбцов суммарного выпуска
        self.M = self.check_sums_equality(Z_m, self.F_m, self.M)
        self.X = self.check_sums_equality(Z_d, self.F_d, self.X)

        # TODO: Переписать для pandas dataframe
        # Вычисляем матрицы технических коэффициентов
        self.A_d = [(Z_d[0] / self.X[0]).astype('float'), (Z_d[1] / self.X[1]).astype('float')]
        self.A_m = [Z_m[0] / self.X[0], Z_m[1] / self.X[1]]
        self.A = [(self.A_d[0] + self.A_m[0]).astype('float'), (self.A_d[1] + self.A_m[1]).astype('float')]

        I = np.eye(length, dtype='float')
        self.U = np.ones((length,length), dtype='float')
        self.L_d = [np.linalg.inv(((I - A).astype('float'))) for A in self.A_d]

        # Доли отечественной\импортной составляющей в общих технологических коэффициентах
        self.R_d = [self.A_d[0] / self.A[0], self.A_d[1] / self.A[1]]
        self.R_d[0][self.A[0] == 0] = 0
        self.R_d[1][self.A[1] == 0] = 0
        self.R_m = [self.U - self.R_d[0], self.U - self.R_d[1]]

        # Доля отечественной составляющей в общем ивестиционном спросе
        self.R_In = self.divide_or_put_zero(self.I_d, self.In)
        self.R_Is = self.divide_or_put_zero(self.I_ds, self.I_s)
        self.R_Igfch = self.divide_or_put_zero(self.I_dgfch, self.I_gfch)

        # Доля отечественной составляющей в общем потребительском спросе
        self.R_C = self.divide_or_put_zero(self.C_d, self.C)
        self.R_Cg = self.divide_or_put_zero(self.C_dg, self.C_g)
        self.R_Ch = self.divide_or_put_zero(self.C_dh, self.C_h)

    def decomposition_Baranov_2016(self):
        """
        Метод декомпозиции из статьи в "Вопросах статистики" 2016 год. Декомпозиция по 2м факторам.

        """
        columns = ['dX полученный с помощью метода декомпозиции, млн', 'Разность X1 - X0, млн',
                   'dM полученный с помощью метода декомпозиции, млн', 'Разность M1 - M0, млн']
        columns_perc = ['Выпуск ' + self.years[0] + ' года, млн', 'Выпуск ' + self.years[1] + ' года, млн',
                        'Выпуск ' + self.years[1] + ' года к ' + self.years[0] + ' году, %',
                        'Импорт ' + self.years[0] + ' года, млн', 'Импорт ' + self.years[1] + ' года, млн',
                        'Импорт ' + self.years[1] + ' года к ' + self.years[0] + ' году, %']

        WL0 = self.A_m[0].dot(self.L_d[0])
        WL1 = self.A_m[1].dot(self.L_d[1])

        dX = ((self.L_d[1] + self.L_d[0]).dot(self.F_d[1] - self.F_d[0]) + (self.L_d[1] - self.L_d[0]).dot(
            self.F_d[1] + self.F_d[0])) / 2

        dM = ((WL1 + WL0).dot(self.F_d[1] - self.F_d[0]) + (WL1 - WL0).dot(self.F_d[1] + self.F_d[0])) / 2 + \
             self.F_m[1] - self.F_m[0]

        dX_perc = (self.X[1] / self.X[0]) * 100
        dM_perc = (self.M[1] / self.M[0]) * 100

        # Вывод таблиц
        results = pd.DataFrame(np.column_stack([dX, self.X[1] - self.X[0], dM, self.M[1] - self.M[0]]),
                               columns=columns, index=self.df_d[0].index)
        results.loc["Total"] = [sum(dX), sum(self.X[1]) - sum(self.X[0]), sum(dM), sum(self.M[1]) - sum(self.M[0])]
        results.columns.name = 'Изменения в выпуске и импорте'

        self.results_percents = pd.DataFrame(
            np.column_stack([self.X[0], self.X[1], dX_perc, self.M[0], self.M[1], dM_perc]),
            columns=columns_perc,
            index=self.df_d[0].index)
        self.results_percents.loc["Total"] = [sum(self.X[0]), sum(self.X[1]), (sum(self.X[1]) / sum(self.X[0])) * 100,
                                              sum(self.M[0]), sum(self.M[1]), (sum(self.M[1]) / sum(self.M[0])) * 100]
        self.results_percents.columns.name = 'Изменения в выпуске и импорте'

        # Проверяем, что изменения в валовом выпуске, полученные как сумма факторов (dX и dM) сходятся с разностями
        # X[1] - X[0] и M[1] - M[0], полученными из таблиц (с точностью до 10^-5)
        assert (sum(self.X[1]) - sum(self.X[0]) - sum(
            dX) < 1e-5), "Oops! Полученные суммарные изменения в валовом выпуске dX не равны X1 - X0!"
        assert (sum(self.M[1]) - sum(self.M[0]) - sum(
            dM) < 1e-5), "Oops! Полученные суммарные изменения в валовом выпуске dM не равны M1 - M0!"

        result_tables = {
            "Упрощенная декомпозиция изменений в выпуске и импорте за " + self.my_years + "гг " + self.prices_in: results}
        self.save_to_excel('results_simple(Baranov_2016).xlsx', **result_tables)

        print("\nРезультат работы метода декомпозиции Baranov_2016 сохранен в папку results!")

    def decomposition_Baranov_2018(self):
        """
        Метод декомпозиции из статьи "Методологические проблемы использования метода структурной декомпозиции
        в модели "затраты – выпуск" на современном этапе" (2018).

        Декомпозиция по 6 факторам - промежуточный спрос, внешний спрос, спрос домашних хозяйств, спрос
        государства, валовое накопление основного капитала, изменение материальных оборотных средств

        """
        # Колонки для результирующих таблиц
        columns_X = ['Конечный спрос через формулу для декомпозиции 16 года',
                  'Конечный спрос как сумма факторов', 'dX полученный с помощью метода декомпозиции',
                  'Разность X1 - X0']
        columns_M = ['Конечный спрос через формулу для декомпозиции 16 года',
                  'Конечный спрос как сумма факторов', 'dM полученный с помощью метода декомпозиции',
                  'Разность M1 - M0']
        res_columns = ['Промежуточный спрос', 'Внешний спрос', 'Спрос домашних хозяйств', 'Спрос государства',
                    'Валовое накопление основного капитала', 'Изменение запаса материальных оборотных средств']
        res_index = ['Выпуск отечественной продукции', 'Импорт', 'Всего']
        res_columns_perc = ['Промежуточный спрос, %', 'Внешний спрос, %', 'Спрос домашних хозяйств, %',
                         'Спрос государства, %', 'Валовое накопление основного капитала, %',
                         'Изменение запаса материальных оборотных средств, %']

        sumL = self.L_d[0] + self.L_d[1]
        sumW = self.A_m[0].dot(self.L_d[0]) + self.A_m[1].dot(self.L_d[1])

        # Получаем слагаемые декомпозиции изменения выпуска отечественной продукции
        dX = np.array([np.zeros(len(self.M[0]))] * 8)
        dX[0] = ((self.L_d[1] - self.L_d[0]).dot(self.F_d[1] + self.F_d[0])) / 2
        dX[1] = sumL.dot(self.E[1] - self.E[0]) / 2
        dX[2] = sumL.dot(self.C_dh[1] - self.C_dh[0]) / 2
        dX[3] = sumL.dot(self.C_dg[1] - self.C_dg[0]) / 2
        dX[4] = sumL.dot(self.I_dgfch[1] - self.I_dgfch[0]) / 2
        dX[5] = sumL.dot(self.I_ds[1] - self.I_ds[0]) / 2
        dX_all = dX[0] + dX[1] + dX[2] + dX[3] + dX[4] + dX[5]
        Xtot = sum(dX_all)

        dX[6] = dX[1] + dX[2] + dX[3] + dX[4] + dX[5]
        dX[7] = ((self.L_d[1] + self.L_d[0]).dot(self.F_d[1] - self.F_d[0])) / 2

        # Получаем слагаемые декомпозиции изменения импорта
        dM = np.array([np.zeros(len(self.M[0]))] * 8)
        dM[0] = ((self.A_m[1] - self.A_m[0]).dot(self.L_d[1].dot(self.F_d[1]) + self.L_d[0].dot(self.F_d[0])) +
                 self.A_m[0].dot(self.L_d[1] - self.L_d[0]).dot(self.F_d[1]) + self.A_m[1].dot(
            self.L_d[1] - self.L_d[0]).dot(self.F_d[0])) / 2

        dM[1] = self.E_r[1] - self.E_r[0] + sumW.dot(self.E[1] - self.E[0]) / 2
        dM[2] = self.C_mh[1] - self.C_mh[0] + sumW.dot(self.C_dh[1] - self.C_dh[0]) / 2
        dM[3] = self.C_mg[1] - self.C_mg[0] + sumW.dot(self.C_dg[1] - self.C_dg[0]) / 2
        dM[4] = self.I_mgfch[1] - self.I_mgfch[0] + sumW.dot(self.I_dgfch[1] - self.I_dgfch[0]) / 2
        dM[5] = self.I_ms[1] - self.I_ms[0] + sumW.dot(self.I_ds[1] - self.I_ds[0]) / 2
        dM_all = dM[0] + dM[1] + dM[2] + dM[3] + dM[4] + dM[5]
        Mtot = sum(dM_all)

        dM[6] = dM[1] + dM[2] + dM[3] + dM[4] + dM[5]
        dM[7] = ((self.A_m[1].dot(self.L_d[1]) + self.A_m[0].dot(self.L_d[0])).dot(self.F_d[1] - self.F_d[0])) / 2 + (
            self.F_m[1] - self.F_m[0])

        # Проверяем, что изменения в валовом выпуске, полученные как сумма факторов (dX_all и dM_all) сходятся с
        # разностями X[1] - X[0] и M[1] - M[0], полученными из таблиц (с точностью до 10^-5)
        assert (sum(self.X[1]) - sum(self.X[0]) - sum(
            dX_all) < 1e-5), "Oops! Полученные суммарные изменения в валовом выпуске dX_all не равны X1 - X0!"
        assert (sum(self.M[1]) - sum(self.M[0]) - sum(
            dM_all) < 1e-5), "Oops! Полученные суммарные изменения в валовом выпуске dM_all не равны M1 - M0!"

        # Вывод таблиц
        result_d = pd.DataFrame(np.column_stack(dX[:6]), columns=res_columns, index=self.df_d[0].index)
        result_d.columns.name = 'Выпуск отечественной продукции'
        result_m = pd.DataFrame(np.column_stack(dM[:6]), columns=res_columns, index=self.df_d[0].index)
        result_m.columns.name = 'Импорт'

        res_check_X = pd.DataFrame(np.column_stack([dX[7], dX[6], dX_all, self.X[1] - self.X[0]]),
                                   columns=columns_X, index=self.df_d[0].index)
        res_check_X.columns.name = 'Выпуск отечественной продукци'
        res_check_M = pd.DataFrame(np.column_stack([dM[7], dM[6], dM_all, self.M[1] - self.M[0]]),
                                   columns=columns_M, index=self.df_d[0].index)
        res_check_M.columns.name = 'Импорт'

        # Вывод таблиц в процентах - таблицы аналогичные полученным в "Вопросах статистики"
        res_perc = pd.DataFrame(
            np.column_stack([(dX[0] + dM[0]) / abs((dX_all + dM_all)) * 100, (dX[6] + dM[6]) / abs((dX_all + dM_all)) *
                             100]),
            columns=["Промежуточный спрос, %", "Конечный спрос, %"], index=self.df_d[0].index)
        res_perc.columns.name = "Изменение спроса суммарно"

        res_perc1 = pd.DataFrame(np.column_stack([dX[0] / abs((dX[0] + dM[0])) * 100, dM[0] / abs((dX[0] + dM[0])) *
                                                  100]),
                                 columns=["Отечественная продукция, %", "Импорт, %"], index=self.df_d[0].index)
        res_perc1.columns.name = "Изменение промежуточного спроса"

        res_perc2 = pd.DataFrame(
            np.column_stack([dX[6] / abs((dX[6] + dM[6])) * 100, dM[6] / abs((dX[6] + dM[6])) * 100]),
            columns=["Отечественная продукция, %", "Импорт, %"], index=self.df_d[0].index)
        res_perc2.columns.name = "Изменение конечного спроса"

        results_perc_d = pd.DataFrame(np.column_stack(dX[:6] / abs(dX_all) * 100), index=self.df_d[0].index,
                                      columns=res_columns_perc)
        results_perc_d.columns.name = 'Изменение отечественого выпуска'

        results_perc_m = pd.DataFrame(np.column_stack(dM[:6] / abs(dM_all) * 100), index=self.df_d[0].index,
                                      columns=res_columns_perc)
        results_perc_m.columns.name = 'Изменение импорта'

        # res_perc.loc['Private Households with Employed Persons'] = [0, 100]
        # results_perc_d.loc['Private Households with Employed Persons'] = [""] * 6
        # results_perc_m.loc['Private Households with Employed Persons'] = [""]*6

        # Суммы
        sumss_d = list(map(sum, dX[:6]))
        sumss_m = list(map(sum, dM[:6]))
        sumss = list(map(add, sumss_d, sumss_m))

        # TODO: сделать так, чтобы не приходилось отдельно считать Total для каждой таблицы
        # Добавляем строки с суммой в конец таблиц
        res_check_X.loc['Total'] = [sum(dX[7]), sum(dX[6]), Xtot, sum(self.X[1]) - sum(self.X[0])]
        res_check_M.loc['Total'] = [sum(dM[7]), sum(dM[6]), Mtot, sum(self.M[1]) - sum(self.M[0])]
        result_d.loc['Total'] = sumss_d
        result_m.loc['Total'] = sumss_m

        res_perc.loc['Total'] = [np.round(sum(dX[0] + dM[0]) / abs(sum(dX_all + dM_all)) * 100, 1),
                                 np.round(sum(dX[6] + dM[6]) / abs(sum(dX_all + dM_all)) * 100, 1)]
        res_perc1.loc['Total'] = [np.round(sum(dX[0]) / abs(sum(dX[0] + dM[0])) * 100, 1),
                                  np.round(sum(dM[0]) / abs(sum(dX[0] + dM[0])) * 100, 1)]
        res_perc2.loc['Total'] = [np.round(sum(dX[6]) / abs(sum(dX[6] + dM[6])) * 100, 1),
                                  np.round(sum(dM[6]) / abs(sum(dX[6] + dM[6])) * 100, 1)]
        results_perc_d.loc['Total'] = np.round(sumss_d / abs(sum(dX_all)) * 100, 1)
        results_perc_m.loc['Total'] = np.round(sumss_m / abs(sum(dM_all)) * 100, 1)

        results = pd.DataFrame([sumss_d, sumss_m, sumss], index=res_index, columns=res_columns)
        results.columns.name = 'Изменение выпуска за ' + self.years[0] + "-" + self.years[1]

        results_perc = pd.DataFrame(
            [sumss_d / abs(sum(sumss_d)) * 100, sumss_m / abs(sum(sumss_m)) * 100, sumss / abs(sum(sumss)) * 100],
            index=res_index, columns=res_columns_perc)
        results_perc.columns.name = 'Изменение выпуска за ' + self.years[0] + "-" + self.years[1]



        # Присваиваем имена таблицам и сохраняем в excel
        percented_result_tables = {self.pack_name("Декомпозиция изменений выпуска по всем факторам"): results_perc,
                                   self.pack_name("Декомпозиция изменений отечественного выпуска по всем факторам и "
                                   "по всем отраслям"): results_perc_d,
                                   "Декомпозиция изменений импорта по всем факторам и по всем отраслям за "
                                   + self.my_years + "гг " + self.prices_in: results_perc_m}

        percented_tables = {"Изменения в выпуске и импорте за " + self.my_years + "гг "
                            + self.prices_in: self.results_percents,
                            "Изменение спроса суммарно для отечественной продукции и "
                            "импорта в процентах за " + self.my_years + "гг " + self.prices_in: res_perc,
                            "Изменение промежуточного спроса в процентах за " + self.my_years +
                            "гг " + self.prices_in: res_perc1,
                            "Изменение конечного спроса в процентах за " + self.my_years +
                            "гг " + self.prices_in: res_perc2}

        result_tables = {'Декомпозиция изменений выпуска по всем факторам за ' + self.my_years +
                         'гг ' + self.prices_in: results,
                         'Выпуск отечественной продукци за ' + self.my_years +
                         'гг ' + self.prices_in: result_d,
                         'Импорт за ' + self.my_years +
                         'гг ' + self.prices_in: result_m}
        checking_tables = {'Выпуск отечественной продукци за ' + self.my_years + 'гг ' + self.prices_in: res_check_X,
                           'Импорт за ' + self.my_years + 'гг ' + self.prices_in: res_check_M}

        self.save_to_excel('results_in_percents(Baranov_2018).xlsx',
                           **percented_result_tables)
        self.save_to_excel('changes_in_percents.xlsx', **percented_tables)
        self.save_to_excel('results(Baranov_2018).xlsx', **result_tables)
        self.save_to_excel('для_проверки_(Baranov_2018).xlsx', **checking_tables)

        print("Результат работы метода декомпозиции Baranov_2018 сохранен в папку results!\n")

    def decomposition_Magacho_2018(self):
        """
        Метод декомпозиции из статьи Magacho, G.R., et al., "Impacts of trade liberalization on countries’ sectoral
        structure of production and trade: A structural decomposition analysis." Structural Change and Economics
        Dynamics (2018)

        Декомпозиция по 4 факторам - технологические изменения, импортозамещение, конечный спрос, экспорт(формула 15).
        Также раскладываем суммарный экспорт на directed и indirirected.

        """
        # Колонки для результирующих таблиц
        res_columns = ['Технологические изменения', 'Импортозамещение','Конечный спрос(включая экспорт)',
                       'Экспорт косвенный', 'Экспорт прямой', 'Экспорт суммарный',
                       'dX полученный с помощью метода декомпозиции', 'Разность X1 - X0']

        res_percented_columns = ['Технологические изменения, %', 'Импортозамещение, %',
                       'Конечный спрос(включая экспорт), %', 'Экспорт косвенный, %', 'Экспорт  прямой, %',
                       'Экспорт суммарный, %']


        dA = self.A_m[1] + self.A_d[1] - self.A_m[0] - self.A_d[0]
        sumF = self.F_d[1] + self.F_d[0]

        # Получаем слагаемые декомпозиции изменения выпуска отечественной продукции
        technological_change = (self.L_d[1].dot(dA)).dot(self.L_d[0]).dot(sumF) / 2
        substitution_national_inputs = (self.L_d[1].dot(self.A_m[0] - self.A_m[1])).dot(self.L_d[0]).dot(sumF) / 2
        final_demands = (self.L_d[1] + self.L_d[0]).dot(self.F_d[1] - self.F_d[0]) / 2

        export = self.E[1] - self.E[0]
        export_total = (self.L_d[1] + self.L_d[0]).dot(export) / 2
        export_ind = export_total - export

        dX = technological_change + substitution_national_inputs + final_demands
        dX[dX == 0] = self.eps0

        # Проверяем, что изменения в валовом выпуске, полученные как сумма факторов (dX) сходятся с разностью
        # X[1] - X[0], полученной из таблиц (с точностью до 10^-5)
        assert (sum(self.X[1]) - sum(self.X[0]) - sum(dX) < 1e-5), \
            "Oops! Полученные суммарные изменения в валовом выпуске dX не равны X1 - X0!"


        # Заполняем таблицы
        results = pd.DataFrame(np.column_stack([technological_change, substitution_national_inputs,
                                         final_demands, export_ind, export, export_total, dX,
                                                self.X[1] - self.X[0]]), index=self.df_d[0].index,
                               columns=res_columns)

        results.columns.name = 'Выпуск отечественной продукции'


        results_percented = pd.DataFrame(np.column_stack([technological_change / abs(dX) * 100,
                                                        substitution_national_inputs / abs(dX) * 100,
                                                        final_demands / abs(dX) * 100, export_ind / abs(dX) * 100,
                                                        export / abs(dX) * 100, export_total / abs(dX) * 100]),
                                         index=self.df_d[0].index,columns=res_percented_columns)
        results_percented.columns.name = 'Выпуск отечественной продукции'


        results.loc["Total"] = [sum(technological_change), sum(substitution_national_inputs), sum(final_demands),
                            sum(export_ind), sum(export), sum(export_total), sum(dX), sum(self.X[1]) - sum(self.X[0])]
        results_percented.loc["Total"] = [sum(technological_change) / abs(sum(dX)) * 100,
                                          sum(substitution_national_inputs) / abs(sum(dX)) * 100,
                                         sum(final_demands) / abs(sum(dX)) * 100,
                                          sum(export_ind) / abs(sum(dX)) * 100,
                                          sum(export) / abs(sum(dX)) * 100,
                                          sum(export_total) / abs(sum(dX)) * 100]



        # Присваиваем имена таблицам и сохраняем в excel
        result_tables = {self.pack_name('Выпуск отечественной продукции'): results}
        result_percented_tables = {self.pack_name('Выпуск отечественной продукции'): results_percented}
        self.save_to_excel('results(Magacho_2018).xlsx', **result_tables)
        self.save_to_excel('results_in_percents(Magacho_2018).xlsx', **result_percented_tables)

        print("Результат работы метода декомпозиции Magacho_2018 сохранен в папку results!\n")

    def decomposition_Chenery_extended(self):
        """
        Расширенный метод декомпозиции Chenery.
        """

        res_columns_d = ['Изменения в технологиях', 'Изменения в соотношении отечественных и импортных затрат в '
                         'промежуточном спросе', 'Изменения во внешнем спросе(экспорт)',
                         'Изменение инвестиционного спроса на отечественную продукцию',
                         'Изменение запасов материальных оборотных средств на отечественную продукцию',

                         'Изменения соотношения отечественных и импортных инвестиционных продуктов',
                         'Изменения соотношения отечественных и импортных запасов материальных оборотных средств',
                         'Изменение потребительского спроса домашних хозяйств на отечественную продукцию',
                         'Изменения спроса со стороны государства на отечественную продукцию',
                         'Изменения соотношения отечественной продукции к импортной со стороны домашних хозяйств',
                         'Изменения соотношения отечественной продукции к импортной со стороны государственного '
                         'потербителя',
                         'dX полученный с помощью метода декомпозиции', 'Разность X1 - X0']

        res_index = ['Выпуск отечественной продукции', 'Импорт', 'Всего']
        res_columns_perc = list(map(self.add_percent_to_column_name, res_columns_d[:-2]))
        res_columns_m = res_columns_d[:-2] + ['Реэкспорт', 'dM полученный с помощью метода декомпозиции',
                                              'Разность M1 - M0']
        res_columns_perc_m = list(map(self.add_percent_to_column_name, res_columns_m[:-2]))

        sumL = self.L_d[0] + self.L_d[1]
        sumW = self.A_m[0].dot(self.L_d[0]) + self.A_m[1].dot(self.L_d[1])

        # Вычисляем абсолютные значения изменений величин
        dA = self.A[1] - self.A[0]
        dI = self.In[1] - self.In[0]
        # dC = self.C[1] - self.C[0]

        dI_s = self.I_s[1] - self.I_s[0]
        dI_gfch = self.I_gfch[1] - self.I_gfch[0]
        dC_g = self.C_g[1] - self.C_g[0]
        dC_h = self.C_h[1] - self.C_h[0]

        dR_d = self.R_d[1] - self.R_d[0]
        dR_In= self.R_In[1] - self.R_In[0]
        dR_Is = self.R_Is[1] - self.R_Is[0]
        dR_Igfch = self.R_Igfch[1] - self.R_Igfch[0]
        dR_Cg = self.R_Cg[1] - self.R_Cg[0]
        dR_Ch = self.R_Ch[1] - self.R_Ch[0]

        # Получаем слагаемые декомпозиции изменения выпуска отечественной продукции
        dX = np.array([np.zeros_like(self.M[0])] * 11)
        dX[0] = (self.L_d[0].dot(self.R_d[0] * dA).dot(self.X[1]) +
                 self.L_d[1].dot(self.R_d[1] * dA).dot(self.X[0])) / 2  # изменения технологии
        dX[1] = (self.L_d[0].dot(dR_d * self.A[1]).dot(self.X[1]) +
                 self.L_d[1].dot(dR_d * self.A[0]).dot(self.X[0])) / 2  # изменения соотношения отечественных и
        # импортных промежуточных затрат
        dX[2] = sumL.dot(self.E[1] - self.E[0]) / 2  # изменения во внешнем спросе

        dX[3] = (self.L_d[0].dot(self.R_In[0] * dI) + self.L_d[1].dot(self.R_In[1] * dI)) / 2  # изменения
        # инвестиционного спроса
        dX[4] = (self.L_d[0].dot(self.R_Is[0] * dI_s) + self.L_d[1].dot(self.R_Is[1] * dI_s)) / 2  # изменения
        # запаса материальных средств

        dX[5] = (self.L_d[0].dot(dR_In* self.In[1]) + self.L_d[1].dot(dR_In* self.In[0])) / 2 # изменения соотношения
        #  отечественных и импортных инвестиционных продуктов
        dX[6] = (self.L_d[0].dot(dR_Is * self.I_s[1]) +
                 self.L_d[1].dot(dR_Is * self.I_s[0])) / 2  # изменения соотношения отечественных и импортных запасов
        # материальных оборотных средств

        dX[7] = (self.L_d[0].dot(self.R_Ch[0] * dC_h) + self.L_d[1].dot(self.R_Ch[1] * dC_h)) / 2  # изменения
        # спроса со стороны домашних хозяйств
        dX[8] = (self.L_d[0].dot(self.R_Cg[0] * dC_g) + self.L_d[1].dot(self.R_Cg[1] * dC_g)) / 2  # изменения
        # спроса со стороны государства

        dX[9] = (self.L_d[0].dot(dR_Ch * self.C_h[1]) +
                 self.L_d[1].dot(dR_Ch * self.C_h[0])) / 2  # изменения соотношения отечественной продукции к
        # импортной со стороны домашних хозяйств
        dX[10] = (self.L_d[0].dot(dR_Cg * self.C_g[1]) +
                  self.L_d[1].dot(dR_Cg * self.C_g[0])) / 2  # изменения соотношения отечественной продукции к
        # импортной со стороны государства


        dX_all = sum(dX) - dX[4] - dX[6]
        Xtot = sum(dX_all)

        # Получаем слагаемые декомпозиции изменения импорта
        dM = np.array([np.zeros(len(self.M[0]))] * 12)

        dM[0] = ((dA * self.R_m[0]).dot(self.X[1]) + self.A_m[0].dot((self.L_d[0]).dot(self.R_d[0] * dA)).dot(self.X[1]) +
                 (dA * self.R_m[1]).dot(self.X[0]) +
                 self.A_m[1].dot((self.L_d[1]).dot(self.R_d[1] * dA)).dot(self.X[0])) / 2  # изменения технологии
        dM[1] = (self.A_m[0].dot((self.L_d[0]).dot(dR_d * self.A[1])).dot(self.X[1]) - (dR_d * self.A[1]).dot(self.X[1]) +
                 self.A_m[1].dot((self.L_d[1]).dot(dR_d * self.A[0])).dot(self.X[0]) -
                 (dR_d * self.A[0]).dot(self.X[0])) / 2  # изменения соотношения отечественных и импортных
        # промежуточных затрат
        dM[2] = sumW.dot(self.E[1] - self.E[0]) / 2  # изменения во внешнем спросе

        dM[3] = (self.A_m[0].dot((self.L_d[0]).dot(self.R_In[0] * dI)) + 2 * dI - (self.R_In[0] * dI) +
                 self.A_m[1].dot((self.L_d[1]).dot(self.R_In[1] * dI)) - (self.R_In[1] * dI)) / 2  # изменения
        # инвестиционного спроса
        dM[4] = (self.A_m[0].dot((self.L_d[0]).dot(self.R_Is[0] * dI_s)) + 2 * dI_s - (self.R_Is[0] * dI_s) +
                 self.A_m[1].dot((self.L_d[1]).dot(self.R_Is[1] * dI_s)) - (self.R_Is[1] * dI_s)) / 2  # изменения
        # запаса материальных средств

        dM[5] = (self.A_m[0].dot((self.L_d[0]).dot(dR_In* self.In[1])) - (dR_In* self.In[1]) +
                 self.A_m[1].dot((self.L_d[1]).dot(dR_In* self.In[0])) - (dR_In* self.In[0])) / 2  #
        # изменения соотношения отечественных и импортных инвестиционных продуктов
        dM[6] = (self.A_m[0].dot((self.L_d[0]).dot(dR_Is * self.I_s[1])) - (dR_Is * self.I_s[1]) +
                 self.A_m[1].dot((self.L_d[1]).dot(dR_Is * self.I_s[0])) - (dR_Is * self.I_s[0])) / 2  # изменения соотношения отечественных и импортных запасов
        # материальных оборотных средств

        dM[7] = (self.A_m[0].dot((self.L_d[0]).dot(self.R_Ch[0] * dC_h)) + 2 * dC_h - (self.R_Ch[0] * dC_h) +
                 self.A_m[1].dot((self.L_d[1]).dot(self.R_Ch[1] * dC_h)) - (self.R_Ch[1] * dC_h)) / 2  # изменения
        # спроса со стороны домашних хозяйств
        dM[8] = (self.A_m[0].dot((self.L_d[0]).dot(self.R_Cg[0] * dC_g)) + 2 * dC_g - (self.R_Cg[0] * dC_g) +
                  self.A_m[1].dot((self.L_d[1]).dot(self.R_Cg[1] * dC_g)) - (self.R_Cg[1] * dC_g)) / 2  # изменения
        # спроса со стороны государства

        dM[9] = (self.A_m[0].dot((self.L_d[0]).dot(dR_Ch * self.C_h[1])) - (dR_Ch * self.C_h[1]) +
                 self.A_m[1].dot((self.L_d[1]).dot(dR_Ch * self.C_h[0])) - (dR_Ch * self.C_h[0])) / 2 # изменения
        # соотношения отечественной продукции к импортной со стороны домашних хозяйств
        dM[10] = (self.A_m[0].dot((self.L_d[0]).dot(dR_Cg * self.C_g[1])) - (dR_Cg * self.C_g[1]) +
                 self.A_m[1].dot((self.L_d[1]).dot(dR_Cg * self.C_g[0])) - (dR_Cg * self.C_g[0])) / 2 # изменения
        # соотношения отечественной продукции к импортной со стороны государства




        dM[11] = self.E_r[1] - self.E_r[0]  # реэкспорт

        dM_all = sum(dM) - dM[4] - dM[6]
        Mtot = sum(dM_all)


        # Проверяем, что изменения в валовом выпуске, полученные как сумма факторов (dX_all и dM_all) сходятся с
        # разностями X[1] - X[0] и M[1] - M[0], полученными из таблиц (с точностью до 10^-5)
        assert (sum(self.X[1]) - sum(self.X[0]) - sum(
            dX_all) < 1e-5), "Oops! Полученные суммарные изменения в валовом выпуске dX_all не равны X1 - X0!"
        assert (sum(self.M[1]) - sum(self.M[0]) - sum(
            dM_all) < 1e-5), "Oops! Полученные суммарные изменения в валовом выпуске dM_all не равны M1 - M0!"

        # Суммы
        sumss_d = list(map(sum, dX))
        sumss_m = list(map(sum, dM))
        sumss = list(map(add, sumss_d, sumss_m))
        dX_all[dX_all == 0] = self.eps0
        #dX_all[dX_all == 0] = self.eps0

        # Вывод таблиц
        result_d = pd.DataFrame(np.column_stack([dX[0], dX[1], dX[2], dX[3], dX[4], dX[5], dX[6],
                                                 dX[7], dX[8], dX[9], dX[10], dX_all, self.X[1] - self.X[0]]),
                                columns=res_columns_d,
                                index=self.df_d[0].index)
        result_d.columns.name = 'Выпуск отечественной продукции'
        result_m = pd.DataFrame(np.column_stack([dM[0], dM[1], dM[2], dM[3], dM[4], dM[5], dM[6],
                                                 dM[7], dM[8], dM[9], dM[10], dM[11], dM_all, self.M[1] - self.M[0]]),
                                columns=res_columns_m, index=self.df_d[0].index)
        result_m.columns.name = 'Импорт'

        results_perc_d = pd.DataFrame(np.column_stack(dX[:] / abs(dX_all) * 100.), index=self.df_d[
            0].index, columns=res_columns_perc)
        results_perc_d.columns.name = 'Изменение отечественого выпуска'
        results_perc_m = pd.DataFrame(np.column_stack(dM[:] / abs(dM_all) * 100), index=self.df_d[0].index,
                                      columns=res_columns_perc_m)
        results_perc_m.columns.name = 'Изменение импорта'

        # Добавляем строки с суммой в конец таблиц
        result_d.loc['Total'] = sumss_d + [Xtot] + [sum(self.X[1]) - sum(self.X[0])]
        result_m.loc['Total'] = sumss_m + [Mtot] + [sum(self.M[1]) - sum(self.M[0])]
        results_perc_d.loc['Total'] = np.array(sumss_d) / abs(Xtot) * 100.
        results_perc_m.loc['Total'] = np.array(sumss_m) / abs(sum(dM_all)) * 100.

        # Суммарные результаты
        sumss_m = sumss_m[:-1]
        results = pd.DataFrame([sumss_d, sumss_m, sumss], index=res_index, columns=res_columns_d[:-2])
        results.columns.name = 'Изменение выпуска'

        results_perc = pd.DataFrame(
            [np.array(sumss_d) / abs(sum(sumss_d)) * 100, np.array(sumss_m) / abs(sum(sumss_m)) * 100,
             np.array(sumss) / abs(sum(sumss)) * 100], index=res_index, columns=res_columns_perc)
        results_perc.columns.name = 'Изменение выпуска'

        result_tables = {self.pack_name('Декомпозиция изменений выпуска по всем факторам'): results,
                         self.pack_name('Выпуск отечественной продукци'): result_d,
                         self.pack_name('Импорт за'): result_m}

        percented_result_tables = {self.pack_name("Декомпозиция изменений выпуска по всем факторам"): results_perc,
                                   self.pack_name("Декомпозиция изменений отечественного выпуска по всем факторам и "
                                                  "по всем отраслям"): results_perc_d,
                                   self.pack_name("Декомпозиция изменений импорта по всем факторам и по всем "
                                                  "отраслям"):results_perc_m}

        self.save_to_excel('results(Chenery_extended).xlsx', **result_tables)
        self.save_to_excel('results_in_percents(Chenery_extended).xlsx', **percented_result_tables)

        print("Результат работы метода декомпозиции Chenery_extended сохранен в папку results!\n")

    def save_to_excel(self, file_name, rounding="%.3f", **tables):
        """
        Cохраняет полученные таблицы в выбранный excel-файл

        Parameters
        ----------
        file_name: string
            имя файла
        rounding: string
            Формат округления чисел в сохраняемых таблицах.
            по умолчанию - "%.3f"(до 3 знаков после запятой),
            для результатов в процентах - "%.1f"(до 1 знака после запятой)
        tables: dictionary
            Словарь из названий таблиц и самих таблиц

        """
        writer = pd.ExcelWriter("./results/" + self.my_years + "/" + file_name, engine='xlsxwriter')
        workbook = writer.book

        for table_name, df in tables.items():
            sheet_name = df.columns.name

            df.to_excel(writer, sheet_name=sheet_name, float_format=rounding, startrow=1, startcol=2,
                        header=False, index=False)

            worksheet = writer.sheets[sheet_name]
            worksheet.set_zoom(80)
            worksheet.set_column(2, len(df.columns) + 1, 23)

            # Add a header format
            header_format = workbook.add_format({
                'bold': True,
                'text_wrap': True,
                'align': 'center',
                'valign': 'vcenter',
                'fg_color': '#D7E4BC',
                'border': 1})

            # Add total row formating
            if any(df.index.values == 'Total'):
                total_format = workbook.add_format({'bold': True, 'fg_color': '#ffb74d', 'border': 1})
                worksheet.write_row(np.shape(df)[0], 2, np.array(df.loc['Total', :]), total_format)

            # Add codes & index
            if len(df.index) > len(self.codes):
                codes2 = pd.concat([pd.Series(['']), self.codes])
                worksheet.write_column('A1', codes2, header_format)
            worksheet.write_column('B1', np.insert(df.index.values, 0, ''), header_format)
            worksheet.set_column('B:B', 45)

            # Add header
            columns = np.insert(df.columns.values, 0, table_name)
            for col_num, value in enumerate(columns):
                worksheet.write(0, col_num + 1, value, header_format)
            worksheet.set_row(0, 75)

        writer.save()
        workbook.close()
