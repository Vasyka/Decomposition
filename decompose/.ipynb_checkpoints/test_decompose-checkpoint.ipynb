# %%
import decompose

# %load_ext autoreload
# %autoreload 2
dec = decompose.Decomposition()
dec.prepare_data(path = "./data/задание 1 для студентов.xlsx")

results_16, results_16_perc = dec.decomposition_2016()
res_check_X, res_check_M, result_d, result_m, results18 = dec.decomposition_2018()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Ошибка в таблице " Input-Output Table for 2003 " в строке " Agriculture, Hunting, Forestry and Fishing " должно быть: 67.38396039814415 , написано: 17.437346102019607
#
# Результат работы метода decomposition_2016 сохранен в папку results!
# Результат работы метода decomposition_2018 сохранен в папку results!

# %%
results_16_perc
# Out:
# Валовый выпуск и импорт                            Выпуск 2003 года, млн  \
# AtB Agriculture, Hunting, Forestry and Fishing                   2502.75
# C Mining and Quarrying                                           4768.94
# 15t16 Food, Beverages and Tobacco                                2430.21
# 17t18 Textiles and Textile Products                               283.59
# 19 Leather, Leather and Footwear                                 36.6607
# 20 Wood and Products of Wood and Cork                            248.559
# 21t22 Pulp, Paper, Paper , Printing and Publishing                474.02
# 23 Coke, Refined Petroleum and Nuclear Fuel                         3108
# 24 Chemicals and Chemical Products                               1178.76
# 25 Rubber and Plastics                                           235.043
# 26 Other Non-Metallic Mineral                                    679.357
# 27t28 Basic Metals and Fabricated Metal                          3242.77
# ...

# %%
results_16
# Out:
# Валовый выпуск и импорт                            dX полученный с помощью метода декомпозиции, млн  \
# AtB Agriculture, Hunting, Forestry and Fishing                                              291.257
# C Mining and Quarrying                                                                      481.243
# 15t16 Food, Beverages and Tobacco                                                           755.714
# 17t18 Textiles and Textile Products                                                        -91.4242
# 19 Leather, Leather and Footwear                                                            20.6608
# 20 Wood and Products of Wood and Cork                                                       32.6161
# 21t22 Pulp, Paper, Paper , Printing and Publishing                                          137.591
# 23 Coke, Refined Petroleum and Nuclear Fuel                                                 1280.01
# ...
