# %%
#from decompose import *
'''
# На старых данных:
dec = Decomposition()
path_and_sheetnames = {"./data/задание 1 для студентов.xlsx": [0, 1]}
dec.load_WIOD2013_merged_data(**path_and_sheetnames)
dec.prepare_data(column_order='eng')

# Запускаем методы декомпозиции
dec.decomposition_Baranov_2016()
dec.decomposition_Baranov_2018()
dec.decomposition_Magacho_2018()
'''

# На новых данных:
# Создаем новый экземпляр класса, загружаем данные и готовим их к декомпозиции
dec1 = Decomposition()
path_and_sheetnames1 = {"./data/симметричные таблицы WIOD 2003 и 2010 в ценах 2008 25 декабря.xlsx": [0, 1]}
dec1.load_WIOD2013_merged_data(**path_and_sheetnames1)
dec1.prepare_data(column_order='eng')

# Запускаем методы декомпозиции
dec1.decomposition_Baranov_2016()
dec1.decomposition_Baranov_2018()
dec1.decomposition_Magacho_2018()
dec1.decomposition_Chenery_extended()
# Out:
# Годы таблицы: 2003-2010
#
# Результат работы метода декомпозиции Baranov_2016 сохранен в папку results!
# Результат работы метода декомпозиции Baranov_2018 сохранен в папку results!
#
# Результат работы метода декомпозиции Magacho_2018 сохранен в папку results!
#
# Результат работы метода декомпозиции Chenery_extended сохранен в папку results!

# %%
# Создаем новый экземпляр класса, загружаем данные и готовим их к декомпозиции
dec = Decomposition()
path_and_sheetnames = {"./data/all2011.xlsx": ['SD calculated def', 'SM calculated def'],
                       "./data/all2014 (проверочная).xlsx": ['SD calculated def', 'SM calculated def']}
dec.load_Rosstat_separated_data(**path_and_sheetnames)
dec.prepare_data(column_order='rus')
# Запускаем методы декомпозиции
dec.decomposition_Baranov_2016()
dec.decomposition_Baranov_2018()
dec.decomposition_Magacho_2018()
dec.decomposition_Chenery_extended()
# Out:
# Годы таблицы: 2011-2014
#
# Результат работы метода декомпозиции Baranov_2016 сохранен в папку results!
# Результат работы метода декомпозиции Baranov_2018 сохранен в папку results!
#
# Результат работы метода декомпозиции Magacho_2018 сохранен в папку results!
#
# Результат работы метода декомпозиции Chenery_extended сохранен в папку results!

# %%
# Создаем новый экземпляр класса, загружаем данные и готовим их к декомпозиции
dec = Decomposition()
path_and_sheetnames = {"./data/all2014 (проверочная).xlsx": ['SD calculated def', 'SM calculated def'],
                       "./data/all2015 (проверочная).xlsx": ['SD calculated def', 'SM calculated def']}
dec.load_Rosstat_separated_data(**path_and_sheetnames)
dec.prepare_data(column_order='rus')

# Запускаем методы декомпозиции
dec.decomposition_Baranov_2016()
dec.decomposition_Baranov_2018()
dec.decomposition_Magacho_2018()
dec.decomposition_Chenery_extended()
# Out:
# Годы таблицы: 2014-2015
#
# Результат работы метода декомпозиции Baranov_2016 сохранен в папку results!
# Результат работы метода декомпозиции Baranov_2018 сохранен в папку results!
#
# Результат работы метода декомпозиции Magacho_2018 сохранен в папку results!
#
# Результат работы метода декомпозиции Chenery_extended сохранен в папку results!

# %%
import os
import re
import warnings
from operator import add

import numpy as np
import pandas as pd

# Отключаем warnings
warnings.simplefilter("ignore")
# Расположение 1ого квадранта таблицы и столбцов\строк с названиями в ней
vertical_table_position = slice(5, 75)  # положение и размеры таблицы по вертикали
horizontal_table_position = slice(4, 46)  # положение и размеры таблицы по горизонтали
industries_part_position = slice(4, 39)  # положение и размеры части таблицы с промежуточным потреблением по
# горизонтали
codes_position = 1  # номер строки в таблице с кодами отраслей
columns_names_position = 2  # номер строки в таблице с названиями колонок
rows_names_position = 1  # номер столбца в таблице с названиями строк
countries_names_col = 2 # номер столбца в таблице с названиями стран
countries_names_row = 3  # номер строки в таблице с названиями стран

start_year = 95
end_year = 96
file_path = "./data/raw_wiod13/wiot" + str(start_year) + "_row_apr12.xlsx"
country = "BRA" #Brazil

start = timeit.default_timer()
file = pd.ExcelFile(file_path)
world_df1 = pd.read_excel(file, sheet_name=0)
print(timeit.default_timer() - start,'s')
world_df1.head()
# Out:
# 23.08225313501316 s
#   Intercountry Input-Output Table for 1995 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0          40 countries, in current prices        NaN        NaN        NaN
# 1                   (industry-by-industry)        NaN        NaN        NaN
# 2                        (millions of US$)        NaN        NaN        NaN
# 3                                      NaN        NaN        NaN        NaN
# 4                                      NaN        NaN        NaN        NaN
#
#                                    Unnamed: 4            Unnamed: 5  \
# 0                                         NaN                   NaN
# 1                                         AtB                     C
# 2  Agriculture, Hunting, Forestry and Fishing  Mining and Quarrying
# 3                                         AUS                   AUS
# 4                                          c1                    c2
#
#                     Unnamed: 6                     Unnamed: 7  \
# 0                          NaN                            NaN
# 1                        15t16                          17t18
# 2  Food, Beverages and Tobacco  Textiles and Textile Products
# 3                          AUS                            AUS
# 4                           c3                             c4
#
#                       Unnamed: 8                          Unnamed: 9  \
# 0                            NaN                                 NaN
# 1                             19                                  20
# 2  Leather, Leather and Footwear  Wood and Products of Wood and Cork
# 3                            AUS                                 AUS
# 4                             c5                                  c6
#
#        ...                                           Unnamed: 1635  \
# 0      ...                                                     NaN
# 1      ...                                                     NaN
# 2      ...       Final consumption expenditure by non-profit or...
# 3      ...                                                     USA
# 4      ...                                                     c38
#
#                                  Unnamed: 1636                  Unnamed: 1637  \
# 0                                          NaN                            NaN
# 1                                          NaN                            NaN
# 2  Final consumption expenditure by government  Gross fixed capital formation
# 3                                          USA                            USA
# 4                                          c39                            c41
#
#                           Unnamed: 1638  \
# 0                                   NaN
# 1                                   NaN
# 2  Changes in inventories and valuables
# 3                                   USA
# 4                                   c42
#
#                                  Unnamed: 1639  \
# 0                                          NaN
# 1                                          NaN
# 2  Final consumption expenditure by households
# 3                                          RoW
# 4                                          c37
#
#                                        Unnamed: 1640  \
# 0                                                NaN
# 1                                                NaN
# 2  Final consumption expenditure by non-profit or...
# 3                                                RoW
# 4                                                c38
#
#                                  Unnamed: 1641                  Unnamed: 1642  \
# 0                                          NaN                            NaN
# 1                                          NaN                            NaN
# 2  Final consumption expenditure by government  Gross fixed capital formation
# 3                                          RoW                            RoW
# 4                                          c39                            c41
#
#                           Unnamed: 1643 Unnamed: 1644
# 0                                   NaN           NaN
# 1                                   NaN           NaN
# 2  Changes in inventories and valuables  Total output
# 3                                   RoW           NaN
# 4                                   c42           NaN
#
# [5 rows x 1645 columns]

# %%
countries_col = world_df1.iloc[:,countries_names_col]
countries_row = world_df1.iloc[countries_names_row,:]
vertical_country_position = np.where(countries_col == country)[0]
horizontal_country_position = np.where(countries_row == country)[0]
vertical_country_position
#horizontal_country_position
# Out:
# array([145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157,
#        158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170,
#        171, 172, 173, 174, 175, 176, 177, 178, 179])

# %%
# set columns & index 
columns = world_df1.iloc[columns_names_position,horizontal_country_position].values
index = world_df1.iloc[vertical_country_position, rows_names_position].values
industries_col = world_df1.iloc[:,rows_names_position]

import_df = pd.DataFrame(columns=columns, index = index)
import_df.columns.name = world_df1.columns[0] + ": " + country + " import"


# merge sum import by industries for all countries except chosen
for industry in index:
    industry_indexes = np.where(industries_col == industry)[0]
    
    # get import by industry for all counties except chosen
    import_by_industry = world_df1.iloc[industry_indexes, horizontal_country_position]
    import_by_industry = import_by_industry[countries_col[industry_indexes] != country]
    import_by_industry = import_by_industry.sum(axis=0).values
    
    import_df.loc[industry,:] = import_by_industry

import_df
# Out:
# Intercountry Input-Output Table for 1995: BRA import Agriculture, Hunting, Forestry and Fishing  \
# Agriculture, Hunting, Forestry and Fishing                                               166.98
# Mining and Quarrying                                                                    75.0044
# Food, Beverages and Tobacco                                                             111.159
# Textiles and Textile Products                                                           16.5032
# Leather, Leather and Footwear                                                          0.228756
# Wood and Products of Wood and Cork                                                      1.63325
# Pulp, Paper, Paper , Printing and Publishing                                             2.1944
# Coke, Refined Petroleum and Nuclear Fuel                                                71.0022
# Chemicals and Chemical Products                                                         945.542
# Rubber and Plastics                                                                     17.9129
# Other Non-Metallic Mineral                                                              3.52594
# Basic Metals and Fabricated Metal                                                       9.96753
# Machinery, Nec                                                                          2.21237
# Electrical and Optical Equipment                                                        3.54192
# Transport Equipment                                                                     2.56944
# Manufacturing, Nec; Recycling                                                           1.70696
# Electricity, Gas and Water Supply                                                       9.28485
# Construction                                                                           0.263521
# Sale, Maintenance and Repair of Motor Vehicles ...                                       1.8178
# Wholesale Trade and Commission Trade, Except of...                                      11.0904
# Retail Trade, Except of Motor Vehicles and Moto...                                      3.99509
# Hotels and Restaurants                                                                 0.504424
# Inland Transport                                                                        15.3577
# Water Transport                                                                         1.37038
# Air Transport                                                                           1.78354
# Other Supporting and Auxiliary Transport Activi...                                      7.43116
# Post and Telecommunications                                                             5.23858
# Financial Intermediation                                                                5.97693
# Real Estate Activities                                                                  2.04201
# Renting of M&Eq and Other Business Activities                                          0.717073
# Public Admin and Defence; Compulsory Social Sec...                                      1.36576
# Education                                                                            0.00648975
# Health and Social Work                                                                0.0501952
# Other Community, Social and Personal Services                                           1.93113
# Private Households with Employed Persons                                             0.00283335
#
# Intercountry Input-Output Table for 1995: BRA import Mining and Quarrying  \
# Agriculture, Hunting, Forestry and Fishing                       0.243399
# Mining and Quarrying                                              190.251
# Food, Beverages and Tobacco                                      0.879466
# Textiles and Textile Products                                     10.2557
# Leather, Leather and Footwear                                    0.155857
# Wood and Products of Wood and Cork                               0.247821
# Pulp, Paper, Paper , Printing and Publishing                      5.39358
# Coke, Refined Petroleum and Nuclear Fuel                           25.143
# Chemicals and Chemical Products                                   52.0603
# Rubber and Plastics                                                13.538
# Other Non-Metallic Mineral                                        3.67587
# Basic Metals and Fabricated Metal                                 37.6068
# Machinery, Nec                                                    103.263
# Electrical and Optical Equipment                                  29.6875
# Transport Equipment                                               6.14474
# Manufacturing, Nec; Recycling                                     1.57218
# Electricity, Gas and Water Supply                                 13.3347
# Construction                                                      1.03458
# Sale, Maintenance and Repair of Motor Vehicles ...               0.595056
# Wholesale Trade and Commission Trade, Except of...                4.50096
# Retail Trade, Except of Motor Vehicles and Moto...                1.68315
# Hotels and Restaurants                                            69.3519
# Inland Transport                                                  23.0418
# Water Transport                                                   1.90121
# Air Transport                                                     2.41334
# Other Supporting and Auxiliary Transport Activi...                10.1727
# Post and Telecommunications                                       15.0592
# Financial Intermediation                                          6.68433
# Real Estate Activities                                            48.8166
# Renting of M&Eq and Other Business Activities                     39.2926
# Public Admin and Defence; Compulsory Social Sec...                1.81774
# Education                                                          3.4873
# Health and Social Work                                           0.335438
# Other Community, Social and Personal Services                     2.70208
# Private Households with Employed Persons                      8.95772e-05
#
# Intercountry Input-Output Table for 1995: BRA import Food, Beverages and Tobacco  \
# Agriculture, Hunting, Forestry and Fishing                               931.055
# Mining and Quarrying                                                     7.83841
# Food, Beverages and Tobacco                                              416.879
# Textiles and Textile Products                                            17.0648
# Leather, Leather and Footwear                                           0.308479
# Wood and Products of Wood and Cork                                       1.13224
# Pulp, Paper, Paper , Printing and Publishing                              81.309
# Coke, Refined Petroleum and Nuclear Fuel                                 33.2377
# Chemicals and Chemical Products                                          166.314
# Rubber and Plastics                                                      100.124
# Other Non-Metallic Mineral                                                9.4628
# Basic Metals and Fabricated Metal                                        52.5293
# Machinery, Nec                                                           87.6213
# Electrical and Optical Equipment                                         22.5015
# Transport Equipment                                                      12.5184
# Manufacturing, Nec; Recycling                                             2.6264
# Electricity, Gas and Water Supply                                        23.6461
# Construction                                                            0.788904
# Sale, Maintenance and Repair of Motor Vehicles ...                       4.68852
# Wholesale Trade and Commission Trade, Except of...                       21.0197
# Retail Trade, Except of Motor Vehicles and Moto...                       10.0349
# Hotels and Restaurants                                                   34.6074
# Inland Transport                                                         39.2399
# Water Transport                                                          3.51347
# Air Transport                                                            4.57137
# Other Supporting and Auxiliary Transport Activi...                       18.9861
# Post and Telecommunications                                              12.5589
# Financial Intermediation                                                 21.3897
# Real Estate Activities                                                   13.9425
# Renting of M&Eq and Other Business Activities                            74.5585
# Public Admin and Defence; Compulsory Social Sec...                       2.70039
# Education                                                                6.20321
# Health and Social Work                                                  0.273119
# Other Community, Social and Personal Services                            7.00995
# Private Households with Employed Persons                               0.0180456
#
# Intercountry Input-Output Table for 1995: BRA import Textiles and Textile Products  \
# Agriculture, Hunting, Forestry and Fishing                                 18.8817
# Mining and Quarrying                                                       1.19905
# Food, Beverages and Tobacco                                                 1.9932
# Textiles and Textile Products                                              1097.67
# Leather, Leather and Footwear                                              4.36923
# Wood and Products of Wood and Cork                                        0.322509
# Pulp, Paper, Paper , Printing and Publishing                               8.41461
# Coke, Refined Petroleum and Nuclear Fuel                                   18.0175
# Chemicals and Chemical Products                                            215.422
# Rubber and Plastics                                                        12.8878
# Other Non-Metallic Mineral                                                0.977912
# Basic Metals and Fabricated Metal                                          2.57074
# Machinery, Nec                                                             41.5652
# Electrical and Optical Equipment                                           4.59432
# Transport Equipment                                                        3.32453
# Manufacturing, Nec; Recycling                                              5.84773
# Electricity, Gas and Water Supply                                          13.7758
# Construction                                                               0.14401
# Sale, Maintenance and Repair of Motor Vehicles ...                          1.1744
# Wholesale Trade and Commission Trade, Except of...                         6.42246
# Retail Trade, Except of Motor Vehicles and Moto...                         3.48979
# Hotels and Restaurants                                                   0.0301659
# Inland Transport                                                           7.41831
# Water Transport                                                           0.657497
# Air Transport                                                             0.855338
# Other Supporting and Auxiliary Transport Activi...                         3.57241
# Post and Telecommunications                                                1.51631
# Financial Intermediation                                                   6.60728
# Real Estate Activities                                                     7.64098
# Renting of M&Eq and Other Business Activities                              13.2353
# Public Admin and Defence; Compulsory Social Sec...                         1.08879
# Education                                                                  1.08546
# Health and Social Work                                                   0.0610733
# Other Community, Social and Personal Services                               2.0755
# Private Households with Employed Persons                               0.000386919
#
# Intercountry Input-Output Table for 1995: BRA import Leather, Leather and Footwear  \
# Agriculture, Hunting, Forestry and Fishing                                0.667427
# Mining and Quarrying                                                       2.64576
# Food, Beverages and Tobacco                                                32.3697
# Textiles and Textile Products                                              47.1836
# Leather, Leather and Footwear                                               129.33
# Wood and Products of Wood and Cork                                          0.3682
# Pulp, Paper, Paper , Printing and Publishing                               26.1621
# Coke, Refined Petroleum and Nuclear Fuel                                   4.75887
# Chemicals and Chemical Products                                            136.656
# Rubber and Plastics                                                        18.0589
# Other Non-Metallic Mineral                                                 1.27386
# Basic Metals and Fabricated Metal                                          4.84389
# Machinery, Nec                                                             8.79185
# Electrical and Optical Equipment                                           3.79391
# Transport Equipment                                                        1.01535
# Manufacturing, Nec; Recycling                                              1.16557
# Electricity, Gas and Water Supply                                          3.00307
# Construction                                                             0.0853529
# Sale, Maintenance and Repair of Motor Vehicles ...                        0.634066
# Wholesale Trade and Commission Trade, Except of...                         4.20057
# Retail Trade, Except of Motor Vehicles and Moto...                         2.24871
# Hotels and Restaurants                                                    0.153084
# Inland Transport                                                           3.95596
# Water Transport                                                           0.350544
# Air Transport                                                             0.459051
# Other Supporting and Auxiliary Transport Activi...                         1.90803
# Post and Telecommunications                                                1.96014
# Financial Intermediation                                                   2.21758
# Real Estate Activities                                                     1.60008
# Renting of M&Eq and Other Business Activities                              7.07038
# Public Admin and Defence; Compulsory Social Sec...                        0.236171
# Education                                                                 0.576648
# Health and Social Work                                                   0.0205953
# Other Community, Social and Personal Services                              1.65474
# Private Households with Employed Persons                               9.46294e-06
#
# Intercountry Input-Output Table for 1995: BRA import Wood and Products of Wood and Cork  \
# Agriculture, Hunting, Forestry and Fishing                                      28.2788
# Mining and Quarrying                                                           0.344647
# Food, Beverages and Tobacco                                                    0.315076
# Textiles and Textile Products                                                  0.180726
# Leather, Leather and Footwear                                                 0.0178549
# Wood and Products of Wood and Cork                                              16.0027
# Pulp, Paper, Paper , Printing and Publishing                                    7.61196
# Coke, Refined Petroleum and Nuclear Fuel                                        6.05568
# Chemicals and Chemical Products                                                 25.5719
# Rubber and Plastics                                                             4.91631
# Other Non-Metallic Mineral                                                     0.186142
# Basic Metals and Fabricated Metal                                               5.19799
# Machinery, Nec                                                                  12.2284
# Electrical and Optical Equipment                                                1.39735
# Transport Equipment                                                            0.954971
# Manufacturing, Nec; Recycling                                                  0.288955
# Electricity, Gas and Water Supply                                               3.33147
# Construction                                                                   0.140432
# Sale, Maintenance and Repair of Motor Vehicles ...                             0.155061
# Wholesale Trade and Commission Trade, Except of...                             0.787963
# Retail Trade, Except of Motor Vehicles and Moto...                              0.34926
# Hotels and Restaurants                                                          6.40617
# Inland Transport                                                                2.40207
# Water Transport                                                                 0.21938
# Air Transport                                                                  0.278688
# Other Supporting and Auxiliary Transport Activi...                              1.16614
# Post and Telecommunications                                                     0.59158
# Financial Intermediation                                                        1.46269
# Real Estate Activities                                                         0.942915
# Renting of M&Eq and Other Business Activities                                   2.54144
# Public Admin and Defence; Compulsory Social Sec...                              1.20852
# Education                                                                      0.231004
# Health and Social Work                                                        0.0285171
# Other Community, Social and Personal Services                                   0.22553
# Private Households with Employed Persons                                    3.78412e-06
#
# Intercountry Input-Output Table for 1995: BRA import Pulp, Paper, Paper , Printing and Publishing  \
# Agriculture, Hunting, Forestry and Fishing                                                35.8227
# Mining and Quarrying                                                                      22.6915
# Food, Beverages and Tobacco                                                               3.36943
# Textiles and Textile Products                                                             12.4989
# Leather, Leather and Footwear                                                            0.691679
# Wood and Products of Wood and Cork                                                        2.79945
# Pulp, Paper, Paper , Printing and Publishing                                              506.978
# Coke, Refined Petroleum and Nuclear Fuel                                                  14.7046
# Chemicals and Chemical Products                                                            257.68
# Rubber and Plastics                                                                       46.1601
# Other Non-Metallic Mineral                                                                1.73598
# Basic Metals and Fabricated Metal                                                         19.7258
# Machinery, Nec                                                                             33.901
# Electrical and Optical Equipment                                                          32.2463
# Transport Equipment                                                                       4.58964
# Manufacturing, Nec; Recycling                                                             1.44158
# Electricity, Gas and Water Supply                                                         14.0957
# Construction                                                                             0.279254
# Sale, Maintenance and Repair of Motor Vehicles ...                                        1.12501
# Wholesale Trade and Commission Trade, Except of...                                        6.24101
# Retail Trade, Except of Motor Vehicles and Moto...                                         2.4598
# Hotels and Restaurants                                                                    13.8711
# Inland Transport                                                                          9.34627
# Water Transport                                                                          0.841816
# Air Transport                                                                             1.08627
# Other Supporting and Auxiliary Transport Activi...                                          4.534
# Post and Telecommunications                                                               7.78891
# Financial Intermediation                                                                  8.75311
# Real Estate Activities                                                                    9.44097
# Renting of M&Eq and Other Business Activities                                             48.8485
# Public Admin and Defence; Compulsory Social Sec...                                        2.78473
# Education                                                                                 3.99286
# Health and Social Work                                                                    0.14597
# Other Community, Social and Personal Services                                            0.757851
# Private Households with Employed Persons                                              3.44359e-05
#
# Intercountry Input-Output Table for 1995: BRA import Coke, Refined Petroleum and Nuclear Fuel  \
# Agriculture, Hunting, Forestry and Fishing                                            55.4371
# Mining and Quarrying                                                                  2855.34
# Food, Beverages and Tobacco                                                           5.36414
# Textiles and Textile Products                                                         1.74165
# Leather, Leather and Footwear                                                       0.0337376
# Wood and Products of Wood and Cork                                                  0.0606656
# Pulp, Paper, Paper , Printing and Publishing                                          1.69139
# Coke, Refined Petroleum and Nuclear Fuel                                              306.955
# Chemicals and Chemical Products                                                       30.3365
# Rubber and Plastics                                                                   5.74357
# Other Non-Metallic Mineral                                                            1.52348
# Basic Metals and Fabricated Metal                                                     9.62376
# Machinery, Nec                                                                        26.2192
# Electrical and Optical Equipment                                                      10.8921
# Transport Equipment                                                                   2.61431
# Manufacturing, Nec; Recycling                                                         0.52937
# Electricity, Gas and Water Supply                                                     23.9987
# Construction                                                                         0.408335
# Sale, Maintenance and Repair of Motor Vehicles ...                                    1.52356
# Wholesale Trade and Commission Trade, Except of...                                    119.064
# Retail Trade, Except of Motor Vehicles and Moto...                                     2.3625
# Hotels and Restaurants                                                                13.0877
# Inland Transport                                                                      224.127
# Water Transport                                                                      0.916752
# Air Transport                                                                         1.10516
# Other Supporting and Auxiliary Transport Activi...                                    4.62544
# Post and Telecommunications                                                           4.91958
# Financial Intermediation                                                              3.12317
# Real Estate Activities                                                                22.5458
# Renting of M&Eq and Other Business Activities                                         19.4797
# Public Admin and Defence; Compulsory Social Sec...                                   0.773176
# Education                                                                             1.72659
# Health and Social Work                                                               0.101034
# Other Community, Social and Personal Services                                         5.91223
# Private Households with Employed Persons                                           0.00112455
#
# Intercountry Input-Output Table for 1995: BRA import Chemicals and Chemical Products  \
# Agriculture, Hunting, Forestry and Fishing                                    3.3275
# Mining and Quarrying                                                         195.511
# Food, Beverages and Tobacco                                                  24.9162
# Textiles and Textile Products                                                19.4433
# Leather, Leather and Footwear                                               0.454549
# Wood and Products of Wood and Cork                                           2.11502
# Pulp, Paper, Paper , Printing and Publishing                                 42.6237
# Coke, Refined Petroleum and Nuclear Fuel                                      182.72
# Chemicals and Chemical Products                                               1632.4
# Rubber and Plastics                                                          37.9349
# Other Non-Metallic Mineral                                                   12.7595
# Basic Metals and Fabricated Metal                                            31.8659
# Machinery, Nec                                                               65.6903
# Electrical and Optical Equipment                                             21.0352
# Transport Equipment                                                          6.92883
# Manufacturing, Nec; Recycling                                                2.71985
# Electricity, Gas and Water Supply                                             22.548
# Construction                                                                0.886133
# Sale, Maintenance and Repair of Motor Vehicles ...                           2.64678
# Wholesale Trade and Commission Trade, Except of...                           17.2459
# Retail Trade, Except of Motor Vehicles and Moto...                            5.1301
# Hotels and Restaurants                                                       13.2213
# Inland Transport                                                             19.2975
# Water Transport                                                              1.61174
# Air Transport                                                                2.06707
# Other Supporting and Auxiliary Transport Activi...                           8.65151
# Post and Telecommunications                                                  16.3714
# Financial Intermediation                                                     15.9944
# Real Estate Activities                                                        8.7244
# Renting of M&Eq and Other Business Activities                                62.0488
# Public Admin and Defence; Compulsory Social Sec...                            1.6514
# Education                                                                    5.50896
# Health and Social Work                                                      0.226858
# Other Community, Social and Personal Services                                3.93781
# Private Households with Employed Persons                                 7.80529e-05
#
# Intercountry Input-Output Table for 1995: BRA import Rubber and Plastics  \
# Agriculture, Hunting, Forestry and Fishing                       4.27046
# Mining and Quarrying                                              3.5618
# Food, Beverages and Tobacco                                      4.67025
# Textiles and Textile Products                                    23.9291
# Leather, Leather and Footwear                                   0.328036
# Wood and Products of Wood and Cork                              0.494495
# Pulp, Paper, Paper , Printing and Publishing                     36.2771
# Coke, Refined Petroleum and Nuclear Fuel                         29.8269
# Chemicals and Chemical Products                                  823.629
# Rubber and Plastics                                              66.2422
# Other Non-Metallic Mineral                                       1.95682
# Basic Metals and Fabricated Metal                                20.4065
# Machinery, Nec                                                   32.6088
# Electrical and Optical Equipment                                 15.0387
# Transport Equipment                                              6.90158
# Manufacturing, Nec; Recycling                                    2.06211
# Electricity, Gas and Water Supply                                9.27461
# Construction                                                    0.248452
# Sale, Maintenance and Repair of Motor Vehicles ...               1.18719
# Wholesale Trade and Commission Trade, Except of...               7.09022
# Retail Trade, Except of Motor Vehicles and Moto...               2.17879
# Hotels and Restaurants                                           9.88868
# Inland Transport                                                 6.76598
# Water Transport                                                 0.609491
# Air Transport                                                   0.783943
# Other Supporting and Auxiliary Transport Activi...               3.27365
# Post and Telecommunications                                      6.73054
# Financial Intermediation                                         4.62451
# Real Estate Activities                                           4.86458
# Renting of M&Eq and Other Business Activities                    10.3012
# Public Admin and Defence; Compulsory Social Sec...              0.696794
# Education                                                       0.844826
# Health and Social Work                                          0.094183
# Other Community, Social and Personal Services                    2.68076
# Private Households with Employed Persons                      0.00010035
#
# Intercountry Input-Output Table for 1995: BRA import                 ...                   \
# Agriculture, Hunting, Forestry and Fishing                           ...
# Mining and Quarrying                                                 ...
# Food, Beverages and Tobacco                                          ...
# Textiles and Textile Products                                        ...
# Leather, Leather and Footwear                                        ...
# Wood and Products of Wood and Cork                                   ...
# Pulp, Paper, Paper , Printing and Publishing                         ...
# Coke, Refined Petroleum and Nuclear Fuel                             ...
# Chemicals and Chemical Products                                      ...
# Rubber and Plastics                                                  ...
# Other Non-Metallic Mineral                                           ...
# Basic Metals and Fabricated Metal                                    ...
# Machinery, Nec                                                       ...
# Electrical and Optical Equipment                                     ...
# Transport Equipment                                                  ...
# Manufacturing, Nec; Recycling                                        ...
# Electricity, Gas and Water Supply                                    ...
# Construction                                                         ...
# Sale, Maintenance and Repair of Motor Vehicles ...                   ...
# Wholesale Trade and Commission Trade, Except of...                   ...
# Retail Trade, Except of Motor Vehicles and Moto...                   ...
# Hotels and Restaurants                                               ...
# Inland Transport                                                     ...
# Water Transport                                                      ...
# Air Transport                                                        ...
# Other Supporting and Auxiliary Transport Activi...                   ...
# Post and Telecommunications                                          ...
# Financial Intermediation                                             ...
# Real Estate Activities                                               ...
# Renting of M&Eq and Other Business Activities                        ...
# Public Admin and Defence; Compulsory Social Sec...                   ...
# Education                                                            ...
# Health and Social Work                                               ...
# Other Community, Social and Personal Services                        ...
# Private Households with Employed Persons                             ...
#
# Intercountry Input-Output Table for 1995: BRA import Public Admin and Defence; Compulsory Social Security  \
# Agriculture, Hunting, Forestry and Fishing                                                      3.98974
# Mining and Quarrying                                                                            5.75916
# Food, Beverages and Tobacco                                                                      34.714
# Textiles and Textile Products                                                                   2.51167
# Leather, Leather and Footwear                                                                  0.115878
# Wood and Products of Wood and Cork                                                             0.421102
# Pulp, Paper, Paper , Printing and Publishing                                                    35.0126
# Coke, Refined Petroleum and Nuclear Fuel                                                        70.2389
# Chemicals and Chemical Products                                                                 127.167
# Rubber and Plastics                                                                             3.16104
# Other Non-Metallic Mineral                                                                      1.99194
# Basic Metals and Fabricated Metal                                                               17.1701
# Machinery, Nec                                                                                  25.2883
# Electrical and Optical Equipment                                                                90.2214
# Transport Equipment                                                                             26.5901
# Manufacturing, Nec; Recycling                                                                    2.2864
# Electricity, Gas and Water Supply                                                               43.7877
# Construction                                                                                    3.35438
# Sale, Maintenance and Repair of Motor Vehicles ...                                              1.04874
# Wholesale Trade and Commission Trade, Except of...                                              5.54565
# Retail Trade, Except of Motor Vehicles and Moto...                                              6.39556
# Hotels and Restaurants                                                                          456.646
# Inland Transport                                                                                8.22739
# Water Transport                                                                                 1.17926
# Air Transport                                                                                   1.19953
# Other Supporting and Auxiliary Transport Activi...                                              4.63598
# Post and Telecommunications                                                                     173.448
# Financial Intermediation                                                                        106.081
# Real Estate Activities                                                                          73.1198
# Renting of M&Eq and Other Business Activities                                                   215.657
# Public Admin and Defence; Compulsory Social Sec...                                              4.61202
# Education                                                                                         28.37
# Health and Social Work                                                                          4.08647
# Other Community, Social and Personal Services                                                    6.7537
# Private Households with Employed Persons                                                    0.000180855
#
# Intercountry Input-Output Table for 1995: BRA import    Education  \
# Agriculture, Hunting, Forestry and Fishing                2.16259
# Mining and Quarrying                                        1.577
# Food, Beverages and Tobacco                               16.7122
# Textiles and Textile Products                            0.559489
# Leather, Leather and Footwear                           0.0800665
# Wood and Products of Wood and Cork                       0.295155
# Pulp, Paper, Paper , Printing and Publishing              14.1863
# Coke, Refined Petroleum and Nuclear Fuel                  12.3852
# Chemicals and Chemical Products                           52.7809
# Rubber and Plastics                                      0.934899
# Other Non-Metallic Mineral                                1.21419
# Basic Metals and Fabricated Metal                         2.35359
# Machinery, Nec                                            34.9726
# Electrical and Optical Equipment                          12.2675
# Transport Equipment                                       5.75311
# Manufacturing, Nec; Recycling                             15.8123
# Electricity, Gas and Water Supply                         19.9959
# Construction                                              1.94145
# Sale, Maintenance and Repair of Motor Vehicles ...       0.535904
# Wholesale Trade and Commission Trade, Except of...        2.70632
# Retail Trade, Except of Motor Vehicles and Moto...        2.40668
# Hotels and Restaurants                                    136.309
# Inland Transport                                          5.28153
# Water Transport                                          0.600847
# Air Transport                                            0.661589
# Other Supporting and Auxiliary Transport Activi...        2.75152
# Post and Telecommunications                               53.2172
# Financial Intermediation                                  3.69367
# Real Estate Activities                                    48.4932
# Renting of M&Eq and Other Business Activities             95.2061
# Public Admin and Defence; Compulsory Social Sec...        2.06556
# Education                                                 13.2734
# Health and Social Work                                   0.643491
# Other Community, Social and Personal Services              2.7629
# Private Households with Employed Persons              0.000118598
#
# Intercountry Input-Output Table for 1995: BRA import Health and Social Work  \
# Agriculture, Hunting, Forestry and Fishing                          2.64786
# Mining and Quarrying                                                4.59976
# Food, Beverages and Tobacco                                         17.3162
# Textiles and Textile Products                                       32.1095
# Leather, Leather and Footwear                                      0.390654
# Wood and Products of Wood and Cork                                 0.447344
# Pulp, Paper, Paper , Printing and Publishing                        37.3344
# Coke, Refined Petroleum and Nuclear Fuel                            28.5094
# Chemicals and Chemical Products                                     702.577
# Rubber and Plastics                                                 47.6387
# Other Non-Metallic Mineral                                          16.1718
# Basic Metals and Fabricated Metal                                   12.6143
# Machinery, Nec                                                       16.755
# Electrical and Optical Equipment                                    74.4853
# Transport Equipment                                                 9.35261
# Manufacturing, Nec; Recycling                                       4.02043
# Electricity, Gas and Water Supply                                   19.9179
# Construction                                                        2.72885
# Sale, Maintenance and Repair of Motor Vehicles ...                  1.59012
# Wholesale Trade and Commission Trade, Except of...                  8.64439
# Retail Trade, Except of Motor Vehicles and Moto...                  7.93117
# Hotels and Restaurants                                              503.128
# Inland Transport                                                    11.1472
# Water Transport                                                     1.48848
# Air Transport                                                       1.44368
# Other Supporting and Auxiliary Transport Activi...                  6.13005
# Post and Telecommunications                                         32.6477
# Financial Intermediation                                            4.30597
# Real Estate Activities                                              62.0443
# Renting of M&Eq and Other Business Activities                       143.239
# Public Admin and Defence; Compulsory Social Sec...                  3.81357
# Education                                                           20.5539
# Health and Social Work                                              2.67988
# Other Community, Social and Personal Services                       23.8273
# Private Households with Employed Persons                        0.000148822
#
# Intercountry Input-Output Table for 1995: BRA import Other Community, Social and Personal Services  \
# Agriculture, Hunting, Forestry and Fishing                                                  2.0656
# Mining and Quarrying                                                                       3.34788
# Food, Beverages and Tobacco                                                                11.1473
# Textiles and Textile Products                                                                18.81
# Leather, Leather and Footwear                                                             0.725128
# Wood and Products of Wood and Cork                                                        0.337143
# Pulp, Paper, Paper , Printing and Publishing                                               48.2611
# Coke, Refined Petroleum and Nuclear Fuel                                                    80.053
# Chemicals and Chemical Products                                                            43.6885
# Rubber and Plastics                                                                         29.637
# Other Non-Metallic Mineral                                                                 1.71071
# Basic Metals and Fabricated Metal                                                          5.92565
# Machinery, Nec                                                                             21.1603
# Electrical and Optical Equipment                                                           139.797
# Transport Equipment                                                                        110.943
# Manufacturing, Nec; Recycling                                                              5.44221
# Electricity, Gas and Water Supply                                                          15.6777
# Construction                                                                               1.12115
# Sale, Maintenance and Repair of Motor Vehicles ...                                         1.77485
# Wholesale Trade and Commission Trade, Except of...                                         6.23434
# Retail Trade, Except of Motor Vehicles and Moto...                                         3.66619
# Hotels and Restaurants                                                                     127.752
# Inland Transport                                                                            21.115
# Water Transport                                                                            1.99493
# Air Transport                                                                              2.60712
# Other Supporting and Auxiliary Transport Activi...                                         10.3763
# Post and Telecommunications                                                                 99.451
# Financial Intermediation                                                                   10.8323
# Real Estate Activities                                                                      67.981
# Renting of M&Eq and Other Business Activities                                              116.403
# Public Admin and Defence; Compulsory Social Sec...                                         2.70813
# Education                                                                                  9.88807
# Health and Social Work                                                                    0.689475
# ...
# Financial Intermediation                                                                 89.4258
# Real Estate Activities                                                                   423.086
# Renting of M&Eq and Other Business Activities                                            136.178
# Public Admin and Defence; Compulsory Social Sec...                                       15.3418
# Education                                                                                18.2252
# Health and Social Work                                                                   5.29828
# Other Community, Social and Personal Services                                            65.6531
# Private Households with Employed Persons                                              0.00859668
#
# Intercountry Input-Output Table for 1995: BRA import Final consumption expenditure by non-profit organisations serving households (NPISH)  \
# Agriculture, Hunting, Forestry and Fishing                                                  0.000957279
# Mining and Quarrying                                                                        0.000197931
# Food, Beverages and Tobacco                                                                 1.23939e-07
# Textiles and Textile Products                                                               0.000432603
# Leather, Leather and Footwear                                                                7.5838e-05
# Wood and Products of Wood and Cork                                                          0.000595629
# Pulp, Paper, Paper , Printing and Publishing                                                 0.00202239
# Coke, Refined Petroleum and Nuclear Fuel                                                     1.3795e-05
# Chemicals and Chemical Products                                                             0.000350658
# Rubber and Plastics                                                                         7.97027e-05
# Other Non-Metallic Mineral                                                                   0.00109278
# Basic Metals and Fabricated Metal                                                             0.0345133
# Machinery, Nec                                                                                0.0719369
# Electrical and Optical Equipment                                                              0.0404779
# Transport Equipment                                                                          0.00851809
# Manufacturing, Nec; Recycling                                                               4.34691e-06
# Electricity, Gas and Water Supply                                                           3.93788e-05
# Construction                                                                                 9.4128e-06
# Sale, Maintenance and Repair of Motor Vehicles ...                                          2.82439e-05
# Wholesale Trade and Commission Trade, Except of...                                           0.00101306
# Retail Trade, Except of Motor Vehicles and Moto...                                          0.000879482
# Hotels and Restaurants                                                                       0.00567235
# Inland Transport                                                                              0.0268074
# Water Transport                                                                             3.63365e-08
# Air Transport                                                                               3.36415e-07
# Other Supporting and Auxiliary Transport Activi...                                          2.49175e-05
# Post and Telecommunications                                                                  0.00304111
# Financial Intermediation                                                                    2.68679e-07
# Real Estate Activities                                                                      2.80736e-06
# Renting of M&Eq and Other Business Activities                                               0.000222483
# Public Admin and Defence; Compulsory Social Sec...                                            0.0119567
# Education                                                                                   0.000884056
# Health and Social Work                                                                       0.00807835
# Other Community, Social and Personal Services                                                   6.00803
# Private Households with Employed Persons                                                              0
#
# Intercountry Input-Output Table for 1995: BRA import Final consumption expenditure by government  \
# Agriculture, Hunting, Forestry and Fishing                                           5.85474e-05
# Mining and Quarrying                                                                 7.25723e-07
# Food, Beverages and Tobacco                                                          1.12161e-05
# Textiles and Textile Products                                                         2.8874e-06
# Leather, Leather and Footwear                                                         4.5384e-06
# Wood and Products of Wood and Cork                                                     2.392e-08
# Pulp, Paper, Paper , Printing and Publishing                                          0.00454955
# Coke, Refined Petroleum and Nuclear Fuel                                             1.28752e-08
# Chemicals and Chemical Products                                                       3.1317e-05
# Rubber and Plastics                                                                  2.48623e-06
# Other Non-Metallic Mineral                                                           5.91158e-07
# Basic Metals and Fabricated Metal                                                    6.88662e-06
# Machinery, Nec                                                                       1.88209e-05
# Electrical and Optical Equipment                                                     5.53492e-05
# Transport Equipment                                                                  3.49842e-05
# Manufacturing, Nec; Recycling                                                        2.85256e-07
# Electricity, Gas and Water Supply                                                    1.24192e-05
# Construction                                                                         7.30981e-06
# Sale, Maintenance and Repair of Motor Vehicles ...                                   0.000196556
# Wholesale Trade and Commission Trade, Except of...                                   0.000392598
# Retail Trade, Except of Motor Vehicles and Moto...                                    0.00028227
# Hotels and Restaurants                                                               0.000448809
# Inland Transport                                                                     3.42586e-05
# Water Transport                                                                      1.59332e-08
# Air Transport                                                                         4.3633e-07
# Other Supporting and Auxiliary Transport Activi...                                   1.04015e-05
# Post and Telecommunications                                                           0.00463208
# Financial Intermediation                                                                 1.48445
# Real Estate Activities                                                               0.000154702
# Renting of M&Eq and Other Business Activities                                          0.0699782
# Public Admin and Defence; Compulsory Social Sec...                                      0.643231
# Education                                                                                17.3552
# Health and Social Work                                                                   2.09121
# Other Community, Social and Personal Services                                         0.00237589
# Private Households with Employed Persons                                                       0
#
# Intercountry Input-Output Table for 1995: BRA import Gross fixed capital formation  \
# Agriculture, Hunting, Forestry and Fishing                                 18.7214
# Mining and Quarrying                                                       1.96105
# Food, Beverages and Tobacco                                                2.19297
# Textiles and Textile Products                                              2.50957
# Leather, Leather and Footwear                                             0.742879
# Wood and Products of Wood and Cork                                         2.81693
# Pulp, Paper, Paper , Printing and Publishing                               38.8098
# Coke, Refined Petroleum and Nuclear Fuel                                   1.19675
# Chemicals and Chemical Products                                            25.9443
# Rubber and Plastics                                                        25.3071
# Other Non-Metallic Mineral                                                 6.78383
# Basic Metals and Fabricated Metal                                           291.91
# Machinery, Nec                                                             3860.92
# Electrical and Optical Equipment                                           3701.54
# Transport Equipment                                                        2353.06
# Manufacturing, Nec; Recycling                                              130.348
# Electricity, Gas and Water Supply                                          10.1683
# Construction                                                               68.6132
# Sale, Maintenance and Repair of Motor Vehicles ...                         9.63581
# Wholesale Trade and Commission Trade, Except of...                         40.0218
# Retail Trade, Except of Motor Vehicles and Moto...                         15.2295
# Hotels and Restaurants                                                   0.0336102
# Inland Transport                                                           3.67918
# Water Transport                                                         0.00177087
# Air Transport                                                              0.18176
# Other Supporting and Auxiliary Transport Activi...                       0.0830211
# Post and Telecommunications                                                3.14151
# Financial Intermediation                                                 0.0145843
# Real Estate Activities                                                    0.319955
# Renting of M&Eq and Other Business Activities                              12.1454
# Public Admin and Defence; Compulsory Social Sec...                         18.1924
# Education                                                                  3.55842
# Health and Social Work                                                     2.67161
# Other Community, Social and Personal Services                             0.501676
# Private Households with Employed Persons                                0.00159381
#
# Intercountry Input-Output Table for 1995: BRA import Changes in inventories and valuables
# Agriculture, Hunting, Forestry and Fishing                                              0
# Mining and Quarrying                                                                    0
# Food, Beverages and Tobacco                                                             0
# Textiles and Textile Products                                                           0
# Leather, Leather and Footwear                                                           0
# Wood and Products of Wood and Cork                                                      0
# Pulp, Paper, Paper , Printing and Publishing                                            0
# Coke, Refined Petroleum and Nuclear Fuel                                                0
# Chemicals and Chemical Products                                                         0
# Rubber and Plastics                                                                     0
# Other Non-Metallic Mineral                                                              0
# Basic Metals and Fabricated Metal                                                       0
# Machinery, Nec                                                                          0
# Electrical and Optical Equipment                                                        0
# Transport Equipment                                                                     0
# Manufacturing, Nec; Recycling                                                           0
# Electricity, Gas and Water Supply                                                       0
# Construction                                                                            0
# Sale, Maintenance and Repair of Motor Vehicles ...                                      0
# Wholesale Trade and Commission Trade, Except of...                                      0
# Retail Trade, Except of Motor Vehicles and Moto...                                      0
# Hotels and Restaurants                                                                  0
# Inland Transport                                                                        0
# Water Transport                                                                         0
# Air Transport                                                                           0
# Other Supporting and Auxiliary Transport Activi...                                      0
# Post and Telecommunications                                                             0
# Financial Intermediation                                                                0
# Real Estate Activities                                                                  0
# Renting of M&Eq and Other Business Activities                                           0
# Public Admin and Defence; Compulsory Social Sec...                                      0
# Education                                                                               0
# Health and Social Work                                                                  0
# Other Community, Social and Personal Services                                           0
# Private Households with Employed Persons                                                0
#
# [35 rows x 40 columns]

# %%
# Суммарный импорт из оставльных стран + отечественный выпуск
total_row = np.argwhere(countries_col == "TOT")[0]
import_df2 = world_df1.iloc[total_row,horizontal_country_position]
import_df2.columns = world_df1.iloc[columns_names_position,horizontal_country_position]
import_df2.columns.name = world_df1.columns[0] + ": " + country
import_df2.name = import_df2.columns.name

# Суммарный импорт
import_df2 = import_df2.reset_index() 
import_df2 = import_df2.drop('index',axis = 1)
sum_domestic = pd.DataFrame(df.sum(axis=0))
import_df2 - sum_domestic.T
# Out:
# Intercountry Input-Output Table for 1995: BRA Agriculture, Hunting, Forestry and Fishing  \
# 0                                                                                1501.91
#
# Intercountry Input-Output Table for 1995: BRA Mining and Quarrying  \
# 0                                                          726.343
#
# Intercountry Input-Output Table for 1995: BRA Food, Beverages and Tobacco  \
# 0                                                                 2242.27
#
# Intercountry Input-Output Table for 1995: BRA Textiles and Textile Products  \
# 0                                                                   1508.91
#
# Intercountry Input-Output Table for 1995: BRA Leather, Leather and Footwear  \
# 0                                                                    451.42
#
# Intercountry Input-Output Table for 1995: BRA Wood and Products of Wood and Cork  \
# 0                                                                        132.018
#
# Intercountry Input-Output Table for 1995: BRA Pulp, Paper, Paper , Printing and Publishing  \
# 0                                                                                  1133.43
#
# Intercountry Input-Output Table for 1995: BRA Coke, Refined Petroleum and Nuclear Fuel  \
# 0                                                                              3763.91
#
# Intercountry Input-Output Table for 1995: BRA Chemicals and Chemical Products  \
# 0                                                                     2490.21
#
# Intercountry Input-Output Table for 1995: BRA Rubber and Plastics  \
# 0                                                         1144.34
#
# Intercountry Input-Output Table for 1995: BRA                 ...                   \
# 0                                                             ...
#
# Intercountry Input-Output Table for 1995: BRA Public Admin and Defence; Compulsory Social Security  \
# 0                                                                                        1590.79
#
# Intercountry Input-Output Table for 1995: BRA Education  \
# 0                                               566.594
#
# Intercountry Input-Output Table for 1995: BRA Health and Social Work  \
# 0                                                            1864.23
#
# Intercountry Input-Output Table for 1995: BRA Other Community, Social and Personal Services  \
# 0                                                                                   1038.35
#
# Intercountry Input-Output Table for 1995: BRA Private Households with Employed Persons  \
# 0                                                                                    0
#
# Intercountry Input-Output Table for 1995: BRA Final consumption expenditure by households  \
# 0                                                                                 14182.9
#
# Intercountry Input-Output Table for 1995: BRA Final consumption expenditure by non-profit organisations serving households (NPISH)  \
# 0                                                                                        6.22835
#
# Intercountry Input-Output Table for 1995: BRA Final consumption expenditure by government  \
# 0                                                                                 21.6541
#
# Intercountry Input-Output Table for 1995: BRA Gross fixed capital formation  \
# 0                                                                     10653
#
# Intercountry Input-Output Table for 1995: BRA Changes in inventories and valuables
# 0                                                                      1.85303e-05
#
# [1 rows x 40 columns]

# %%
# Сохраняем обрезанную версию таблицы отечественного выпуска для выбранной страны, добавляем строки и столбцы с названиями
df = world_df1.iloc[vertical_country_position,horizontal_country_position]
df.columns = world_df1.iloc[columns_names_position,horizontal_country_position]
df.columns.name = world_df1.columns[0] + ": " + country
 
df.index = world_df1.iloc[vertical_country_position, rows_names_position]
df.index.name = ""
df.name = df.columns.name
df
# Out:
# Intercountry Input-Output Table for 1995: BRA      Agriculture, Hunting, Forestry and Fishing  \
#
# Agriculture, Hunting, Forestry and Fishing                                            4721.16
# Mining and Quarrying                                                                  189.781
# Food, Beverages and Tobacco                                                           2805.47
# Textiles and Textile Products                                                         104.641
# Leather, Leather and Footwear                                                         2.15487
# Wood and Products of Wood and Cork                                                    101.487
# Pulp, Paper, Paper , Printing and Publishing                                          13.6181
# Coke, Refined Petroleum and Nuclear Fuel                                              723.054
# Chemicals and Chemical Products                                                       3292.75
# Rubber and Plastics                                                                   198.204
# Other Non-Metallic Mineral                                                            51.0638
# Basic Metals and Fabricated Metal                                                     189.146
# Machinery, Nec                                                                        9.41922
# Electrical and Optical Equipment                                                      27.1822
# Transport Equipment                                                                   19.5432
# Manufacturing, Nec; Recycling                                                         20.5074
# Electricity, Gas and Water Supply                                                      289.38
# Construction                                                                         0.458558
# Sale, Maintenance and Repair of Motor Vehicles ...                                    435.514
# Wholesale Trade and Commission Trade, Except of...                                    803.762
# Retail Trade, Except of Motor Vehicles and Moto...                                    1422.61
# Hotels and Restaurants                                                                3.13105
# Inland Transport                                                                      258.626
# Water Transport                                                                        22.275
# Air Transport                                                                         33.4883
# Other Supporting and Auxiliary Transport Activi...                                    116.273
# Post and Telecommunications                                                           89.5493
# Financial Intermediation                                                              613.247
# Real Estate Activities                                                                18.7244
# Renting of M&Eq and Other Business Activities                                         636.914
# Public Admin and Defence; Compulsory Social Sec...                                    31.4796
# Education                                                                            0.695036
# Health and Social Work                                                                10.4769
# Other Community, Social and Personal Services                                         402.765
# Private Households with Employed Persons                                                    0
#
# Intercountry Input-Output Table for 1995: BRA      Mining and Quarrying  \
#
# Agriculture, Hunting, Forestry and Fishing                      5.93831
# Mining and Quarrying                                            380.598
# Food, Beverages and Tobacco                                     18.4093
# Textiles and Textile Products                                   89.2747
# Leather, Leather and Footwear                                    1.4193
# Wood and Products of Wood and Cork                              2.11682
# Pulp, Paper, Paper , Printing and Publishing                    69.7376
# Coke, Refined Petroleum and Nuclear Fuel                        320.876
# Chemicals and Chemical Products                                 196.734
# Rubber and Plastics                                             162.767
# Other Non-Metallic Mineral                                      73.7779
# Basic Metals and Fabricated Metal                                674.92
# Machinery, Nec                                                   463.35
# Electrical and Optical Equipment                                199.599
# Transport Equipment                                             49.6176
# Manufacturing, Nec; Recycling                                   6.86912
# Electricity, Gas and Water Supply                               401.596
# Construction                                                    157.008
# Sale, Maintenance and Repair of Motor Vehicles ...               118.56
# Wholesale Trade and Commission Trade, Except of...              218.808
# Retail Trade, Except of Motor Vehicles and Moto...              387.277
# Hotels and Restaurants                                          101.252
# Inland Transport                                                451.507
# Water Transport                                                 38.8875
# Air Transport                                                   58.4635
# Other Supporting and Auxiliary Transport Activi...              202.988
# Post and Telecommunications                                     156.334
# Financial Intermediation                                        662.061
# Real Estate Activities                                          453.818
# Renting of M&Eq and Other Business Activities                   1111.92
# Public Admin and Defence; Compulsory Social Sec...              48.2637
# Education                                                       9.45223
# Health and Social Work                                          10.4208
# Other Community, Social and Personal Services                   703.143
# Private Households with Employed Persons                              0
#
# Intercountry Input-Output Table for 1995: BRA      Food, Beverages and Tobacco  \
#
# Agriculture, Hunting, Forestry and Fishing                             27232.9
# Mining and Quarrying                                                   19.5123
# Food, Beverages and Tobacco                                            10957.4
# Textiles and Textile Products                                           160.58
# Leather, Leather and Footwear                                          7.07536
# Wood and Products of Wood and Cork                                      40.717
# Pulp, Paper, Paper , Printing and Publishing                           604.349
# Coke, Refined Petroleum and Nuclear Fuel                               503.033
# Chemicals and Chemical Products                                        637.748
# Rubber and Plastics                                                    1221.77
# Other Non-Metallic Mineral                                             215.966
# Basic Metals and Fabricated Metal                                      1073.18
# Machinery, Nec                                                          409.35
# Electrical and Optical Equipment                                       181.714
# Transport Equipment                                                    92.0978
# Manufacturing, Nec; Recycling                                           43.036
# Electricity, Gas and Water Supply                                      730.306
# Construction                                                           50.6119
# Sale, Maintenance and Repair of Motor Vehicles ...                     1065.48
# Wholesale Trade and Commission Trade, Except of...                      1966.4
# Retail Trade, Except of Motor Vehicles and Moto...                      3480.4
# Hotels and Restaurants                                                  54.884
# Inland Transport                                                       893.636
# Water Transport                                                        76.9672
# Air Transport                                                          115.713
# Other Supporting and Auxiliary Transport Activi...                      401.76
# Post and Telecommunications                                            309.421
# Financial Intermediation                                               2190.32
# Real Estate Activities                                                 131.515
# Renting of M&Eq and Other Business Activities                          2200.74
# Public Admin and Defence; Compulsory Social Sec...                     115.781
# Education                                                              5.69687
# Health and Social Work                                                 24.7937
# Other Community, Social and Personal Services                          1391.68
# Private Households with Employed Persons                                     0
#
# Intercountry Input-Output Table for 1995: BRA      Textiles and Textile Products  \
#
# Agriculture, Hunting, Forestry and Fishing                               539.855
# Mining and Quarrying                                                     3.23239
# Food, Beverages and Tobacco                                              35.8492
# Textiles and Textile Products                                            9551.26
# Leather, Leather and Footwear                                            22.3546
# Wood and Products of Wood and Cork                                       1.21857
# Pulp, Paper, Paper , Printing and Publishing                             195.398
# Coke, Refined Petroleum and Nuclear Fuel                                 183.385
# Chemicals and Chemical Products                                          768.299
# Rubber and Plastics                                                       174.88
# Other Non-Metallic Mineral                                                1.1104
# Basic Metals and Fabricated Metal                                        10.8902
# Machinery, Nec                                                           183.309
# Electrical and Optical Equipment                                         20.8716
# Transport Equipment                                                      30.0721
# Manufacturing, Nec; Recycling                                            105.216
# Electricity, Gas and Water Supply                                        434.418
# Construction                                                             15.4384
# Sale, Maintenance and Repair of Motor Vehicles ...                       297.214
# Wholesale Trade and Commission Trade, Except of...                       548.522
# Retail Trade, Except of Motor Vehicles and Moto...                        970.85
# Hotels and Restaurants                                                   1.98195
# Inland Transport                                                         174.352
# Water Transport                                                          15.0166
# Air Transport                                                             22.576
# Other Supporting and Auxiliary Transport Activi...                       78.3849
# Post and Telecommunications                                              60.3692
# Financial Intermediation                                                 677.082
# Real Estate Activities                                                   71.4874
# Renting of M&Eq and Other Business Activities                            429.372
# Public Admin and Defence; Compulsory Social Sec...                       25.0798
# Education                                                                1.78786
# Health and Social Work                                                    7.3014
# Other Community, Social and Personal Services                            271.522
# Private Households with Employed Persons                                       0
#
# Intercountry Input-Output Table for 1995: BRA      Leather, Leather and Footwear  \
#
# Agriculture, Hunting, Forestry and Fishing                               53.6727
# Mining and Quarrying                                                     6.65336
# Food, Beverages and Tobacco                                              840.761
# Textiles and Textile Products                                            257.591
# Leather, Leather and Footwear                                            2129.01
# Wood and Products of Wood and Cork                                       7.72772
# Pulp, Paper, Paper , Printing and Publishing                             175.908
# Coke, Refined Petroleum and Nuclear Fuel                                 32.5646
# Chemicals and Chemical Products                                          479.321
# Rubber and Plastics                                                       218.59
# Other Non-Metallic Mineral                                               20.8235
# Basic Metals and Fabricated Metal                                        97.6049
# Machinery, Nec                                                           44.3903
# Electrical and Optical Equipment                                         31.4011
# Transport Equipment                                                      7.40758
# Manufacturing, Nec; Recycling                                            28.7249
# Electricity, Gas and Water Supply                                        92.7109
# Construction                                                             4.25355
# Sale, Maintenance and Repair of Motor Vehicles ...                       143.635
# Wholesale Trade and Commission Trade, Except of...                       265.086
# Retail Trade, Except of Motor Vehicles and Moto...                       469.185
# Hotels and Restaurants                                                   1.03232
# Inland Transport                                                         98.9806
# Water Transport                                                          8.52502
# Air Transport                                                            12.8165
# Other Supporting and Auxiliary Transport Activi...                       44.4997
# Post and Telecommunications                                               34.272
# Financial Intermediation                                                 226.106
# Real Estate Activities                                                    15.077
# Renting of M&Eq and Other Business Activities                            243.758
# Public Admin and Defence; Compulsory Social Sec...                       10.9878
# Education                                                               0.548036
# Health and Social Work                                                   3.41376
# Other Community, Social and Personal Services                            154.145
# Private Households with Employed Persons                                       0
#
# Intercountry Input-Output Table for 1995: BRA      Wood and Products of Wood and Cork  \
#
# Agriculture, Hunting, Forestry and Fishing                                    538.552
# Mining and Quarrying                                                         0.937635
# Food, Beverages and Tobacco                                                   6.66213
# Textiles and Textile Products                                                0.946828
# Leather, Leather and Footwear                                               0.0305342
# Wood and Products of Wood and Cork                                             1267.4
# Pulp, Paper, Paper , Printing and Publishing                                  61.1369
# Coke, Refined Petroleum and Nuclear Fuel                                      74.0275
# Chemicals and Chemical Products                                               87.9174
# Rubber and Plastics                                                           61.0837
# Other Non-Metallic Mineral                                                    3.13597
# Basic Metals and Fabricated Metal                                             92.4315
# Machinery, Nec                                                                55.4082
# Electrical and Optical Equipment                                              11.7284
# Transport Equipment                                                           7.87533
# Manufacturing, Nec; Recycling                                                 18.3536
# Electricity, Gas and Water Supply                                              104.42
# Construction                                                                  5.24151
# Sale, Maintenance and Repair of Motor Vehicles ...                            32.6428
# Wholesale Trade and Commission Trade, Except of...                            60.2439
# Retail Trade, Except of Motor Vehicles and Moto...                            106.628
# Hotels and Restaurants                                                        9.44354
# Inland Transport                                                              41.6904
# Water Transport                                                               3.59072
# Air Transport                                                                 5.39829
# Other Supporting and Auxiliary Transport Activi...                            18.7432
# Post and Telecommunications                                                   14.4353
# Financial Intermediation                                                      149.812
# Real Estate Activities                                                        8.73061
# Renting of M&Eq and Other Business Activities                                  102.67
# Public Admin and Defence; Compulsory Social Sec...                             5.7506
# Education                                                                    0.248447
# Health and Social Work                                                       0.859421
# Other Community, Social and Personal Services                                 64.9255
# Private Households with Employed Persons                                            0
#
# Intercountry Input-Output Table for 1995: BRA      Pulp, Paper, Paper , Printing and Publishing  \
#
# Agriculture, Hunting, Forestry and Fishing                                              685.188
# Mining and Quarrying                                                                    23.3941
# Food, Beverages and Tobacco                                                             60.9373
# Textiles and Textile Products                                                           101.829
# Leather, Leather and Footwear                                                           8.67187
# Wood and Products of Wood and Cork                                                      102.212
# Pulp, Paper, Paper , Printing and Publishing                                            3829.27
# Coke, Refined Petroleum and Nuclear Fuel                                                102.303
# Chemicals and Chemical Products                                                         891.724
# Rubber and Plastics                                                                     481.377
# Other Non-Metallic Mineral                                                              19.5808
# Basic Metals and Fabricated Metal                                                       288.937
# Machinery, Nec                                                                          142.704
# Electrical and Optical Equipment                                                        60.3862
# Transport Equipment                                                                     19.4788
# Manufacturing, Nec; Recycling                                                           40.9571
# Electricity, Gas and Water Supply                                                        439.05
# Construction                                                                            20.2436
# Sale, Maintenance and Repair of Motor Vehicles ...                                      243.499
# Wholesale Trade and Commission Trade, Except of...                                      449.389
# Retail Trade, Except of Motor Vehicles and Moto...                                       795.39
# Hotels and Restaurants                                                                  21.6035
# Inland Transport                                                                        328.543
# Water Transport                                                                         28.2968
# Air Transport                                                                           42.5414
# Other Supporting and Auxiliary Transport Activi...                                      147.706
# Post and Telecommunications                                                             113.758
# Financial Intermediation                                                                888.072
# Real Estate Activities                                                                  88.7655
# Renting of M&Eq and Other Business Activities                                           809.096
# Public Admin and Defence; Compulsory Social Sec...                                      66.7041
# Education                                                                               3.40682
# Health and Social Work                                                                  6.89527
# Other Community, Social and Personal Services                                           511.648
# Private Households with Employed Persons                                                      0
#
# Intercountry Input-Output Table for 1995: BRA      Coke, Refined Petroleum and Nuclear Fuel  \
#
# Agriculture, Hunting, Forestry and Fishing                                          1598.11
# Mining and Quarrying                                                                8428.16
# Food, Beverages and Tobacco                                                          197.38
# Textiles and Textile Products                                                       19.6643
# Leather, Leather and Footwear                                                      0.192984
# Wood and Products of Wood and Cork                                                 0.702826
# Pulp, Paper, Paper , Printing and Publishing                                        15.5415
# Coke, Refined Petroleum and Nuclear Fuel                                            4073.25
# Chemicals and Chemical Products                                                     137.946
# Rubber and Plastics                                                                 64.6869
# Other Non-Metallic Mineral                                                          15.6328
# Basic Metals and Fabricated Metal                                                   121.978
# Machinery, Nec                                                                      113.962
# Electrical and Optical Equipment                                                    67.0308
# Transport Equipment                                                                  15.925
# Manufacturing, Nec; Recycling                                                       2.28623
# Electricity, Gas and Water Supply                                                   184.167
# Construction                                                                        19.6447
# Sale, Maintenance and Repair of Motor Vehicles ...                                  372.727
# Wholesale Trade and Commission Trade, Except of...                                  687.886
# Retail Trade, Except of Motor Vehicles and Moto...                                  1217.52
# Hotels and Restaurants                                                              21.5627
# Inland Transport                                                                    250.771
# Water Transport                                                                     21.5984
# Air Transport                                                                       32.4711
# Other Supporting and Auxiliary Transport Activi...                                  112.741
# Post and Telecommunications                                                         86.8293
# Financial Intermediation                                                            310.707
# Real Estate Activities                                                              208.019
# Renting of M&Eq and Other Business Activities                                       617.568
# Public Admin and Defence; Compulsory Social Sec...                                  26.8063
# Education                                                                           5.00482
# Health and Social Work                                                               11.379
# Other Community, Social and Personal Services                                       390.531
# Private Households with Employed Persons                                                  0
#
# Intercountry Input-Output Table for 1995: BRA      Chemicals and Chemical Products  \
#
# Agriculture, Hunting, Forestry and Fishing                                 137.522
# Mining and Quarrying                                                       483.143
# Food, Beverages and Tobacco                                                486.495
# Textiles and Textile Products                                               100.41
# Leather, Leather and Footwear                                              2.36509
# Wood and Products of Wood and Cork                                          125.51
# Pulp, Paper, Paper , Printing and Publishing                               414.361
# Coke, Refined Petroleum and Nuclear Fuel                                   2014.17
# Chemicals and Chemical Products                                            5669.07
# Rubber and Plastics                                                        419.003
# Other Non-Metallic Mineral                                                 251.546
# Basic Metals and Fabricated Metal                                          559.752
# Machinery, Nec                                                             278.118
# Electrical and Optical Equipment                                            119.06
# Transport Equipment                                                        38.5393
# Manufacturing, Nec; Recycling                                              15.5587
# Electricity, Gas and Water Supply                                          696.646
# Construction                                                               47.8491
# Sale, Maintenance and Repair of Motor Vehicles ...                         620.494
# Wholesale Trade and Commission Trade, Except of...                         1145.15
# Retail Trade, Except of Motor Vehicles and Moto...                         2026.85
# Hotels and Restaurants                                                      23.255
# Inland Transport                                                           568.839
# Water Transport                                                            48.9931
# Air Transport                                                              73.6562
# Other Supporting and Auxiliary Transport Activi...                         255.738
# Post and Telecommunications                                                 196.96
# Financial Intermediation                                                   1634.61
# Real Estate Activities                                                     81.5927
# Renting of M&Eq and Other Business Activities                              1400.87
# Public Admin and Defence; Compulsory Social Sec...                         80.9197
# Education                                                                  6.67323
# Health and Social Work                                                      16.115
# Other Community, Social and Personal Services                              885.867
# Private Households with Employed Persons                                         0
#
# Intercountry Input-Output Table for 1995: BRA      Rubber and Plastics  \
#
# Agriculture, Hunting, Forestry and Fishing                     131.576
# Mining and Quarrying                                           9.94812
# Food, Beverages and Tobacco                                    24.1487
# Textiles and Textile Products                                  172.764
# Leather, Leather and Footwear                                 0.867553
# Wood and Products of Wood and Cork                             8.90845
# Pulp, Paper, Paper , Printing and Publishing                   310.734
# Coke, Refined Petroleum and Nuclear Fuel                       169.978
# Chemicals and Chemical Products                                2807.18
# Rubber and Plastics                                            794.195
# Other Non-Metallic Mineral                                     7.97827
# Basic Metals and Fabricated Metal                              288.656
# Machinery, Nec                                                 142.694
# Electrical and Optical Equipment                               109.129
# Transport Equipment                                            46.1431
# Manufacturing, Nec; Recycling                                  30.8016
# Electricity, Gas and Water Supply                              288.789
# Construction                                                   13.7596
# Sale, Maintenance and Repair of Motor Vehicles ...              239.15
# Wholesale Trade and Commission Trade, Except of...             441.363
# Retail Trade, Except of Motor Vehicles and Moto...             781.185
# Hotels and Restaurants                                         15.9036
# Inland Transport                                               177.491
# Water Transport                                                 15.287
# Air Transport                                                  22.9824
# Other Supporting and Auxiliary Transport Activi...             79.7963
# Post and Telecommunications                                    61.4561
# Financial Intermediation                                        471.37
# Real Estate Activities                                         45.2515
# Renting of M&Eq and Other Business Activities                  437.103
# Public Admin and Defence; Compulsory Social Sec...             26.9682
# Education                                                      1.37577
# Health and Social Work                                         6.68473
# Other Community, Social and Personal Services                  276.411
# Private Households with Employed Persons                             0
#
# Intercountry Input-Output Table for 1995: BRA                      ...                   \
#                                                                    ...
# Agriculture, Hunting, Forestry and Fishing                         ...
# Mining and Quarrying                                               ...
# Food, Beverages and Tobacco                                        ...
# Textiles and Textile Products                                      ...
# Leather, Leather and Footwear                                      ...
# Wood and Products of Wood and Cork                                 ...
# Pulp, Paper, Paper , Printing and Publishing                       ...
# Coke, Refined Petroleum and Nuclear Fuel                           ...
# Chemicals and Chemical Products                                    ...
# Rubber and Plastics                                                ...
# Other Non-Metallic Mineral                                         ...
# Basic Metals and Fabricated Metal                                  ...
# Machinery, Nec                                                     ...
# Electrical and Optical Equipment                                   ...
# Transport Equipment                                                ...
# Manufacturing, Nec; Recycling                                      ...
# Electricity, Gas and Water Supply                                  ...
# Construction                                                       ...
# Sale, Maintenance and Repair of Motor Vehicles ...                 ...
# Wholesale Trade and Commission Trade, Except of...                 ...
# Retail Trade, Except of Motor Vehicles and Moto...                 ...
# Hotels and Restaurants                                             ...
# Inland Transport                                                   ...
# Water Transport                                                    ...
# Air Transport                                                      ...
# Other Supporting and Auxiliary Transport Activi...                 ...
# Post and Telecommunications                                        ...
# Financial Intermediation                                           ...
# Real Estate Activities                                             ...
# Renting of M&Eq and Other Business Activities                      ...
# Public Admin and Defence; Compulsory Social Sec...                 ...
# Education                                                          ...
# Health and Social Work                                             ...
# Other Community, Social and Personal Services                      ...
# Private Households with Employed Persons                           ...
#
# Intercountry Input-Output Table for 1995: BRA      Public Admin and Defence; Compulsory Social Security  \
#
# Agriculture, Hunting, Forestry and Fishing                                                    119.916
# Mining and Quarrying                                                                          11.2797
# Food, Beverages and Tobacco                                                                   859.744
# Textiles and Textile Products                                                                 57.6722
# Leather, Leather and Footwear                                                                 1.31289
# Wood and Products of Wood and Cork                                                            17.6315
# Pulp, Paper, Paper , Printing and Publishing                                                  444.596
# Coke, Refined Petroleum and Nuclear Fuel                                                      917.125
# Chemicals and Chemical Products                                                               407.355
# Rubber and Plastics                                                                           20.7838
# Other Non-Metallic Mineral                                                                    36.5793
# Basic Metals and Fabricated Metal                                                             337.318
# Machinery, Nec                                                                                66.2852
# Electrical and Optical Equipment                                                              207.959
# Transport Equipment                                                                            124.02
# Manufacturing, Nec; Recycling                                                                 31.2701
# Electricity, Gas and Water Supply                                                             1341.39
# Construction                                                                                  1418.53
# Sale, Maintenance and Repair of Motor Vehicles ...                                            206.362
# Wholesale Trade and Commission Trade, Except of...                                            380.851
# Retail Trade, Except of Motor Vehicles and Moto...                                            674.083
# Hotels and Restaurants                                                                        659.411
# Inland Transport                                                                              1692.53
# Water Transport                                                                               145.774
# Air Transport                                                                                 219.157
# Other Supporting and Auxiliary Transport Activi...                                            760.926
# Post and Telecommunications                                                                   586.037
# Financial Intermediation                                                                      10890.8
# Real Estate Activities                                                                        680.758
# Renting of M&Eq and Other Business Activities                                                 4168.15
# Public Admin and Defence; Compulsory Social Sec...                                            153.506
# Education                                                                                     76.5751
# Health and Social Work                                                                        17.2443
# Other Community, Social and Personal Services                                                 2635.81
# Private Households with Employed Persons                                                            0
#
# Intercountry Input-Output Table for 1995: BRA      Education  \
#
# Agriculture, Hunting, Forestry and Fishing           69.1211
# Mining and Quarrying                                 2.34911
# Food, Beverages and Tobacco                          412.999
# Textiles and Textile Products                        7.34249
# Leather, Leather and Footwear                        0.75316
# Wood and Products of Wood and Cork                   2.82608
# Pulp, Paper, Paper , Printing and Publishing         302.911
# Coke, Refined Petroleum and Nuclear Fuel             154.028
# Chemicals and Chemical Products                      168.841
# Rubber and Plastics                                  4.18986
# Other Non-Metallic Mineral                           24.1592
# Basic Metals and Fabricated Metal                    17.7507
# Machinery, Nec                                       130.968
# Electrical and Optical Equipment                     14.9896
# Transport Equipment                                  7.39077
# Manufacturing, Nec; Recycling                        509.632
# Electricity, Gas and Water Supply                    620.037
# Construction                                         1387.41
# Sale, Maintenance and Repair of Motor Vehicles ...   114.548
# Wholesale Trade and Commission Trade, Except of...   211.403
# Retail Trade, Except of Motor Vehicles and Moto...   374.171
# Hotels and Restaurants                               197.482
# Inland Transport                                     657.536
# Water Transport                                      56.6324
# Air Transport                                        85.1412
# Other Supporting and Auxiliary Transport Activi...   295.615
# Post and Telecommunications                          227.672
# Financial Intermediation                             338.216
# Real Estate Activities                               451.744
# Renting of M&Eq and Other Business Activities         1619.3
# Public Admin and Defence; Compulsory Social Sec...   75.8926
# Education                                             41.997
# Health and Social Work                               10.2652
# Other Community, Social and Personal Services           1024
# Private Households with Employed Persons                   0
#
# Intercountry Input-Output Table for 1995: BRA      Health and Social Work  \
#
# Agriculture, Hunting, Forestry and Fishing                        67.3399
# Mining and Quarrying                                              10.7793
# Food, Beverages and Tobacco                                       335.095
# Textiles and Textile Products                                     453.316
# Leather, Leather and Footwear                                     2.08322
# Wood and Products of Wood and Cork                                3.77272
# Pulp, Paper, Paper , Printing and Publishing                      467.539
# Coke, Refined Petroleum and Nuclear Fuel                          188.021
# Chemicals and Chemical Products                                   2381.35
# Rubber and Plastics                                               563.875
# Other Non-Metallic Mineral                                        368.535
# Basic Metals and Fabricated Metal                                 229.146
# Machinery, Nec                                                    39.7414
# Electrical and Optical Equipment                                  217.175
# Transport Equipment                                               18.0232
# Manufacturing, Nec; Recycling                                     14.3736
# Electricity, Gas and Water Supply                                 605.407
# Construction                                                       626.84
# Sale, Maintenance and Repair of Motor Vehicles ...                312.404
# Wholesale Trade and Commission Trade, Except of...                576.557
# Retail Trade, Except of Motor Vehicles and Moto...                1020.47
# Hotels and Restaurants                                            729.985
# Inland Transport                                                  847.748
# Water Transport                                                    73.015
# Air Transport                                                     109.771
# Other Supporting and Auxiliary Transport Activi...                 381.13
# Post and Telecommunications                                       293.532
# Financial Intermediation                                           378.15
# Real Estate Activities                                            576.236
# Renting of M&Eq and Other Business Activities                     2087.73
# Public Admin and Defence; Compulsory Social Sec...                113.264
# Education                                                         59.5503
# Health and Social Work                                            17.5943
# Other Community, Social and Personal Services                     1320.22
# Private Households with Employed Persons                                0
#
# Intercountry Input-Output Table for 1995: BRA      Other Community, Social and Personal Services  \
#
# Agriculture, Hunting, Forestry and Fishing                                               58.0459
# Mining and Quarrying                                                                     8.33045
# Food, Beverages and Tobacco                                                              279.876
# Textiles and Textile Products                                                            327.729
# Leather, Leather and Footwear                                                            9.78369
# Wood and Products of Wood and Cork                                                       5.87545
# Pulp, Paper, Paper , Printing and Publishing                                             1212.15
# Coke, Refined Petroleum and Nuclear Fuel                                                 1071.72
# Chemicals and Chemical Products                                                          140.143
# Rubber and Plastics                                                                      355.546
# Other Non-Metallic Mineral                                                               32.6518
# Basic Metals and Fabricated Metal                                                        52.1703
# Machinery, Nec                                                                           57.0938
# Electrical and Optical Equipment                                                         442.498
# Transport Equipment                                                                      676.572
# Manufacturing, Nec; Recycling                                                            149.605
# Electricity, Gas and Water Supply                                                        468.648
# Construction                                                                             150.781
# Sale, Maintenance and Repair of Motor Vehicles ...                                       327.211
# Wholesale Trade and Commission Trade, Except of...                                       603.885
# Retail Trade, Except of Motor Vehicles and Moto...                                       1068.84
# Hotels and Restaurants                                                                   187.549
# Inland Transport                                                                         1195.58
# Water Transport                                                                          102.973
# Air Transport                                                                             154.81
# Other Supporting and Auxiliary Transport Activi...                                        537.51
# Post and Telecommunications                                                               413.97
# Financial Intermediation                                                                 1072.91
# Real Estate Activities                                                                     633.2
# Renting of M&Eq and Other Business Activities                                            2944.34
# Public Admin and Defence; Compulsory Social Sec...                                       134.892
# Education                                                                                15.5489
# ...
# Real Estate Activities                                                                 51928.2
# Renting of M&Eq and Other Business Activities                                          27896.2
# Public Admin and Defence; Compulsory Social Sec...                                     1143.27
# Education                                                                              10885.9
# Health and Social Work                                                                 15290.4
# Other Community, Social and Personal Services                                          17640.7
# Private Households with Employed Persons                                                     0
#
# Intercountry Input-Output Table for 1995: BRA      Final consumption expenditure by non-profit organisations serving households (NPISH)  \
#
# Agriculture, Hunting, Forestry and Fishing                                                          0
# Mining and Quarrying                                                                                0
# Food, Beverages and Tobacco                                                                         0
# Textiles and Textile Products                                                                       0
# Leather, Leather and Footwear                                                                       0
# Wood and Products of Wood and Cork                                                                  0
# Pulp, Paper, Paper , Printing and Publishing                                                        0
# Coke, Refined Petroleum and Nuclear Fuel                                                            0
# Chemicals and Chemical Products                                                                     0
# Rubber and Plastics                                                                                 0
# Other Non-Metallic Mineral                                                                          0
# Basic Metals and Fabricated Metal                                                                   0
# Machinery, Nec                                                                                      0
# Electrical and Optical Equipment                                                                    0
# Transport Equipment                                                                                 0
# Manufacturing, Nec; Recycling                                                                       0
# Electricity, Gas and Water Supply                                                                   0
# Construction                                                                                        0
# Sale, Maintenance and Repair of Motor Vehicles ...                                                  0
# Wholesale Trade and Commission Trade, Except of...                                                  0
# Retail Trade, Except of Motor Vehicles and Moto...                                                  0
# Hotels and Restaurants                                                                              0
# Inland Transport                                                                              1708.28
# Water Transport                                                                               147.131
# Air Transport                                                                                 221.197
# Other Supporting and Auxiliary Transport Activi...                                            768.007
# Post and Telecommunications                                                                   591.491
# Financial Intermediation                                                                            0
# Real Estate Activities                                                                              0
# Renting of M&Eq and Other Business Activities                                                 4206.94
# Public Admin and Defence; Compulsory Social Sec...                                            4.78497
# Education                                                                                    0.480199
# Health and Social Work                                                                        644.801
# Other Community, Social and Personal Services                                                 2660.34
# Private Households with Employed Persons                                                            0
#
# Intercountry Input-Output Table for 1995: BRA      Final consumption expenditure by government  \
#
# Agriculture, Hunting, Forestry and Fishing                                                   0
# Mining and Quarrying                                                                         0
# Food, Beverages and Tobacco                                                                  0
# Textiles and Textile Products                                                                0
# Leather, Leather and Footwear                                                                0
# Wood and Products of Wood and Cork                                                           0
# Pulp, Paper, Paper , Printing and Publishing                                                 0
# Coke, Refined Petroleum and Nuclear Fuel                                                     0
# Chemicals and Chemical Products                                                              0
# Rubber and Plastics                                                                          0
# Other Non-Metallic Mineral                                                                   0
# Basic Metals and Fabricated Metal                                                            0
# Machinery, Nec                                                                               0
# Electrical and Optical Equipment                                                             0
# Transport Equipment                                                                          0
# Manufacturing, Nec; Recycling                                                                0
# Electricity, Gas and Water Supply                                                            0
# Construction                                                                                 0
# Sale, Maintenance and Repair of Motor Vehicles ...                                           0
# Wholesale Trade and Commission Trade, Except of...                                           0
# Retail Trade, Except of Motor Vehicles and Moto...                                           0
# Hotels and Restaurants                                                                       0
# Inland Transport                                                                      0.886113
# Water Transport                                                                      0.0763192
# Air Transport                                                                         0.114739
# Other Supporting and Auxiliary Transport Activi...                                     0.39838
# Post and Telecommunications                                                           0.306814
# Financial Intermediation                                                               720.784
# Real Estate Activities                                                                       0
# Renting of M&Eq and Other Business Activities                                          2.18221
# Public Admin and Defence; Compulsory Social Sec...                                     95382.6
# Education                                                                              35423.6
# Health and Social Work                                                                 29146.7
# Other Community, Social and Personal Services                                          1.37996
# Private Households with Employed Persons                                                     0
#
# Intercountry Input-Output Table for 1995: BRA      Gross fixed capital formation  \
#
# Agriculture, Hunting, Forestry and Fishing                               4104.46
# Mining and Quarrying                                                     10.2204
# Food, Beverages and Tobacco                                              97.4924
# Textiles and Textile Products                                            58.6321
# Leather, Leather and Footwear                                            6.47462
# Wood and Products of Wood and Cork                                       80.0825
# Pulp, Paper, Paper , Printing and Publishing                             20.9171
# Coke, Refined Petroleum and Nuclear Fuel                                 1.46882
# Chemicals and Chemical Products                                          53.3491
# Rubber and Plastics                                                      85.6268
# Other Non-Metallic Mineral                                                27.608
# Basic Metals and Fabricated Metal                                        3298.41
# Machinery, Nec                                                           9269.68
# Electrical and Optical Equipment                                         13120.2
# Transport Equipment                                                      8363.64
# Manufacturing, Nec; Recycling                                            3408.94
# Electricity, Gas and Water Supply                                        4.39724
# Construction                                                             62049.4
# Sale, Maintenance and Repair of Motor Vehicles ...                       1746.16
# Wholesale Trade and Commission Trade, Except of...                       3222.62
# Retail Trade, Except of Motor Vehicles and Moto...                       5703.83
# Hotels and Restaurants                                                   12.8047
# Inland Transport                                                         537.715
# Water Transport                                                          46.3124
# Air Transport                                                            69.6262
# Other Supporting and Auxiliary Transport Activi...                       241.746
# Post and Telecommunications                                              186.184
# Financial Intermediation                                                 32.6153
# Real Estate Activities                                                   1184.62
# Renting of M&Eq and Other Business Activities                            1324.22
# Public Admin and Defence; Compulsory Social Sec...                       51.8243
# Education                                                                21.7944
# Health and Social Work                                                   57.5856
# Other Community, Social and Personal Services                            837.397
# Private Households with Employed Persons                                       0
#
# Intercountry Input-Output Table for 1995: BRA      Changes in inventories and valuables
#
# Agriculture, Hunting, Forestry and Fishing                                     -376.238
# Mining and Quarrying                                                            351.266
# Food, Beverages and Tobacco                                                     10.2303
# Textiles and Textile Products                                                   500.884
# Leather, Leather and Footwear                                                   414.741
# Wood and Products of Wood and Cork                                             -63.4262
# Pulp, Paper, Paper , Printing and Publishing                                    155.035
# Coke, Refined Petroleum and Nuclear Fuel                                       -359.465
# Chemicals and Chemical Products                                                -496.501
# Rubber and Plastics                                                             296.272
# Other Non-Metallic Mineral                                                      352.536
# Basic Metals and Fabricated Metal                                              -335.355
# Machinery, Nec                                                                 -251.988
# Electrical and Optical Equipment                                               -455.443
# Transport Equipment                                                            -1275.98
# Manufacturing, Nec; Recycling                                                  -129.296
# Electricity, Gas and Water Supply                                                     0
# Construction                                                                          0
# Sale, Maintenance and Repair of Motor Vehicles ...                             -35.0478
# Wholesale Trade and Commission Trade, Except of...                             -64.6825
# Retail Trade, Except of Motor Vehicles and Moto...                             -114.484
# Hotels and Restaurants                                                        -0.250266
# Inland Transport                                                               -9.31189
# Water Transport                                                               -0.802016
# Air Transport                                                                  -1.20575
# Other Supporting and Auxiliary Transport Activi...                             -4.18643
# Post and Telecommunications                                                    -3.22424
# Financial Intermediation                                                              0
# Real Estate Activities                                                       -0.0346428
# Renting of M&Eq and Other Business Activities                                  -22.9322
# Public Admin and Defence; Compulsory Social Sec...                              2.72135
# Education                                                                    -0.0291215
# Health and Social Work                                                        -0.923376
# Other Community, Social and Personal Services                                  -14.5016
# Private Households with Employed Persons                                              0
#
# [35 rows x 40 columns]

# %%
import os
import re
import warnings
from operator import add

import numpy as np
import pandas as pd

# Отключаем warnings
warnings.simplefilter("ignore")


class Decomposition(object):
    """
    Класс с методами необходимыми для декомпозиции.

    Пользовательские методы:
    ------------------------
    - load_WIOD2013_merged_data(**path_and_sheetnames) - чтение данных из таблиц WIOD release 2013. Таблицы
    отечественного выпуска и импорта находятся на одной странице, данные за разные годы лежат в одном файле.
    - load_Rosstat_separated_data(**path_and_sheetnames) - чтение данных из таблиц Росстата. Таблицы отечественного
    выпуска и импорта находятся на разных страницах, данные за разные годы лежат в разных файлах.
    - prepare_data(column_order) - подготовка данных перед декомпозицией

    Методы декомпозиции:
    --------------------
    - decomposition_Baranov_2016() - декомпозиция из статьи в "Вопросах статистики" 2016 год по 2м факторам.
    - decomposition_Baranov_2018() - декомпозиция по статье "Методологические проблемы использования метода структурной
    декомпозиции в модели "затраты – выпуск" на современном этапе" (2018) - по 6 факторам - промежуточный спрос,
    внешний спрос, спрос домашних хозяйств, спрос государства, валовое накопление основного капитала,
    изменение материальных оборотных средств
    - decomposition_Magacho_2018() - декомпозиция из статьи Magacho, G.R., et al., "Impacts of trade liberalization
    on countries’ sectoral structure of production and trade: A structural decomposition analysis." Structural Change
    and Economics Dynamics (2018) - по 4 факторам - технологические изменения, импортозамещение, конечный спрос, экспорт(формула 15).
    Также раскладываем суммарный экспорт на directed и indirirected.
    - decomposition_Chenery() - декомпозиция Chenery

    Методы используемые для внутренних операций:
    --------------------------------------------
    - get_by_name(name) - возвращает столбец по номеру столбца с конца из матриц обоих годов для отечественной
    продукции и импорта
    - get_table(df) - возвращает матрицы затрат на покупку продуктов одних отраслей для производства продуктов других
    отраслей
    - check_sums_equality(Z, F, Total) - проверяет правильность полученной таблицы X или M с точностью до 10^-8
    - save_to_excel(file_name, rounding="%.3f", **tables) - сохраняет полученные таблицы в выбранный excel-файл
    - pack_name(str) - приклеивает к строке годы, к которым относится содержание строки, и если было указано, то год,
    для которого были пересчитаны цены в таблице
    - add_percent_to_column_name(str) - добавляет знак процента для названий колонок таблиц.
    - divide_or_put_zero(X,Y) - производит деление вектора X на Y, если Y != 0, остальное заполняет нулями.

    """

    def __init__(self):
        self.prices_in = ""  # в каких ценах пересчитаны таблицы
        self.years = []  # годы за которые приведены таблицы
        self.df_d = []  # таблицы отечественного выпуска
        self.df_m = []  # таблицы импорта
        self.eps0 = 1e-20 # хранит число на которое заменяются нули в таблице

    def load_WIOD2013_merged_data(self, **path_and_sheetnames):
        """
        Чтение данных из таблиц WIOD release 2013. Таблицы отечественного выпуска и импорта находятся на одной
        странице, данные за разные годы лежат в одном файле.

        Parameters
        ----------
        path_and_sheetnames: dictionary
            путь к excel-файлу и страницы в excel-файле

        """

        # Расположение 1ого квадранта таблицы и столбцов\строк с названиями в ней
        vertical_table_position = slice(5, 75)  # положение и размеры таблицы по вертикали
        horizontal_table_position = slice(4, 46)  # положение и размеры таблицы по горизонтали
        industries_part_position = slice(4, 39)  # положение и размеры части таблицы с промежуточным потреблением по
        # горизонтали
        codes_position = 1  # номер строки в таблице с кодами отраслей
        columns_names_position = 2  # номер строки в таблице с названиями колонок
        rows_names_position = 1  # номер столбца в таблице с названиями строк


        df_all = []
        for path, sheetnames in path_and_sheetnames.items():
            file = pd.ExcelFile(path)
            for sheetname in sheetnames:
                df1 = pd.read_excel(file, sheet_name=sheetname)

                # Получаем имена столбцов и строк
                rows = df1.iloc[vertical_table_position, rows_names_position]
                rows.name = ""
                columns = df1.iloc[columns_names_position, horizontal_table_position]
                columns.name = df1.columns[0]

                # Получаем из таблицы коды отраслей (одинаковые по вертикали и горизонтали)
                self.codes = df1.iloc[codes_position, industries_part_position]

                # Сохраняем обрезанную версию таблицы
                df = df1.iloc[vertical_table_position, horizontal_table_position]
                df.columns = columns
                df.index = rows
                df.name = columns.name

                df_all.append(df)
                self.years.append(re.search("\d+", columns.name).group(0))

            #print("Обрабатываем данные из таблицы \"" + columns.name + "\"")
            self.prices_in = "(в ценах " + re.search("\d+", df1.iloc[0, 0]).group(0) + "года)"

            # Делим таблицы на отечественный выпуск и импорт
            self.df_d = [df_all[0].iloc[:35], df_all[1].iloc[:35]]
            self.df_m = [df_all[0].iloc[35:], df_all[1].iloc[35:]]

    def load_Rosstat_separated_data(self, **path_and_sheetnames):
        """
        Чтение данных из таблиц Росстата. Таблицы отечественного выпуска и импорта находятся на разных страницах,
        данные за разные годы лежат в разных файлах.

        Parameters
        ----------
        path_and_sheetnames: dictionary
            путь к excel-файлу и страницы в excel-файле

        """

        # Расположение таблицы и столбцов\строк с названиями в ней
        vertical_table_position = slice(3, 62)  # положение и размеры таблицы по вертикали
        horizontal_table_position = slice(3, 69)  # положение и размеры таблицы по горизонтали
        industries_part_position = slice(3, 62)  # положение и размеры части таблицы с промежуточным потреблением по
        # горизонтали
        codes_position = 1  # номер строки в таблице с кодами отраслей
        columns_names_position = 0  # номер строки в таблице с названиями колонок
        rows_names_position = 2  # номер столбца в таблице с названиями строк


        for path, sheetnames in path_and_sheetnames.items():
            file = pd.ExcelFile(path)
            for i, sheetname in enumerate(sheetnames):
                df1 = pd.read_excel(file, sheet_name=sheetname)

                # Получаем имена столбцов и строк
                rows = df1.iloc[vertical_table_position, rows_names_position]
                rows.name = ""
                columns = df1.iloc[columns_names_position, horizontal_table_position]
                columns.name = df1.columns[0]

                # Получаем из таблицы коды отраслей (одинаковые по вертикали и горизонтали)
                self.codes = df1.iloc[codes_position, industries_part_position]

                # Сохраняем обрезанную версию таблицы
                df = df1.iloc[vertical_table_position, horizontal_table_position]
                df.columns = columns
                df.index = rows
                df.name = columns.name

                # Делим таблицы на отечественный выпуск и импорт
                if not i:
                    self.df_d.append(df)
                else:
                    self.df_m.append(df)

            #print("Обрабатываем данные из таблицы \"" + columns.name + "\"")
            self.years.append(re.search("\d+", columns.name).group(0))

    def get_by_pos(self, pos):
        """
        Возвращает столбец по номеру столбца с конца из матриц обоих годов для отечественной продукции и импорта
        """
        get_by_pos0 = lambda df: df.iloc[:, pos]
        res_m = np.array(list(map(get_by_pos0, self.df_m)))
        res_d = np.array(list(map(get_by_pos0, self.df_d)))
        return res_m, res_d

    def get_table(self, df):
        """
        Возвращает матрицы затрат на покупку продуктов одних отраслей для производства продуктов других отраслей
        """
        return df.iloc[:, :-7]

    def pack_name(self, str):
        """
        Приклеивает к строке годы, к которым относится содержание строки, и если было указано, то год, для которого были
        пересчитаны цены в таблице

        str: string
            строка-название таблицы\страницы файла
        """
        return str + " за " + self.my_years + "гг " + self.prices_in

    def check_sums_equality(self, Z, F, Total):
        """
        Проверяет правильность полученной таблицы X или M с точностью до 10^-8
        """
        for year in [0, 1]:
            z = Z[year]
            f = F[year]
            total = Total[year]
            for i in range(len(total)):
                if (abs(sum(z.iloc[i]) + f[i] - total[i]) >= 1e-8):
                    #print("Ошибка в таблице \"", z.columns.name, "\" в строке \"", z.columns[i],
                         # "\" должно быть:", sum(z.iloc[i]) + f[i], ", написано:", total[i])
                    Total[year][i] = sum(z.iloc[i]) + f[i]
        return Total

    def divide_or_put_zero(self,X,Y):
        """
        Производит деление вектора X на Y, если Y != 0, остальное заполняет нулями.
        """
        res = np.zeros_like(X)
        mask = Y != 0.
        res[mask] = X[mask] / Y[mask]
        return res

    def add_percent_to_column_name(self,s):
        """
        Добавляет знак процента для названий колонок таблиц.
        """
        return s + ", %"

    def prepare_data(self, column_order):
        """
        Подготовка данных перед декомпозицией

        column_order: string
            Порядок столбцов в таблице "eng" - households, NPISH, government or "rus" - households, government, NPISH
        """
        self.columns = self.df_d[0].columns.values
        self.my_years = self.years[0] + "-" + self.years[1]
        length = len(self.columns) - 7
        os.makedirs("./results/" + self.my_years, exist_ok=True)
        print("Годы таблицы:", self.my_years)

        if column_order == 'eng':
            self.C_mnpish, self.C_dnpish = self.get_by_pos(-6)
            self.C_mg, self.C_dg = self.get_by_pos(-5)
        else:
            self.C_mg, self.C_dg = self.get_by_pos(-6)
            self.C_mnpish, self.C_dnpish = self.get_by_pos(-5)

        self.C_mh, self.C_dh = self.get_by_pos(-7)
        self.I_mgfch, self.I_dgfch = self.get_by_pos(-4)
        self.I_ms, self.I_ds = self.get_by_pos(-3)
        self.E_r, self.E = self.get_by_pos(-2)
        self.M, self.X = self.get_by_pos(-1)

        Z_m = list(map(self.get_table, self.df_m))
        Z_d = list(map(self.get_table, self.df_d))

        # Заменяем нули на выбранный eps0
        self.X[self.X == 0] = self.eps0
        self.M[self.M == 0] = self.eps0

        # Вычисляем суммы столбцов таблицы
        self.I_m = self.I_mgfch + self.I_ms
        self.I_d = self.I_dgfch + self.I_ds
        self.C_mh = self.C_mh + self.C_mnpish
        self.C_dh = self.C_dh + self.C_dnpish
        self.C_m = self.C_mg + self.C_mh
        self.C_d = self.C_dg + self.C_dh
        self.F_m = self.I_m + self.C_m + self.E_r
        self.F_d = self.I_d + self.C_d + self.E

        # Получаем суммарные показатели для импорта и отечественной продукции
        self.I_s = self.I_ds + self.I_ms
        self.I_gfch = self.I_dgfch + self.I_mgfch
        self.In = self.I_d + self.I_m
        self.C_g = self.C_dg + self.C_mg
        self.C_h = self.C_dh + self.C_mh
        self.C = self.C_d + self.C_m

        # Проверяем правильность столбцов суммарного выпуска
        self.M = self.check_sums_equality(Z_m, self.F_m, self.M)
        self.X = self.check_sums_equality(Z_d, self.F_d, self.X)

        # TODO: Переписать для pandas dataframe
        # Вычисляем матрицы технических коэффициентов
        self.A_d = [(Z_d[0] / self.X[0]).astype('float'), (Z_d[1] / self.X[1]).astype('float')]
        self.A_m = [Z_m[0] / self.X[0], Z_m[1] / self.X[1]]
        self.A = [(self.A_d[0] + self.A_m[0]).astype('float'), (self.A_d[1] + self.A_m[1]).astype('float')]

        I = np.eye(length, dtype='float')
        self.U = np.ones((length,length), dtype='float')
        self.L_d = [np.linalg.inv(((I - A).astype('float'))) for A in self.A_d]

        # Доли отечественной\импортной составляющей в общих технологических коэффициентах
        self.R_d = [self.A_d[0] / self.A[0], self.A_d[1] / self.A[1]]
        self.R_d[0][self.A[0] == 0] = 0
        self.R_d[1][self.A[1] == 0] = 0
        self.R_m = [self.U - self.R_d[0], self.U - self.R_d[1]]

        # Доля отечественной составляющей в общем ивестиционном спросе
        self.R_In = self.divide_or_put_zero(self.I_d, self.In)
        self.R_Is = self.divide_or_put_zero(self.I_ds, self.I_s)
        self.R_Igfch = self.divide_or_put_zero(self.I_dgfch, self.I_gfch)

        # Доля отечественной составляющей в общем потребительском спросе
        self.R_C = self.divide_or_put_zero(self.C_d, self.C)
        self.R_Cg = self.divide_or_put_zero(self.C_dg, self.C_g)
        self.R_Ch = self.divide_or_put_zero(self.C_dh, self.C_h)

    def decomposition_Baranov_2016(self):
        """
        Метод декомпозиции из статьи в "Вопросах статистики" 2016 год. Декомпозиция по 2м факторам.

        """
        columns = ['dX полученный с помощью метода декомпозиции, млн', 'Разность X1 - X0, млн',
                   'dM полученный с помощью метода декомпозиции, млн', 'Разность M1 - M0, млн']
        columns_perc = ['Выпуск ' + self.years[0] + ' года, млн', 'Выпуск ' + self.years[1] + ' года, млн',
                        'Выпуск ' + self.years[1] + ' года к ' + self.years[0] + ' году, %',
                        'Импорт ' + self.years[0] + ' года, млн', 'Импорт ' + self.years[1] + ' года, млн',
                        'Импорт ' + self.years[1] + ' года к ' + self.years[0] + ' году, %']

        WL0 = self.A_m[0].dot(self.L_d[0])
        WL1 = self.A_m[1].dot(self.L_d[1])

        dX = ((self.L_d[1] + self.L_d[0]).dot(self.F_d[1] - self.F_d[0]) + (self.L_d[1] - self.L_d[0]).dot(
            self.F_d[1] + self.F_d[0])) / 2

        dM = ((WL1 + WL0).dot(self.F_d[1] - self.F_d[0]) + (WL1 - WL0).dot(self.F_d[1] + self.F_d[0])) / 2 + \
             self.F_m[1] - self.F_m[0]

        dX_perc = (self.X[1] / self.X[0]) * 100
        dM_perc = (self.M[1] / self.M[0]) * 100

        # Вывод таблиц
        results = pd.DataFrame(np.column_stack([dX, self.X[1] - self.X[0], dM, self.M[1] - self.M[0]]),
                               columns=columns, index=self.df_d[0].index)
        results.loc["Total"] = [sum(dX), sum(self.X[1]) - sum(self.X[0]), sum(dM), sum(self.M[1]) - sum(self.M[0])]
        results.columns.name = 'Изменения в выпуске и импорте'

        self.results_percents = pd.DataFrame(
            np.column_stack([self.X[0], self.X[1], dX_perc, self.M[0], self.M[1], dM_perc]),
            columns=columns_perc,
            index=self.df_d[0].index)
        self.results_percents.loc["Total"] = [sum(self.X[0]), sum(self.X[1]), (sum(self.X[1]) / sum(self.X[0])) * 100,
                                              sum(self.M[0]), sum(self.M[1]), (sum(self.M[1]) / sum(self.M[0])) * 100]
        self.results_percents.columns.name = 'Изменения в выпуске и импорте'

        # Проверяем, что изменения в валовом выпуске, полученные как сумма факторов (dX и dM) сходятся с разностями
        # X[1] - X[0] и M[1] - M[0], полученными из таблиц (с точностью до 10^-5)
        assert (sum(self.X[1]) - sum(self.X[0]) - sum(
            dX) < 1e-5), "Oops! Полученные суммарные изменения в валовом выпуске dX не равны X1 - X0!"
        assert (sum(self.M[1]) - sum(self.M[0]) - sum(
            dM) < 1e-5), "Oops! Полученные суммарные изменения в валовом выпуске dM не равны M1 - M0!"

        result_tables = {
            "Упрощенная декомпозиция изменений в выпуске и импорте за " + self.my_years + "гг " + self.prices_in: results}
        self.save_to_excel('results_simple(Baranov_2016).xlsx', **result_tables)

        print("\nРезультат работы метода декомпозиции Baranov_2016 сохранен в папку results!")

    def decomposition_Baranov_2018(self):
        """
        Метод декомпозиции из статьи "Методологические проблемы использования метода структурной декомпозиции
        в модели "затраты – выпуск" на современном этапе" (2018).

        Декомпозиция по 6 факторам - промежуточный спрос, внешний спрос, спрос домашних хозяйств, спрос
        государства, валовое накопление основного капитала, изменение материальных оборотных средств

        """
        # Колонки для результирующих таблиц
        columns_X = ['Конечный спрос через формулу для декомпозиции 16 года',
                  'Конечный спрос как сумма факторов', 'dX полученный с помощью метода декомпозиции',
                  'Разность X1 - X0']
        columns_M = ['Конечный спрос через формулу для декомпозиции 16 года',
                  'Конечный спрос как сумма факторов', 'dM полученный с помощью метода декомпозиции',
                  'Разность M1 - M0']
        res_columns = ['Промежуточный спрос', 'Внешний спрос', 'Спрос домашних хозяйств', 'Спрос государства',
                    'Валовое накопление основного капитала', 'Изменение запаса материальных оборотных средств']
        res_index = ['Выпуск отечественной продукции', 'Импорт', 'Всего']
        res_columns_perc = ['Промежуточный спрос, %', 'Внешний спрос, %', 'Спрос домашних хозяйств, %',
                         'Спрос государства, %', 'Валовое накопление основного капитала, %',
                         'Изменение запаса материальных оборотных средств, %']

        sumL = self.L_d[0] + self.L_d[1]
        sumW = self.A_m[0].dot(self.L_d[0]) + self.A_m[1].dot(self.L_d[1])

        # Получаем слагаемые декомпозиции изменения выпуска отечественной продукции
        dX = np.array([np.zeros(len(self.M[0]))] * 8)
        dX[0] = ((self.L_d[1] - self.L_d[0]).dot(self.F_d[1] + self.F_d[0])) / 2
        dX[1] = sumL.dot(self.E[1] - self.E[0]) / 2
        dX[2] = sumL.dot(self.C_dh[1] - self.C_dh[0]) / 2
        dX[3] = sumL.dot(self.C_dg[1] - self.C_dg[0]) / 2
        dX[4] = sumL.dot(self.I_dgfch[1] - self.I_dgfch[0]) / 2
        dX[5] = sumL.dot(self.I_ds[1] - self.I_ds[0]) / 2
        dX_all = dX[0] + dX[1] + dX[2] + dX[3] + dX[4] + dX[5]
        Xtot = sum(dX_all)

        dX[6] = dX[1] + dX[2] + dX[3] + dX[4] + dX[5]
        dX[7] = ((self.L_d[1] + self.L_d[0]).dot(self.F_d[1] - self.F_d[0])) / 2

        # Получаем слагаемые декомпозиции изменения импорта
        dM = np.array([np.zeros(len(self.M[0]))] * 8)
        dM[0] = ((self.A_m[1] - self.A_m[0]).dot(self.L_d[1].dot(self.F_d[1]) + self.L_d[0].dot(self.F_d[0])) +
                 self.A_m[0].dot(self.L_d[1] - self.L_d[0]).dot(self.F_d[1]) + self.A_m[1].dot(
            self.L_d[1] - self.L_d[0]).dot(self.F_d[0])) / 2

        dM[1] = self.E_r[1] - self.E_r[0] + sumW.dot(self.E[1] - self.E[0]) / 2
        dM[2] = self.C_mh[1] - self.C_mh[0] + sumW.dot(self.C_dh[1] - self.C_dh[0]) / 2
        dM[3] = self.C_mg[1] - self.C_mg[0] + sumW.dot(self.C_dg[1] - self.C_dg[0]) / 2
        dM[4] = self.I_mgfch[1] - self.I_mgfch[0] + sumW.dot(self.I_dgfch[1] - self.I_dgfch[0]) / 2
        dM[5] = self.I_ms[1] - self.I_ms[0] + sumW.dot(self.I_ds[1] - self.I_ds[0]) / 2
        dM_all = dM[0] + dM[1] + dM[2] + dM[3] + dM[4] + dM[5]
        Mtot = sum(dM_all)

        dM[6] = dM[1] + dM[2] + dM[3] + dM[4] + dM[5]
        dM[7] = ((self.A_m[1].dot(self.L_d[1]) + self.A_m[0].dot(self.L_d[0])).dot(self.F_d[1] - self.F_d[0])) / 2 + (
            self.F_m[1] - self.F_m[0])

        # Проверяем, что изменения в валовом выпуске, полученные как сумма факторов (dX_all и dM_all) сходятся с
        # разностями X[1] - X[0] и M[1] - M[0], полученными из таблиц (с точностью до 10^-5)
        assert (sum(self.X[1]) - sum(self.X[0]) - sum(
            dX_all) < 1e-5), "Oops! Полученные суммарные изменения в валовом выпуске dX_all не равны X1 - X0!"
        assert (sum(self.M[1]) - sum(self.M[0]) - sum(
            dM_all) < 1e-5), "Oops! Полученные суммарные изменения в валовом выпуске dM_all не равны M1 - M0!"

        # Вывод таблиц
        result_d = pd.DataFrame(np.column_stack(dX[:6]), columns=res_columns, index=self.df_d[0].index)
        result_d.columns.name = 'Выпуск отечественной продукции'
        result_m = pd.DataFrame(np.column_stack(dM[:6]), columns=res_columns, index=self.df_d[0].index)
        result_m.columns.name = 'Импорт'

        res_check_X = pd.DataFrame(np.column_stack([dX[7], dX[6], dX_all, self.X[1] - self.X[0]]),
                                   columns=columns_X, index=self.df_d[0].index)
        res_check_X.columns.name = 'Выпуск отечественной продукци'
        res_check_M = pd.DataFrame(np.column_stack([dM[7], dM[6], dM_all, self.M[1] - self.M[0]]),
                                   columns=columns_M, index=self.df_d[0].index)
        res_check_M.columns.name = 'Импорт'

        # Вывод таблиц в процентах - таблицы аналогичные полученным в "Вопросах статистики"
        res_perc = pd.DataFrame(
            np.column_stack([(dX[0] + dM[0]) / abs((dX_all + dM_all)) * 100, (dX[6] + dM[6]) / abs((dX_all + dM_all)) *
                             100]),
            columns=["Промежуточный спрос, %", "Конечный спрос, %"], index=self.df_d[0].index)
        res_perc.columns.name = "Изменение спроса суммарно"

        res_perc1 = pd.DataFrame(np.column_stack([dX[0] / abs((dX[0] + dM[0])) * 100, dM[0] / abs((dX[0] + dM[0])) *
                                                  100]),
                                 columns=["Отечественная продукция, %", "Импорт, %"], index=self.df_d[0].index)
        res_perc1.columns.name = "Изменение промежуточного спроса"

        res_perc2 = pd.DataFrame(
            np.column_stack([dX[6] / abs((dX[6] + dM[6])) * 100, dM[6] / abs((dX[6] + dM[6])) * 100]),
            columns=["Отечественная продукция, %", "Импорт, %"], index=self.df_d[0].index)
        res_perc2.columns.name = "Изменение конечного спроса"

        results_perc_d = pd.DataFrame(np.column_stack(dX[:6] / abs(dX_all) * 100), index=self.df_d[0].index,
                                      columns=res_columns_perc)
        results_perc_d.columns.name = 'Изменение отечественого выпуска'

        results_perc_m = pd.DataFrame(np.column_stack(dM[:6] / abs(dM_all) * 100), index=self.df_d[0].index,
                                      columns=res_columns_perc)
        results_perc_m.columns.name = 'Изменение импорта'

        # res_perc.loc['Private Households with Employed Persons'] = [0, 100]
        # results_perc_d.loc['Private Households with Employed Persons'] = [""] * 6
        # results_perc_m.loc['Private Households with Employed Persons'] = [""]*6

        # Суммы
        sumss_d = list(map(sum, dX[:6]))
        sumss_m = list(map(sum, dM[:6]))
        sumss = list(map(add, sumss_d, sumss_m))

        # TODO: сделать так, чтобы не приходилось отдельно считать Total для каждой таблицы
        # Добавляем строки с суммой в конец таблиц
        res_check_X.loc['Total'] = [sum(dX[7]), sum(dX[6]), Xtot, sum(self.X[1]) - sum(self.X[0])]
        res_check_M.loc['Total'] = [sum(dM[7]), sum(dM[6]), Mtot, sum(self.M[1]) - sum(self.M[0])]
        result_d.loc['Total'] = sumss_d
        result_m.loc['Total'] = sumss_m

        res_perc.loc['Total'] = [np.round(sum(dX[0] + dM[0]) / abs(sum(dX_all + dM_all)) * 100, 1),
                                 np.round(sum(dX[6] + dM[6]) / abs(sum(dX_all + dM_all)) * 100, 1)]
        res_perc1.loc['Total'] = [np.round(sum(dX[0]) / abs(sum(dX[0] + dM[0])) * 100, 1),
                                  np.round(sum(dM[0]) / abs(sum(dX[0] + dM[0])) * 100, 1)]
        res_perc2.loc['Total'] = [np.round(sum(dX[6]) / abs(sum(dX[6] + dM[6])) * 100, 1),
                                  np.round(sum(dM[6]) / abs(sum(dX[6] + dM[6])) * 100, 1)]
        results_perc_d.loc['Total'] = np.round(sumss_d / abs(sum(dX_all)) * 100, 1)
        results_perc_m.loc['Total'] = np.round(sumss_m / abs(sum(dM_all)) * 100, 1)

        results = pd.DataFrame([sumss_d, sumss_m, sumss], index=res_index, columns=res_columns)
        results.columns.name = 'Изменение выпуска за ' + self.years[0] + "-" + self.years[1]

        results_perc = pd.DataFrame(
            [sumss_d / abs(sum(sumss_d)) * 100, sumss_m / abs(sum(sumss_m)) * 100, sumss / abs(sum(sumss)) * 100],
            index=res_index, columns=res_columns_perc)
        results_perc.columns.name = 'Изменение выпуска за ' + self.years[0] + "-" + self.years[1]



        # Присваиваем имена таблицам и сохраняем в excel
        percented_result_tables = {self.pack_name("Декомпозиция изменений выпуска по всем факторам"): results_perc,
                                   self.pack_name("Декомпозиция изменений отечественного выпуска по всем факторам и "
                                   "по всем отраслям"): results_perc_d,
                                   "Декомпозиция изменений импорта по всем факторам и по всем отраслям за "
                                   + self.my_years + "гг " + self.prices_in: results_perc_m}

        percented_tables = {"Изменения в выпуске и импорте за " + self.my_years + "гг "
                            + self.prices_in: self.results_percents,
                            "Изменение спроса суммарно для отечественной продукции и "
                            "импорта в процентах за " + self.my_years + "гг " + self.prices_in: res_perc,
                            "Изменение промежуточного спроса в процентах за " + self.my_years +
                            "гг " + self.prices_in: res_perc1,
                            "Изменение конечного спроса в процентах за " + self.my_years +
                            "гг " + self.prices_in: res_perc2}

        result_tables = {'Декомпозиция изменений выпуска по всем факторам за ' + self.my_years +
                         'гг ' + self.prices_in: results,
                         'Выпуск отечественной продукци за ' + self.my_years +
                         'гг ' + self.prices_in: result_d,
                         'Импорт за ' + self.my_years +
                         'гг ' + self.prices_in: result_m}
        checking_tables = {'Выпуск отечественной продукци за ' + self.my_years + 'гг ' + self.prices_in: res_check_X,
                           'Импорт за ' + self.my_years + 'гг ' + self.prices_in: res_check_M}

        self.save_to_excel('results_in_percents(Baranov_2018).xlsx',
                           **percented_result_tables)
        self.save_to_excel('changes_in_percents.xlsx', **percented_tables)
        self.save_to_excel('results(Baranov_2018).xlsx', **result_tables)
        self.save_to_excel('для_проверки_(Baranov_2018).xlsx', **checking_tables)

        print("Результат работы метода декомпозиции Baranov_2018 сохранен в папку results!\n")

    def decomposition_Magacho_2018(self):
        """
        Метод декомпозиции из статьи Magacho, G.R., et al., "Impacts of trade liberalization on countries’ sectoral
        structure of production and trade: A structural decomposition analysis." Structural Change and Economics
        Dynamics (2018)

        Декомпозиция по 4 факторам - технологические изменения, импортозамещение, конечный спрос, экспорт(формула 15).
        Также раскладываем суммарный экспорт на directed и indirirected.

        """
        # Колонки для результирующих таблиц
        res_columns = ['Технологические изменения', 'Импортозамещение','Конечный спрос(включая экспорт)',
                       'Экспорт косвенный', 'Экспорт прямой', 'Экспорт суммарный',
                       'dX полученный с помощью метода декомпозиции', 'Разность X1 - X0']

        res_percented_columns = ['Технологические изменения, %', 'Импортозамещение, %',
                       'Конечный спрос(включая экспорт), %', 'Экспорт косвенный, %', 'Экспорт  прямой, %',
                       'Экспорт суммарный, %']


        dA = self.A_m[1] + self.A_d[1] - self.A_m[0] - self.A_d[0]
        sumF = self.F_d[1] + self.F_d[0]

        # Получаем слагаемые декомпозиции изменения выпуска отечественной продукции
        technological_change = (self.L_d[1].dot(dA)).dot(self.L_d[0]).dot(sumF) / 2
        substitution_national_inputs = (self.L_d[1].dot(self.A_m[0] - self.A_m[1])).dot(self.L_d[0]).dot(sumF) / 2
        final_demands = (self.L_d[1] + self.L_d[0]).dot(self.F_d[1] - self.F_d[0]) / 2

        export = self.E[1] - self.E[0]
        export_total = (self.L_d[1] + self.L_d[0]).dot(export) / 2
        export_ind = export_total - export

        dX = technological_change + substitution_national_inputs + final_demands
        dX[dX == 0] = self.eps0

        # Проверяем, что изменения в валовом выпуске, полученные как сумма факторов (dX) сходятся с разностью
        # X[1] - X[0], полученной из таблиц (с точностью до 10^-5)
        assert (sum(self.X[1]) - sum(self.X[0]) - sum(dX) < 1e-5), \
            "Oops! Полученные суммарные изменения в валовом выпуске dX не равны X1 - X0!"


        # Заполняем таблицы
        results = pd.DataFrame(np.column_stack([technological_change, substitution_national_inputs,
                                         final_demands, export_ind, export, export_total, dX,
                                                self.X[1] - self.X[0]]), index=self.df_d[0].index,
                               columns=res_columns)

        results.columns.name = 'Выпуск отечественной продукции'


        results_percented = pd.DataFrame(np.column_stack([technological_change / abs(dX) * 100,
                                                        substitution_national_inputs / abs(dX) * 100,
                                                        final_demands / abs(dX) * 100, export_ind / abs(dX) * 100,
                                                        export / abs(dX) * 100, export_total / abs(dX) * 100]),
                                         index=self.df_d[0].index,columns=res_percented_columns)
        results_percented.columns.name = 'Выпуск отечественной продукции'


        results.loc["Total"] = [sum(technological_change), sum(substitution_national_inputs), sum(final_demands),
                            sum(export_ind), sum(export), sum(export_total), sum(dX), sum(self.X[1]) - sum(self.X[0])]
        results_percented.loc["Total"] = [sum(technological_change) / abs(sum(dX)) * 100,
                                          sum(substitution_national_inputs) / abs(sum(dX)) * 100,
                                         sum(final_demands) / abs(sum(dX)) * 100,
                                          sum(export_ind) / abs(sum(dX)) * 100,
                                          sum(export) / abs(sum(dX)) * 100,
                                          sum(export_total) / abs(sum(dX)) * 100]



        # Присваиваем имена таблицам и сохраняем в excel
        result_tables = {self.pack_name('Выпуск отечественной продукции'): results}
        result_percented_tables = {self.pack_name('Выпуск отечественной продукции'): results_percented}
        self.save_to_excel('results(Magacho_2018).xlsx', **result_tables)
        self.save_to_excel('results_in_percents(Magacho_2018).xlsx', **result_percented_tables)

        print("Результат работы метода декомпозиции Magacho_2018 сохранен в папку results!\n")

    def decomposition_Chenery_extended(self):
        """
        Расширенный метод декомпозиции Chenery.
        """

        res_columns_d = ['Изменения в технологиях', 'Изменения в соотношении отечественных и импортных затрат в '
                         'промежуточном спросе', 'Изменения во внешнем спросе(экспорт)',
                         'Изменение инвестиционного спроса на отечественную продукцию',
                         'Изменение запасов материальных оборотных средств на отечественную продукцию',

                         'Изменения соотношения отечественных и импортных инвестиционных продуктов',
                         'Изменения соотношения отечественных и импортных запасов материальных оборотных средств',
                         'Изменение потребительского спроса домашних хозяйств на отечественную продукцию',
                         'Изменения спроса со стороны государства на отечественную продукцию',
                         'Изменения соотношения отечественной продукции к импортной со стороны домашних хозяйств',
                         'Изменения соотношения отечественной продукции к импортной со стороны государственного '
                         'потербителя',
                         'dX полученный с помощью метода декомпозиции', 'Разность X1 - X0']

        res_index = ['Выпуск отечественной продукции', 'Импорт', 'Всего']
        res_columns_perc = list(map(self.add_percent_to_column_name, res_columns_d[:-2]))
        res_columns_m = res_columns_d[:-2] + ['Реэкспорт', 'dM полученный с помощью метода декомпозиции',
                                              'Разность M1 - M0']
        res_columns_perc_m = list(map(self.add_percent_to_column_name, res_columns_m[:-2]))

        sumL = self.L_d[0] + self.L_d[1]
        sumW = self.A_m[0].dot(self.L_d[0]) + self.A_m[1].dot(self.L_d[1])

        # Вычисляем абсолютные значения изменений величин
        dA = self.A[1] - self.A[0]
        dI = self.In[1] - self.In[0]
        # dC = self.C[1] - self.C[0]

        dI_s = self.I_s[1] - self.I_s[0]
        dI_gfch = self.I_gfch[1] - self.I_gfch[0]
        dC_g = self.C_g[1] - self.C_g[0]
        dC_h = self.C_h[1] - self.C_h[0]

        dR_d = self.R_d[1] - self.R_d[0]
        dR_In= self.R_In[1] - self.R_In[0]
        dR_Is = self.R_Is[1] - self.R_Is[0]
        dR_Igfch = self.R_Igfch[1] - self.R_Igfch[0]
        dR_Cg = self.R_Cg[1] - self.R_Cg[0]
        dR_Ch = self.R_Ch[1] - self.R_Ch[0]

        # Получаем слагаемые декомпозиции изменения выпуска отечественной продукции
        dX = np.array([np.zeros_like(self.M[0])] * 11)
        dX[0] = (self.L_d[0].dot(self.R_d[0] * dA).dot(self.X[1]) +
                 self.L_d[1].dot(self.R_d[1] * dA).dot(self.X[0])) / 2  # изменения технологии
        dX[1] = (self.L_d[0].dot(dR_d * self.A[1]).dot(self.X[1]) +
                 self.L_d[1].dot(dR_d * self.A[0]).dot(self.X[0])) / 2  # изменения соотношения отечественных и
        # импортных промежуточных затрат
        dX[2] = sumL.dot(self.E[1] - self.E[0]) / 2  # изменения во внешнем спросе

        dX[3] = (self.L_d[0].dot(self.R_In[0] * dI) + self.L_d[1].dot(self.R_In[1] * dI)) / 2  # изменения
        # инвестиционного спроса
        dX[4] = (self.L_d[0].dot(self.R_Is[0] * dI_s) + self.L_d[1].dot(self.R_Is[1] * dI_s)) / 2  # изменения
        # запаса материальных средств

        dX[5] = (self.L_d[0].dot(dR_In* self.In[1]) + self.L_d[1].dot(dR_In* self.In[0])) / 2 # изменения соотношения
        #  отечественных и импортных инвестиционных продуктов
        dX[6] = (self.L_d[0].dot(dR_Is * self.I_s[1]) +
                 self.L_d[1].dot(dR_Is * self.I_s[0])) / 2  # изменения соотношения отечественных и импортных запасов
        # материальных оборотных средств

        dX[7] = (self.L_d[0].dot(self.R_Ch[0] * dC_h) + self.L_d[1].dot(self.R_Ch[1] * dC_h)) / 2  # изменения
        # спроса со стороны домашних хозяйств
        dX[8] = (self.L_d[0].dot(self.R_Cg[0] * dC_g) + self.L_d[1].dot(self.R_Cg[1] * dC_g)) / 2  # изменения
        # спроса со стороны государства

        dX[9] = (self.L_d[0].dot(dR_Ch * self.C_h[1]) +
                 self.L_d[1].dot(dR_Ch * self.C_h[0])) / 2  # изменения соотношения отечественной продукции к
        # импортной со стороны домашних хозяйств
        dX[10] = (self.L_d[0].dot(dR_Cg * self.C_g[1]) +
                  self.L_d[1].dot(dR_Cg * self.C_g[0])) / 2  # изменения соотношения отечественной продукции к
        # импортной со стороны государства


        dX_all = sum(dX) - dX[4] - dX[6]
        Xtot = sum(dX_all)

        # Получаем слагаемые декомпозиции изменения импорта
        dM = np.array([np.zeros(len(self.M[0]))] * 12)

        dM[0] = ((dA * self.R_m[0]).dot(self.X[1]) + self.A_m[0].dot((self.L_d[0]).dot(self.R_d[0] * dA)).dot(self.X[1]) +
                 (dA * self.R_m[1]).dot(self.X[0]) +
                 self.A_m[1].dot((self.L_d[1]).dot(self.R_d[1] * dA)).dot(self.X[0])) / 2  # изменения технологии
        dM[1] = (self.A_m[0].dot((self.L_d[0]).dot(dR_d * self.A[1])).dot(self.X[1]) - (dR_d * self.A[1]).dot(self.X[1]) +
                 self.A_m[1].dot((self.L_d[1]).dot(dR_d * self.A[0])).dot(self.X[0]) -
                 (dR_d * self.A[0]).dot(self.X[0])) / 2  # изменения соотношения отечественных и импортных
        # промежуточных затрат
        dM[2] = sumW.dot(self.E[1] - self.E[0]) / 2  # изменения во внешнем спросе

        dM[3] = (self.A_m[0].dot((self.L_d[0]).dot(self.R_In[0] * dI)) + 2 * dI - (self.R_In[0] * dI) +
                 self.A_m[1].dot((self.L_d[1]).dot(self.R_In[1] * dI)) - (self.R_In[1] * dI)) / 2  # изменения
        # инвестиционного спроса
        dM[4] = (self.A_m[0].dot((self.L_d[0]).dot(self.R_Is[0] * dI_s)) + 2 * dI_s - (self.R_Is[0] * dI_s) +
                 self.A_m[1].dot((self.L_d[1]).dot(self.R_Is[1] * dI_s)) - (self.R_Is[1] * dI_s)) / 2  # изменения
        # запаса материальных средств

        dM[5] = (self.A_m[0].dot((self.L_d[0]).dot(dR_In* self.In[1])) - (dR_In* self.In[1]) +
                 self.A_m[1].dot((self.L_d[1]).dot(dR_In* self.In[0])) - (dR_In* self.In[0])) / 2  #
        # изменения соотношения отечественных и импортных инвестиционных продуктов
        dM[6] = (self.A_m[0].dot((self.L_d[0]).dot(dR_Is * self.I_s[1])) - (dR_Is * self.I_s[1]) +
                 self.A_m[1].dot((self.L_d[1]).dot(dR_Is * self.I_s[0])) - (dR_Is * self.I_s[0])) / 2  # изменения соотношения отечественных и импортных запасов
        # материальных оборотных средств

        dM[7] = (self.A_m[0].dot((self.L_d[0]).dot(self.R_Ch[0] * dC_h)) + 2 * dC_h - (self.R_Ch[0] * dC_h) +
                 self.A_m[1].dot((self.L_d[1]).dot(self.R_Ch[1] * dC_h)) - (self.R_Ch[1] * dC_h)) / 2  # изменения
        # спроса со стороны домашних хозяйств
        dM[8] = (self.A_m[0].dot((self.L_d[0]).dot(self.R_Cg[0] * dC_g)) + 2 * dC_g - (self.R_Cg[0] * dC_g) +
                  self.A_m[1].dot((self.L_d[1]).dot(self.R_Cg[1] * dC_g)) - (self.R_Cg[1] * dC_g)) / 2  # изменения
        # спроса со стороны государства

        dM[9] = (self.A_m[0].dot((self.L_d[0]).dot(dR_Ch * self.C_h[1])) - (dR_Ch * self.C_h[1]) +
                 self.A_m[1].dot((self.L_d[1]).dot(dR_Ch * self.C_h[0])) - (dR_Ch * self.C_h[0])) / 2 # изменения
        # соотношения отечественной продукции к импортной со стороны домашних хозяйств
        dM[10] = (self.A_m[0].dot((self.L_d[0]).dot(dR_Cg * self.C_g[1])) - (dR_Cg * self.C_g[1]) +
                 self.A_m[1].dot((self.L_d[1]).dot(dR_Cg * self.C_g[0])) - (dR_Cg * self.C_g[0])) / 2 # изменения
        # соотношения отечественной продукции к импортной со стороны государства




        dM[11] = self.E_r[1] - self.E_r[0]  # реэкспорт

        dM_all = sum(dM) - dM[4] - dM[6]
        Mtot = sum(dM_all)


        # Проверяем, что изменения в валовом выпуске, полученные как сумма факторов (dX_all и dM_all) сходятся с
        # разностями X[1] - X[0] и M[1] - M[0], полученными из таблиц (с точностью до 10^-5)
        assert (sum(self.X[1]) - sum(self.X[0]) - sum(
            dX_all) < 1e-5), "Oops! Полученные суммарные изменения в валовом выпуске dX_all не равны X1 - X0!"
        assert (sum(self.M[1]) - sum(self.M[0]) - sum(
            dM_all) < 1e-5), "Oops! Полученные суммарные изменения в валовом выпуске dM_all не равны M1 - M0!"

        # Суммы
        sumss_d = list(map(sum, dX))
        sumss_m = list(map(sum, dM))
        sumss = list(map(add, sumss_d, sumss_m))
        dX_all[dX_all == 0] = self.eps0
        #dX_all[dX_all == 0] = self.eps0

        # Вывод таблиц
        result_d = pd.DataFrame(np.column_stack([dX[0], dX[1], dX[2], dX[3], dX[4], dX[5], dX[6],
                                                 dX[7], dX[8], dX[9], dX[10], dX_all, self.X[1] - self.X[0]]),
                                columns=res_columns_d,
                                index=self.df_d[0].index)
        result_d.columns.name = 'Выпуск отечественной продукции'
        result_m = pd.DataFrame(np.column_stack([dM[0], dM[1], dM[2], dM[3], dM[4], dM[5], dM[6],
                                                 dM[7], dM[8], dM[9], dM[10], dM[11], dM_all, self.M[1] - self.M[0]]),
                                columns=res_columns_m, index=self.df_d[0].index)
        result_m.columns.name = 'Импорт'

        results_perc_d = pd.DataFrame(np.column_stack(dX[:] / abs(dX_all) * 100.), index=self.df_d[
            0].index, columns=res_columns_perc)
        results_perc_d.columns.name = 'Изменение отечественого выпуска'
        results_perc_m = pd.DataFrame(np.column_stack(dM[:] / abs(dM_all) * 100), index=self.df_d[0].index,
                                      columns=res_columns_perc_m)
        results_perc_m.columns.name = 'Изменение импорта'

        # Добавляем строки с суммой в конец таблиц
        result_d.loc['Total'] = sumss_d + [Xtot] + [sum(self.X[1]) - sum(self.X[0])]
        result_m.loc['Total'] = sumss_m + [Mtot] + [sum(self.M[1]) - sum(self.M[0])]
        results_perc_d.loc['Total'] = np.array(sumss_d) / abs(Xtot) * 100.
        results_perc_m.loc['Total'] = np.array(sumss_m) / abs(sum(dM_all)) * 100.

        # Суммарные результаты
        sumss_m = sumss_m[:-1]
        results = pd.DataFrame([sumss_d, sumss_m, sumss], index=res_index, columns=res_columns_d[:-2])
        results.columns.name = 'Изменение выпуска'

        results_perc = pd.DataFrame(
            [np.array(sumss_d) / abs(sum(sumss_d)) * 100, np.array(sumss_m) / abs(sum(sumss_m)) * 100,
             np.array(sumss) / abs(sum(sumss)) * 100], index=res_index, columns=res_columns_perc)
        results_perc.columns.name = 'Изменение выпуска'

        result_tables = {self.pack_name('Декомпозиция изменений выпуска по всем факторам'): results,
                         self.pack_name('Выпуск отечественной продукци'): result_d,
                         self.pack_name('Импорт за'): result_m}

        percented_result_tables = {self.pack_name("Декомпозиция изменений выпуска по всем факторам"): results_perc,
                                   self.pack_name("Декомпозиция изменений отечественного выпуска по всем факторам и "
                                                  "по всем отраслям"): results_perc_d,
                                   self.pack_name("Декомпозиция изменений импорта по всем факторам и по всем "
                                                  "отраслям"):results_perc_m}

        self.save_to_excel('results(Chenery_extended).xlsx', **result_tables)
        self.save_to_excel('results_in_percents(Chenery_extended).xlsx', **percented_result_tables)

        print("Результат работы метода декомпозиции Chenery_extended сохранен в папку results!\n")

    def save_to_excel(self, file_name, rounding="%.3f", **tables):
        """
        Cохраняет полученные таблицы в выбранный excel-файл

        Parameters
        ----------
        file_name: string
            имя файла
        rounding: string
            Формат округления чисел в сохраняемых таблицах.
            по умолчанию - "%.3f"(до 3 знаков после запятой),
            для результатов в процентах - "%.1f"(до 1 знака после запятой)
        tables: dictionary
            Словарь из названий таблиц и самих таблиц

        """
        writer = pd.ExcelWriter("./results/" + self.my_years + "/" + file_name, engine='xlsxwriter')
        workbook = writer.book

        for table_name, df in tables.items():
            sheet_name = df.columns.name

            df.to_excel(writer, sheet_name=sheet_name, float_format=rounding, startrow=1, startcol=2,
                        header=False, index=False)

            worksheet = writer.sheets[sheet_name]
            worksheet.set_zoom(80)
            worksheet.set_column(2, len(df.columns) + 1, 23)

            # Add a header format
            header_format = workbook.add_format({
                'bold': True,
                'text_wrap': True,
                'align': 'center',
                'valign': 'vcenter',
                'fg_color': '#D7E4BC',
                'border': 1})

            # Add total row formating
            if any(df.index.values == 'Total'):
                total_format = workbook.add_format({'bold': True, 'fg_color': '#ffb74d', 'border': 1})
                worksheet.write_row(np.shape(df)[0], 2, np.array(df.loc['Total', :]), total_format)

            # Add codes & index
            if len(df.index) > len(self.codes):
                codes2 = pd.concat([pd.Series(['']), self.codes])
                worksheet.write_column('A1', codes2, header_format)
            worksheet.write_column('B1', np.insert(df.index.values, 0, ''), header_format)
            worksheet.set_column('B:B', 45)

            # Add header
            columns = np.insert(df.columns.values, 0, table_name)
            for col_num, value in enumerate(columns):
                worksheet.write(0, col_num + 1, value, header_format)
            worksheet.set_row(0, 75)

        writer.save()
        workbook.close()
